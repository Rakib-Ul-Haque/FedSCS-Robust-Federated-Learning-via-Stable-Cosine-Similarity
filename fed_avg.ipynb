# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import os
import sys
import time
import copy
import random
import warnings
import pickle

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch import Tensor
from torch.utils.data import DataLoader, Subset

import torchvision
from torchvision import datasets, transforms, models

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from collections import Counter

# Plot settings
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Ignore warnings
warnings.filterwarnings("ignore")

# Reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda:0

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#====CNN model
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)

        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        # Fully connected layers
        self.fc1 = nn.Linear(128 * 8 * 8, 512)  # Adjust input size here
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Add a linear layer for classification

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)

        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)

        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# # Train

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag):
    global opti
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    # u_le_rate=(le_rate * w_l)
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(local_model.parameters(), max_norm=1.0)
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        # print(f"Round {roun}, client {cli}, epoch {epoch}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    # print(f"\n Round {roun}, client {cli+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= 0,0#test(f_weights, test_loader)
    
    
    epoch_rmd=0#model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [roun, cli, epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data
    
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()
    lmodel.load_state_dict(w)
    lmodel.eval()

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def calculate_flri(client_updates, client_weights):
    """
    client_updates: list of model update tensors (delta_w_k), flattened
    client_weights: list of weights (alpha_k), usually n_k / total_n
    """
    assert len(client_updates) == len(client_weights), "Mismatch between updates and weights"

    # Compute the weighted average update
    avg_update = sum(w * u for w, u in zip(client_weights, client_updates))

    def cosine_sim(a, b):
        return torch.nn.functional.cosine_similarity(a, b, dim=0)

    # Compute weighted disagreement
    rosa_t = 0.0
    for w_k, delta_k in zip(client_weights, client_updates):
        sim = cosine_sim(delta_k, avg_update)
        rosa_t += w_k * (1 - sim)
    
    return rosa_t.item()

# %%
def fed_avg(client_weights_list):
    """
    Plain averaging of client weights (no weighting by client sizes).
    client_sizes argument is ignored.
    """
    num_clients = len(client_weights_list)
    if num_clients == 0:
        raise ValueError("No client weights provided")

    agg_weights = {}
    for key in client_weights_list[0].keys():
        agg_weights[key] = torch.zeros_like(client_weights_list[0][key], dtype=torch.float32)

    for weights in client_weights_list:
        for key in agg_weights.keys():
            agg_weights[key] += weights[key].float()

    for key in agg_weights.keys():
        agg_weights[key] /= num_clients  # divide by number of clients

    return agg_weights

# %%
def flatten_model_update(update_dict):
    """
    Convert a dict of parameter tensors (model state dict differences)
    to one 1D flattened tensor.
    """
    flat_params = []
    for key in update_dict:
        flat_params.append(update_dict[key].flatten())
    return torch.cat(flat_params)

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_clients_list, participating_client_list, val_loader, folder_name, norms_results
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)
    r_flag=0
    # weights = [1] * C
    global delta_ad
    global weight_c
    # client_sizes=[1]*P

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]

        update_list=[]
        weight_list=[]
        client_sizes = []
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True)
                
                train_accuracy, train_loss, c_f_weights, epoch_flag = train(i_w, E, train_loader, learning_rate, c, r, epoch_flag)
                
                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

                model_update = {}
                for key in global_model.state_dict():
                    model_update[key] = torch.sub(c_f_weights[key], i_w[key])
                
                update_list.append(model_update)
                weight_list.append(c_f_weights)
                client_sizes.append(1)

            else:
                print(f"client {c} is not selectecd")
        
        # #calcualting AD
        # ad_c_list = []
        # num_participants = len(update_list)
        # for i in range(num_participants):
        #     dists = []
        #     for j in range(num_participants):
        #         if i != j:
        #             diff = 0.0
        #             for key in update_list[i]:
        #                 # diff += torch.norm(update_list[i][key] - update_list[j][key], p=2).item() ** 2
        #                 diff += torch.norm(update_list[i][key].float() - update_list[j][key].float(), p=2).item() ** 2

        #             dists.append(diff)
        #     ad_c = sum(dists) / (num_participants - 1)
        #     ad_c_list.append(ad_c)
        # delta_ad[f"round_{r}"]=(ad_c_list, r)

        #list and round counter
        round_epoch=(epoch_flag)
        
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)

        print(f"\n\n Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss}")

        # FedAvg aggregation
        all_final_weights = fed_avg(weight_list)
        
        # flat_updates = [flatten_model_update(update) for update in update_list]

        # total_samples = sum(client_sizes)
        # client_weights = [size / total_samples for size in client_sizes]

        flri=0#calculate_flri(flat_updates, client_weights)
        # print(f"round {r} = flri {flri}")
        
        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)# distribution=f'clients_no_{client_no}_data_non-IID_CIFAR10_alpha_0.5'
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss}")
        
        list_accuracy.append(round_train_accuracy)
        list_loss.append(round_train_loss)
        list_test_accuracy.append(round_test_accuracy)
        list_test_loss.append(round_test_loss)
        
        #model deviation code
        round_rmd=0#model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)
        
        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch, flri]
        round_results.loc[len(round_results)] = round_data
        
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed \n\n")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=10
participating_client=10
epochs=5
learning_rate=0.01
round_no=60
batch_size=64
data_class=10

opti="sgd"
# opti="adam"

mathod="fed_avg"

# set_up='IID'
# set_up='non_IID'
set_up='salt_pepper'
# set_up='mislabelled'

# iid
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_infinity"

#non_iid
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_0.1"
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_0.5"

#salt_pepper
# distribution=f"clients_no_5_10_IID_CIFAR10_alpha_infinity_0.6"
# distribution=f"clients_no_5_10_data_non-IID_CIFAR10_alpha_0.1_0.6"
distribution=f"clients_no_5_10_data_non-IID_CIFAR10_alpha_0.5_0.6"


#misslabelled
# distribution=f"IID_clients_1_2_3_4_60pct_mislabeled_CIFAR10_infinity"
# distribution=f"clients_1_2_3_4_60pct_mislabeled_CIFAR10_0.1"
# distribution=f"clients_1_2_3_4_60pct_mislabeled_CIFAR10_0.5"


# List of clients
total_clients_list = list(range(0, client_no))
# print(total_clients_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch', 'flri']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['round', 'client', 'train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

ad_client_values_list=[]

list_accuracy=[]
list_loss=[]
list_test_accuracy=[]
list_test_loss=[]


delta_ad={}
weight_c={}

#===================================loading the saved weight list====================================================
global_model = model().to(device)
file_path= "i_w.pth"
initial_weights = {k: v.clone() for k, v in global_model.state_dict().items()}
torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=False)
Print("Model's initial weights", initial_weights)

folder_name = f"{mathod}_{opti}_lr={learning_rate}_R={round_no}_E={epochs}_B={batch_size}_{distribution}"
# Out:
# Model's initial weights:conv1.weight: tensor([[ 0.1471,  0.1597, -0.0451],
#         [ 0.1768, -0.0422,  0.0388],
#         [-0.0937,  0.1130,  0.1697]], device='cuda:0')

# %% [markdown]
# # Dataset loader

# %%
def print_data_distribution(clients_data):
    """
    Print the distribution of class labels for each client.
    """
    for idx, client in enumerate(clients_data):
        labels = [label for (_, label) in client]
        class_counts = Counter(labels)
        sorted_counts = dict(sorted(class_counts.items()))
        print(f"Client {idx} - Total Samples: {len(labels)} - Class Distribution: {sorted_counts}")


pt_path = os.path.join(f'{set_up}', f'{distribution}.pt')

client_datasets = torch.load(pt_path)

print_data_distribution(client_datasets)

from torchvision import datasets, transforms
from torch.utils.data import DataLoader
# Define test set transformations for CIFAR-10 (no augmentation, just normalization)
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),  # mean for CIFAR-10
                         (0.2023, 0.1994, 0.2010))  # std for CIFAR-10
])
# Load CIFAR-10 test dataset
cifar10_test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Create DataLoader for the test set
test_loader = DataLoader(cifar10_test_dataset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# Client 0 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 1 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 2 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 3 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 4 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 5 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 6 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 7 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 8 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 9 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for clients
round_train_accuracy=0
round_train_loss=0
train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


list_accuracy.append(round_train_accuracy)
list_loss.append(round_train_loss)

#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
# val_accuracy,val_loss=test(initial_weights,val_loader)

# print(f"{test_accuracy}, {test_loss}, {val_accuracy}, {val_loss}  ")
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch, 0]
round_results.loc[len(round_results)] = round_data

# list_val_accuracy.append(val_accuracy)
# list_val_loss.append(val_loss)
list_test_accuracy.append(test_accuracy)
list_test_loss.append(test_loss)


Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[ 0.1471,  0.1597, -0.0451],
#         [ 0.1768, -0.0422,  0.0388],
#         [-0.0937,  0.1130,  0.1697]], device='cuda:0')
#
#  train accuracy: 9.994066455696203
#  train_loss: 2.302823704405676
#  test_accuracy: 10.093849840255592
#  test_loss: 2.3028393766750543

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
#  Model's Round: 1, train accuracy of model: 10.540000000000001, train loss of model: 2.3022051530548286
# Model's Round: 1, test accuracy of model: 10.103833865814696, test loss of model: 2.3021571323894463
# round 1 completed
#
#
#
#
#  Model's Round: 2, train accuracy of model: 11.94, train loss of model: 2.3001290846474562
# Model's Round: 2, test accuracy of model: 11.481629392971247, test loss of model: 2.2988180390562114
# round 2 completed
#
#
#
#
#  Model's Round: 3, train accuracy of model: 12.500000000000002, train loss of model: 2.280643450761143
# Model's Round: 3, test accuracy of model: 12.729632587859426, test loss of model: 2.250869056287284
# round 3 completed
#
#
#
#
#  Model's Round: 4, train accuracy of model: 23.895999999999997, train loss of model: 2.104820482489429
# Model's Round: 4, test accuracy of model: 25.668929712460063, test loss of model: 2.4139633079687246
# round 4 completed
#
#
#
#
#  Model's Round: 5, train accuracy of model: 26.948, train loss of model: 2.000604888759082
# Model's Round: 5, test accuracy of model: 27.46605431309904, test loss of model: 2.5055154840024514
# round 5 completed
#
#
#
#
#  Model's Round: 6, train accuracy of model: 30.022000000000002, train loss of model: 1.9381025441085231
# Model's Round: 6, test accuracy of model: 29.962060702875398, test loss of model: 2.3563375747241913
# round 6 completed
#
#
#
#
#  Model's Round: 7, train accuracy of model: 32.480000000000004, train loss of model: 1.8763130918333797
# Model's Round: 7, test accuracy of model: 31.25, test loss of model: 2.4437387888423934
# round 7 completed
#
#
#
#
#  Model's Round: 8, train accuracy of model: 34.842, train loss of model: 1.821162267727188
# Model's Round: 8, test accuracy of model: 32.787539936102235, test loss of model: 2.526871263790435
# round 8 completed
#
#
#
#
#  Model's Round: 9, train accuracy of model: 36.472, train loss of model: 1.777590729918661
# Model's Round: 9, test accuracy of model: 33.12699680511182, test loss of model: 2.5617038636161875
# round 9 completed
#
#
#
#
#  Model's Round: 10, train accuracy of model: 38.00599999999999, train loss of model: 1.7344413496270963
# Model's Round: 10, test accuracy of model: 32.697683706070286, test loss of model: 2.609929493440988
# round 10 completed
#
#
#
#
#  Model's Round: 11, train accuracy of model: 39.23, train loss of model: 1.6945536219621005
# Model's Round: 11, test accuracy of model: 29.52276357827476, test loss of model: 2.946323374208932
# round 11 completed
#
#
#
#
#  Model's Round: 12, train accuracy of model: 40.352000000000004, train loss of model: 1.6606520888171616
# Model's Round: 12, test accuracy of model: 27.236421725239616, test loss of model: 3.196163630714051
# round 12 completed
#
#
#
#
#  Model's Round: 13, train accuracy of model: 41.669999999999995, train loss of model: 1.6238428385951849
# Model's Round: 13, test accuracy of model: 26.936900958466452, test loss of model: 3.3037148950198967
# round 13 completed
#
#
#
#
#  Model's Round: 14, train accuracy of model: 42.392, train loss of model: 1.5930589066276066
# Model's Round: 14, test accuracy of model: 26.717252396166135, test loss of model: 3.696235157811223
# round 14 completed
#
#
#
#
#  Model's Round: 15, train accuracy of model: 43.598, train loss of model: 1.5612697249726406
# Model's Round: 15, test accuracy of model: 26.02835463258786, test loss of model: 4.133473661380073
# round 15 completed
#
#
#
#
#  Model's Round: 16, train accuracy of model: 44.55200000000001, train loss of model: 1.5384183934972255
# Model's Round: 16, test accuracy of model: 26.916932907348244, test loss of model: 4.226381558579758
# round 16 completed
#
#
#
#
#  Model's Round: 17, train accuracy of model: 45.368, train loss of model: 1.5149414886402177
# Model's Round: 17, test accuracy of model: 25.878594249201278, test loss of model: 4.763978865961678
# round 17 completed
#
#
#
#
#  Model's Round: 18, train accuracy of model: 46.172000000000004, train loss of model: 1.4878751276414603
# Model's Round: 18, test accuracy of model: 25.27955271565495, test loss of model: 5.135041058634798
# round 18 completed
#
#
#
#
#  Model's Round: 19, train accuracy of model: 47.251999999999995, train loss of model: 1.4696879592877399
# Model's Round: 19, test accuracy of model: 26.188099041533548, test loss of model: 4.964411765241775
# round 19 completed
#
#
#
#
#  Model's Round: 20, train accuracy of model: 48.038, train loss of model: 1.4425462494922592
# Model's Round: 20, test accuracy of model: 26.886980830670925, test loss of model: 4.976640139144068
# round 20 completed
#
#
#
#
#  Model's Round: 21, train accuracy of model: 48.971999999999994, train loss of model: 1.4194239137293416
# Model's Round: 21, test accuracy of model: 25.169728434504794, test loss of model: 5.392790115679415
# round 21 completed
#
#
#
#
#  Model's Round: 22, train accuracy of model: 49.464000000000006, train loss of model: 1.4025417111342464
# Model's Round: 22, test accuracy of model: 25.249600638977636, test loss of model: 5.725518679847352
# round 22 completed
#
#
#
#
#  Model's Round: 23, train accuracy of model: 50.074, train loss of model: 1.3840780206873446
# Model's Round: 23, test accuracy of model: 25.029952076677315, test loss of model: 5.891510390625975
# round 23 completed
#
#
#
#
#  Model's Round: 24, train accuracy of model: 51.338, train loss of model: 1.365645317488079
# Model's Round: 24, test accuracy of model: 26.447683706070286, test loss of model: 6.020900515321726
# round 24 completed
#
#
#
#
#  Model's Round: 25, train accuracy of model: 51.8, train loss of model: 1.3471791794782952
# Model's Round: 25, test accuracy of model: 27.116613418530353, test loss of model: 5.8121941699006685
# round 25 completed
#
#
#
#
#  Model's Round: 26, train accuracy of model: 52.584, train loss of model: 1.3194595964649056
# Model's Round: 26, test accuracy of model: 25.948482428115017, test loss of model: 6.109610334371987
# round 26 completed
#
#
#
#
#  Model's Round: 27, train accuracy of model: 53.06, train loss of model: 1.3063032022759882
# Model's Round: 27, test accuracy of model: 25.848642172523963, test loss of model: 6.2307752405111785
# round 27 completed
#
#
#
#
#  Model's Round: 28, train accuracy of model: 54.010000000000005, train loss of model: 1.2798361721672589
# Model's Round: 28, test accuracy of model: 28.64416932907348, test loss of model: 5.8601708526428515
# round 28 completed
#
#
#
#
#  Model's Round: 29, train accuracy of model: 54.754000000000005, train loss of model: 1.2607803814773317
# Model's Round: 29, test accuracy of model: 27.655750798722046, test loss of model: 6.299315852479051
# round 29 completed
#
#
#
#
#  Model's Round: 30, train accuracy of model: 55.540000000000006, train loss of model: 1.2414929488791695
# Model's Round: 30, test accuracy of model: 24.810303514376997, test loss of model: 6.74713609165277
# round 30 completed
#
#
#
#
#  Model's Round: 31, train accuracy of model: 56.512, train loss of model: 1.216354262753378
# Model's Round: 31, test accuracy of model: 28.60423322683706, test loss of model: 6.239774655991088
# round 31 completed
#
#
#
#
#  Model's Round: 32, train accuracy of model: 57.21, train loss of model: 1.2007639023322094
# Model's Round: 32, test accuracy of model: 28.973642172523963, test loss of model: 6.163401561042371
# round 32 completed
#
#
#
#
#  Model's Round: 33, train accuracy of model: 57.774, train loss of model: 1.1825991077513636
# Model's Round: 33, test accuracy of model: 28.51437699680511, test loss of model: 6.405322589051609
# round 33 completed
#
#
#
#
#  Model's Round: 34, train accuracy of model: 58.58799999999999, train loss of model: 1.1591320648223538
# Model's Round: 34, test accuracy of model: 29.552715654952078, test loss of model: 6.43915317233759
# round 34 completed
#
#
#
#
#  Model's Round: 35, train accuracy of model: 59.29600000000001, train loss of model: 1.1356187914368472
# Model's Round: 35, test accuracy of model: 28.983626198083066, test loss of model: 6.2905709233146885
# round 35 completed
#
#
#
#
#  Model's Round: 36, train accuracy of model: 60.42999999999999, train loss of model: 1.1106618221802047
# Model's Round: 36, test accuracy of model: 27.476038338658146, test loss of model: 6.950760107832595
# round 36 completed
#
#
#
#
#  Model's Round: 37, train accuracy of model: 60.998000000000005, train loss of model: 1.102235103332544
# Model's Round: 37, test accuracy of model: 27.116613418530353, test loss of model: 6.902088446358142
# round 37 completed
#
#
#
#
#  Model's Round: 38, train accuracy of model: 61.622, train loss of model: 1.0816302265547502
# Model's Round: 38, test accuracy of model: 30.630990415335464, test loss of model: 6.14620991789114
# round 38 completed
#
#
#
#
#  Model's Round: 39, train accuracy of model: 62.112, train loss of model: 1.0569739686726016
# Model's Round: 39, test accuracy of model: 31.978833865814696, test loss of model: 5.791095029812651
# round 39 completed
#
#
#
#
#  Model's Round: 40, train accuracy of model: 62.964, train loss of model: 1.035524921251249
# Model's Round: 40, test accuracy of model: 31.269968051118212, test loss of model: 5.983037349134207
# round 40 completed
#
#
#
#
#  Model's Round: 41, train accuracy of model: 63.657999999999994, train loss of model: 1.0214439023899125
# Model's Round: 41, test accuracy of model: 33.89576677316294, test loss of model: 5.5876103094972365
# round 41 completed
#
#
#
#
#  Model's Round: 42, train accuracy of model: 64.178, train loss of model: 0.9985173359701905
# Model's Round: 42, test accuracy of model: 32.33825878594249, test loss of model: 6.003649665143924
# round 42 completed
#
#
#
#
#  Model's Round: 43, train accuracy of model: 64.992, train loss of model: 0.9824869550481627
# Model's Round: 43, test accuracy of model: 32.50798722044728, test loss of model: 5.971454744521802
# round 43 completed
#
#
#
#
#  Model's Round: 44, train accuracy of model: 65.74800000000002, train loss of model: 0.9611910917336429
# Model's Round: 44, test accuracy of model: 33.67611821086262, test loss of model: 5.9692830871850155
# round 44 completed
#
#
#
#
#  Model's Round: 45, train accuracy of model: 66.41999999999999, train loss of model: 0.9403935911723332
# Model's Round: 45, test accuracy of model: 34.11541533546326, test loss of model: 5.886503406226064
# round 45 completed
#
#
#
#
#  Model's Round: 46, train accuracy of model: 66.95000000000002, train loss of model: 0.9286924958606312
# Model's Round: 46, test accuracy of model: 34.105431309904155, test loss of model: 6.033231307142459
# round 46 completed
#
#
#
#
#  Model's Round: 47, train accuracy of model: 67.4, train loss of model: 0.9107873970571954
# Model's Round: 47, test accuracy of model: 34.12539936102237, test loss of model: 5.933046089574551
# round 47 completed
#
#
#
#
#  Model's Round: 48, train accuracy of model: 68.498, train loss of model: 0.8842609619792503
# Model's Round: 48, test accuracy of model: 35.99241214057508, test loss of model: 5.908027831357889
# round 48 completed
#
#
#
#
#  Model's Round: 49, train accuracy of model: 69.142, train loss of model: 0.8651096291934387
# Model's Round: 49, test accuracy of model: 35.543130990415335, test loss of model: 5.813221046338066
# round 49 completed
#
#
#
#
#  Model's Round: 50, train accuracy of model: 69.792, train loss of model: 0.8524895190438138
# Model's Round: 50, test accuracy of model: 37.79952076677316, test loss of model: 5.428754869360512
# round 50 completed
#
#
#
#
#  Model's Round: 51, train accuracy of model: 70.55799999999999, train loss of model: 0.8340785089927383
# Model's Round: 51, test accuracy of model: 37.1305910543131, test loss of model: 5.812897510041063
# round 51 completed
#
#
#
#
#  Model's Round: 52, train accuracy of model: 70.636, train loss of model: 0.8231238355364979
# Model's Round: 52, test accuracy of model: 37.549920127795524, test loss of model: 5.561588039794288
# round 52 completed
#
#
#
#
#  Model's Round: 53, train accuracy of model: 71.464, train loss of model: 0.8009050011634826
# Model's Round: 53, test accuracy of model: 39.13738019169329, test loss of model: 5.377083764670375
# round 53 completed
#
#
#
#
#  Model's Round: 54, train accuracy of model: 72.14599999999999, train loss of model: 0.784930717718752
# Model's Round: 54, test accuracy of model: 38.188897763578275, test loss of model: 5.726831035492139
# round 54 completed
#
#
#
#
#  Model's Round: 55, train accuracy of model: 72.69999999999999, train loss of model: 0.7693022323560111
# Model's Round: 55, test accuracy of model: 39.177316293929714, test loss of model: 5.596500490420162
# round 55 completed
#
#
#
#
#  Model's Round: 56, train accuracy of model: 73.518, train loss of model: 0.7476955175022536
# Model's Round: 56, test accuracy of model: 39.47683706070288, test loss of model: 5.4866738167052835
# round 56 completed
#
#
#
#
#  Model's Round: 57, train accuracy of model: 74.31, train loss of model: 0.7276921778162824
# Model's Round: 57, test accuracy of model: 38.16892971246006, test loss of model: 5.967029395194861
# round 57 completed
#
#
#
#
#  Model's Round: 58, train accuracy of model: 74.32, train loss of model: 0.7236831799338136
# Model's Round: 58, test accuracy of model: 40.155750798722046, test loss of model: 5.587749657158653
# round 58 completed
#
#
#
#
#  Model's Round: 59, train accuracy of model: 75.244, train loss of model: 0.7071287775341469
# Model's Round: 59, test accuracy of model: 42.31230031948882, test loss of model: 5.160336468547297
# round 59 completed
#
#
#
#
#  Model's Round: 60, train accuracy of model: 75.52599999999998, train loss of model: 0.6879468825421755
# Model's Round: 60, test accuracy of model: 39.47683706070288, test loss of model: 5.974577423863518
# round 60 completed

# %%
# folder_name = f"{mathod}_{opti}_lr={learning_rate}_R={round_no}_ E={epochs}_B={batch_size}_{distribution}"
fn_=f"{mathod}_{opti}_E={epochs}_B={batch_size}_iid"

# %%
# def plot_train_test_accuracy(round_results, title, folder):
#     rounds = list(range(0, len(round_results)))
#     train_accuracies = round_results['train_accuracy'].tolist()
#     test_accuracies = round_results['test_accuracy'].tolist()

#     fig, ax = plt.subplots(figsize=(5, 3))
#     ax.plot(rounds, train_accuracies, label='Train Accuracy', color='blue')
#     ax.plot(rounds, test_accuracies, label='Test Accuracy', color='green')

#     ax.set_xlabel("Round")
#     ax.set_ylabel("Server accuracy in %")
#     ax.set_title(title)
#     ax.set_ylim(0, 100)
#     ax.set_xlim(0, len(rounds))
#     ax.set_xticks(range(0, len(rounds) + 2, 10))

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     ax.grid(True)
#     ax.legend()
#     plt.tight_layout()
#     os.makedirs(folder, exist_ok=True)
#     filename = os.path.join(folder, f"{title}.png")
#     plt.savefig(filename, dpi=300)
#     plt.show()





# def plot_flri(round_results, title, folder):
#     rounds = list(range(0, len(round_results)))
#     train_accuracies = round_results['flri'].tolist()
#     print(train_accuracies)
#     # test_accuracies = round_results['test_accuracy'].tolist()

#     fig, ax = plt.subplots(figsize=(5, 3))
#     ax.plot(rounds, train_accuracies, label='flri', color='blue')
#     # ax.plot(rounds, test_accuracies, label='Test Accuracy', color='green')

#     ax.set_xlabel("Round")
#     ax.set_ylabel("Server accuracy in %")
#     ax.set_title(title)
#     ax.set_ylim(0, 2)
#     ax.set_xlim(0, len(rounds))Amr found himself sidelined and held partially responsible for Uthman's death. He then allied with Mu'awiya, who was also seeking retribution for Uthman's death and challenging Caliph Ali's rule. Amr'
#     ax.set_xticks(range(0, len(rounds) + 2, 10))

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     ax.grid(True)
#     ax.legend()
#     plt.tight_layout()
#     os.makedirs(folder, exist_ok=True)
#     filename = os.path.join(folder, f"{title}.png")
#     plt.savefig(filename, dpi=300)
#     plt.show()

# %%
# # title = f"a) AD vs R for {fn_}"
# # plot_rounds_clients_ad(delta_ad, title, folder_name)

# title = f"Acc (%) vs R for {fn_}"
# plot_train_test_accuracy(round_results, title, folder_name)

# title = f"flri vs R for {fn_}"
# plot_flri(round_results, title, folder_name)

# %% [markdown]
# # Reuslts

# %%
save_dir = folder_name  # your desired folder
os.makedirs(save_dir, exist_ok=True)  # create folder if not exists

save_path = os.path.join(save_dir, 'delta_ad_data.pt')
torch.save(delta_ad, save_path)
print(f"[✓] delta_ad saved at {save_path}")

save_path = os.path.join(folder_name, 'delta_ad_data.pt')

# Load the saved file
if os.path.exists(save_path):
    delta_ad_loaded = torch.load(save_path)
    print("[✓] Loaded delta_ad from:", save_path)
    print(delta_ad_loaded)
else:
    print("[✗] File not found at:", save_path)
# Out:
# [✓] delta_ad saved at fed_avg_sgd_lr=0.01_R=60_E=5_B=64_clients_no_10_data_IID_CIFAR10_alpha_infinity/delta_ad_data.pt
# [✓] Loaded delta_ad from: fed_avg_sgd_lr=0.01_R=60_E=5_B=64_clients_no_10_data_IID_CIFAR10_alpha_infinity/delta_ad_data.pt
# {}

# %%
# Round # Define the folder and file name
# folder_name = f"fed_avg_{opti}_{learning_rate}_{name}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
# folder_name =  f"fed_avg_{opti}_{learning_rate}_{name}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
