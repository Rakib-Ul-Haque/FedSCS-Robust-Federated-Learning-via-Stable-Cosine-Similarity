# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import os
import sys
import time
import copy
import random
import warnings
import pickle

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch import Tensor
from torch.utils.data import DataLoader, Subset

import torchvision
from torchvision import datasets, transforms, models

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
from collections import defaultdict

from sklearn.metrics import confusion_matrix
from collections import Counter

# Plot settings
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Ignore warnings
warnings.filterwarnings("ignore")

# Reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda:0

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#====CNN model
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)

        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        # Fully connected layers
        self.fc1 = nn.Linear(128 * 8 * 8, 512)  # Adjust input size here
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Add a linear layer for classification

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)

        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)

        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# # Train

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag):
    global opti
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    # u_le_rate=(le_rate * w_l)
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(local_model.parameters(), max_norm=1.0)
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        # print(f"Round {roun}, client {cli}, epoch {epoch}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    print(f"\n Round {roun}, client {cli+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    # epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    epoch_test_accuracy=0
    epoch_test_loss=0
    
    epoch_rmd=0#model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [roun, cli, epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data

    delta_weights = {
        k: f_weights[k].to(device) - i_weights[k].to(device)
        for k in i_weights
    }
    
    # Compute L2 norm of weight deltas (proxy for gradient norm)
    delta_norm = 0.0
    for k in delta_weights:
        # Ensure we're working with float tensors
        if delta_weights[k].is_floating_point():
            delta_norm += torch.norm(delta_weights[k]).item() ** 2
    delta_norm = delta_norm ** 0.5
    
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag, delta_norm

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()
    lmodel.load_state_dict(w)
    lmodel.eval()

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
# def calculate_flri(client_updates, client_weights):
#     """
#     client_updates: list of model update tensors (delta_w_k), flattened
#     client_weights: list of weights (alpha_k), usually n_k / total_n
#     """
#     assert len(client_updates) == len(client_weights), "Mismatch between updates and weights"

#     # Compute the weighted average update
#     avg_update = sum(w * u for w, u in zip(client_weights, client_updates))

#     def cosine_sim(a, b):
#         return torch.nn.functional.cosine_similarity(a, b, dim=0)

#     # Compute weighted disagreement
#     rosa_t = 0.0
#     for w_k, delta_k in zip(client_weights, client_updates):
#         sim = cosine_sim(delta_k, avg_update)
#         rosa_t += w_k * (1 - sim)
    
#     return rosa_t.item()

# %%
# def fed_avg(client_weights_list):
#     """
#     Plain averaging of client weights (no weighting by client sizes).
#     client_sizes argument is ignored.
#     """
#     num_clients = len(client_weights_list)
#     if num_clients == 0:
#         raise ValueError("No client weights provided")

#     agg_weights = {}
#     for key in client_weights_list[0].keys():
#         agg_weights[key] = torch.zeros_like(client_weights_list[0][key], dtype=torch.float32)

#     for weights in client_weights_list:
#         for key in agg_weights.keys():
#             agg_weights[key] += weights[key].float()

#     for key in agg_weights.keys():
#         agg_weights[key] /= num_clients  # divide by number of clients

#     return agg_weights


# --------------------------
# FedAAW Aggregation
# --------------------------

def fed_aaw_aggregation(i_w, client_weights_list, client_sizes, gradient_history, beta=1.0, gamma=0.1):
    total_size = sum(client_sizes)
    weights = {}
    
    # Calculate adaptive weights
    for c, (client_weights, delta_norm) in enumerate(client_weights_list):
        Dk = client_sizes[c]
        
        # Update gradient history with delta norm
        if c not in gradient_history:
            gradient_history[c] = [delta_norm]
        else:
            gradient_history[c].append(delta_norm)
        
        # Calculate Rk as moving average of delta norms
        Rk = np.mean(gradient_history[c])
        
        # FedAAW weight formula
        weights[c] = (Dk / total_size) * (beta / (Rk + 1e-8)) - gamma
    
    # Softmax normalization
    q_values = np.array(list(weights.values()))
    exp_q = np.exp(q_values - np.max(q_values))
    normalized_weights = exp_q / exp_q.sum()
    
    # Weighted aggregation
    aggregated_weights = {}
    for key in client_weights_list[0][0].keys():
        aggregated_weights[key] = sum(
            client_weights[key] * normalized_weights[i]
            for i, (client_weights, _) in enumerate(client_weights_list)
        )
        
    return aggregated_weights, gradient_history

# %%
def flatten_model_update(update_dict):
    """
    Convert a dict of parameter tensors (model state dict differences)
    to one 1D flattened tensor.
    """
    flat_params = []
    for key in update_dict:
        flat_params.append(update_dict[key].flatten())
    return torch.cat(flat_params)

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_clients_list, participating_client_list, val_loader, folder_name, norms_results
    
    global gradient_history, device, betas, gammas
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)
    r_flag=0
    # weights = [1] * C
    global delta_ad
    global weight_c
    # client_sizes=[1]*P

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]

        update_list=[]
        weight_list=[]
        norm_list=[]
        client_sizes = []
        models=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True)
                
                train_accuracy, train_loss, c_f_weights, epoch_flag, delta_norm = train(i_w, E, train_loader, learning_rate, c, r, epoch_flag)
                
                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

                model_update = {}
                for key in global_model.state_dict():
                    model_update[key] = torch.sub(c_f_weights[key], i_w[key])
                
                update_list.append(model_update)
                weight_list.append(c_f_weights)
                client_sizes.append(len(data))
                norm_list.append(delta_norm)
                models.append((c_f_weights, delta_norm))
                
            else:
                print(f"client {c} is not selectecd")
        
        # #calcualting AD
        # ad_c_list = []
        # num_participants = len(update_list)
        # for i in range(num_participants):
        #     dists = []
        #     for j in range(num_participants):
        #         if i != j:
        #             diff = 0.0
        #             for key in update_list[i]:
        #                 # diff += torch.norm(update_list[i][key] - update_list[j][key], p=2).item() ** 2
        #                 diff += torch.norm(update_list[i][key].float() - update_list[j][key].float(), p=2).item() ** 2

        #             dists.append(diff)
        #     ad_c = sum(dists) / (num_participants - 1)
        #     ad_c_list.append(ad_c)
        # delta_ad[f"round_{r}"]=(ad_c_list, r)

        #list and round counter
        round_epoch=(epoch_flag)
        
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)

        print(f"\n\n Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss}")

        # FedAvg aggregation
        # all_final_weights = fed_avg(weight_list)
        all_final_weights, gradient_history = fed_aaw_aggregation(i_w=i_w,
                                                                client_weights_list=models,
                                                                client_sizes=client_sizes,
                                                                gradient_history=gradient_history, 
                                                                beta=betas, 
                                                                gamma=gammas)
        
        flat_updates = [flatten_model_update(update) for update in update_list]

        total_samples = sum(client_sizes)
        client_weights = [size / total_samples for size in client_sizes]

        flri= 0 #calculate_flri(flat_updates, client_weights)
        print(f"round {r} = flri {flri}")
        
        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)# distribution=f'clients_no_{client_no}_data_non-IID_CIFAR10_alpha_0.5'
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss}")
        
        list_accuracy.append(round_train_accuracy)
        list_loss.append(round_train_loss)
        list_test_accuracy.append(round_test_accuracy)
        list_test_loss.append(round_test_loss)
        
        #model deviation code
        round_rmd=0#model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)
        
        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch, flri]
        round_results.loc[len(round_results)] = round_data
        
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed \n\n")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=10
participating_client=10
epochs=5
learning_rate=0.01
round_no=60
batch_size=64
data_class=10

gradient_history = defaultdict(list)  # For storing smoothed gradients# You should populate this list based on actual client data

betas = 0.01             # Momentum-like smoothing
gammas= 1.0    


opti="sgd"
# opti="adam"

mathod="fed_aaw"

# set_up='IID'
# set_up='non_IID'
set_up='salt_pepper'
# set_up='mislabelled'

# iid
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_infinity"

#non_iid
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_0.1"
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_0.5"

#salt_pepper
# distribution=f"clients_no_5_10_IID_CIFAR10_alpha_infinity_0.6"
# distribution=f"clients_no_5_10_data_non-IID_CIFAR10_alpha_0.1_0.6"
distribution=f"clients_no_5_10_data_non-IID_CIFAR10_alpha_0.5_0.6"


#misslabelled
# distribution=f"IID_clients_1_2_3_4_60pct_mislabeled_CIFAR10_infinity"
# distribution=f"clients_1_2_3_4_60pct_mislabeled_CIFAR10_0.1"
# distribution=f"clients_1_2_3_4_60pct_mislabeled_CIFAR10_0.5"

# List of clients
total_clients_list = list(range(0, client_no))
# print(total_clients_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch', 'flri']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['round', 'client', 'train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

ad_client_values_list=[]

list_accuracy=[]
list_loss=[]
list_test_accuracy=[]
list_test_loss=[]


delta_ad={}
weight_c={}

#===================================loading the saved weight list====================================================
global_model = model().to(device)
file_path= "i_w.pth"
initial_weights = {k: v.clone() for k, v in global_model.state_dict().items()}
torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=False)
Print("Model's initial weights", initial_weights)

folder_name = f"{mathod}_{opti}_lr={learning_rate}_R={round_no}_E={epochs}_B={batch_size}_{distribution}"
# Out:
# Model's initial weights:conv1.weight: tensor([[ 0.1471,  0.1597, -0.0451],
#         [ 0.1768, -0.0422,  0.0388],
#         [-0.0937,  0.1130,  0.1697]], device='cuda:0')

# %% [markdown]
# # Dataset loader

# %%
def print_data_distribution(clients_data):
    """
    Print the distribution of class labels for each client.
    """
    for idx, client in enumerate(clients_data):
        labels = [label for (_, label) in client]
        class_counts = Counter(labels)
        sorted_counts = dict(sorted(class_counts.items()))
        print(f"Client {idx} - Total Samples: {len(labels)} - Class Distribution: {sorted_counts}")


pt_path = os.path.join(f'{set_up}', f'{distribution}.pt')

client_datasets = torch.load(pt_path)

print_data_distribution(client_datasets)

from torchvision import datasets, transforms
from torch.utils.data import DataLoader
# Define test set transformations for CIFAR-10 (no augmentation, just normalization)
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),  # mean for CIFAR-10
                         (0.2023, 0.1994, 0.2010))  # std for CIFAR-10
])
# Load CIFAR-10 test dataset
cifar10_test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Create DataLoader for the test set
test_loader = DataLoader(cifar10_test_dataset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# Client 0 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 1 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 2 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 3 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 4 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 5 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 6 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 7 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 8 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 9 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for clients
round_train_accuracy=0
round_train_loss=0
train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


list_accuracy.append(round_train_accuracy)
list_loss.append(round_train_loss)

#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
# val_accuracy,val_loss=test(initial_weights,val_loader)

# print(f"{test_accuracy}, {test_loss}, {val_accuracy}, {val_loss}  ")
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch, 0]
round_results.loc[len(round_results)] = round_data

# list_val_accuracy.append(val_accuracy)
# list_val_loss.append(val_loss)
list_test_accuracy.append(test_accuracy)
list_test_loss.append(test_loss)


Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[ 0.1471,  0.1597, -0.0451],
#         [ 0.1768, -0.0422,  0.0388],
#         [-0.0937,  0.1130,  0.1697]], device='cuda:0')
#
#  train accuracy: 9.994066455696203
#  train_loss: 2.302823704405676
#  test_accuracy: 10.093849840255592
#  test_loss: 2.3028393766750543

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
#  Round 1, client 1: epoch_accuracy 11.7, epoch_loss 2.3019570217856877
#
#
#  Round 1, client 2: epoch_accuracy 11.02, epoch_loss 2.3019271681580364
#
#
#  Round 1, client 3: epoch_accuracy 10.78, epoch_loss 2.3020052668414537
#
#
#  Round 1, client 4: epoch_accuracy 10.16, epoch_loss 2.3021542422379118
#
#
#  Round 1, client 5: epoch_accuracy 10.48, epoch_loss 2.302078856697565
#
#
#  Round 1, client 6: epoch_accuracy 10.76, epoch_loss 2.3022578305835966
#
#
#  Round 1, client 7: epoch_accuracy 11.24, epoch_loss 2.302345568620706
#
#
#  Round 1, client 8: epoch_accuracy 9.52, epoch_loss 2.3023279829870296
#
#
#  Round 1, client 9: epoch_accuracy 10.4, epoch_loss 2.3023708440080473
#
#
#  Round 1, client 10: epoch_accuracy 9.34, epoch_loss 2.302626748628254
#
#
#
#  Model's Round: 1, train accuracy of model: 10.540000000000001, train loss of model: 2.3022051530548286
# round 1 = flri 0
# Model's Round: 1, test accuracy of model: 10.103833865814696, test loss of model: 2.302157146100419
# round 1 completed
#
#
#
#  Round 2, client 1: epoch_accuracy 12.54, epoch_loss 2.299938259245474
#
#
#  Round 2, client 2: epoch_accuracy 12.68, epoch_loss 2.29972797104075
#
#
#  Round 2, client 3: epoch_accuracy 12.2, epoch_loss 2.3004424571990967
#
#
#  Round 2, client 4: epoch_accuracy 11.54, epoch_loss 2.3000678382342374
#
#
#  Round 2, client 5: epoch_accuracy 11.5, epoch_loss 2.300633478768264
#
#
#  Round 2, client 6: epoch_accuracy 12.0, epoch_loss 2.29980794085732
#
#
#  Round 2, client 7: epoch_accuracy 11.26, epoch_loss 2.2997703642784795
#
#
#  Round 2, client 8: epoch_accuracy 11.84, epoch_loss 2.3004353046417236
#
#
#  Round 2, client 9: epoch_accuracy 12.38, epoch_loss 2.2999817993067486
#
#
#  Round 2, client 10: epoch_accuracy 11.84, epoch_loss 2.3004976646809636
#
#
#
#  Model's Round: 2, train accuracy of model: 11.978000000000002, train loss of model: 2.300130307825306
# round 2 = flri 0
# Model's Round: 2, test accuracy of model: 11.461661341853036, test loss of model: 2.2988240101847786
# round 2 completed
#
#
#
#  Round 3, client 1: epoch_accuracy 12.66, epoch_loss 2.2822622920893414
#
#
#  Round 3, client 2: epoch_accuracy 12.42, epoch_loss 2.278161667570283
#
#
#  Round 3, client 3: epoch_accuracy 12.42, epoch_loss 2.282341259944288
#
#
#  Round 3, client 4: epoch_accuracy 11.84, epoch_loss 2.279671318923371
#
#
#  Round 3, client 5: epoch_accuracy 12.06, epoch_loss 2.2836175447777856
#
#
#  Round 3, client 6: epoch_accuracy 13.14, epoch_loss 2.277291282822814
#
#
#  Round 3, client 7: epoch_accuracy 12.0, epoch_loss 2.2770857750614986
#
#
#  Round 3, client 8: epoch_accuracy 12.94, epoch_loss 2.281418408019633
#
#
#  Round 3, client 9: epoch_accuracy 11.94, epoch_loss 2.2844082584863976
#
#
#  Round 3, client 10: epoch_accuracy 13.5, epoch_loss 2.280409483969966
#
#
#
#  Model's Round: 3, train accuracy of model: 12.492, train loss of model: 2.280666729166538
# round 3 = flri 0
# Model's Round: 3, test accuracy of model: 12.71964856230032, test loss of model: 2.250933321139302
# round 3 completed
#
#
#
#  Round 4, client 1: epoch_accuracy 24.5, epoch_loss 2.100707924818691
#
#
#  Round 4, client 2: epoch_accuracy 24.2, epoch_loss 2.0911197390737413
#
#
#  Round 4, client 3: epoch_accuracy 24.4, epoch_loss 2.1063186171688613
#
#
#  Round 4, client 4: epoch_accuracy 23.74, epoch_loss 2.0959694053553326
#
#
#  Round 4, client 5: epoch_accuracy 23.68, epoch_loss 2.1212447851519043
#
#
#  Round 4, client 6: epoch_accuracy 23.2, epoch_loss 2.1137157376808458
#
#
#  Round 4, client 7: epoch_accuracy 24.24, epoch_loss 2.0817932162103774
#
#
#  Round 4, client 8: epoch_accuracy 23.24, epoch_loss 2.1120983528185495
#
#
#  Round 4, client 9: epoch_accuracy 24.64, epoch_loss 2.1162200562561613
#
#
#  Round 4, client 10: epoch_accuracy 23.28, epoch_loss 2.109944215303735
#
#
#
#  Model's Round: 4, train accuracy of model: 23.912, train loss of model: 2.10491320498382
# round 4 = flri 0
# Model's Round: 4, test accuracy of model: 25.69888178913738, test loss of model: 2.413015377788117
# round 4 completed
#
#
#
#  Round 5, client 1: epoch_accuracy 27.1, epoch_loss 1.9914314716677122
#
#
#  Round 5, client 2: epoch_accuracy 26.7, epoch_loss 2.0092071204245845
#
#
#  Round 5, client 3: epoch_accuracy 27.08, epoch_loss 2.0098875323428382
#
#
#  Round 5, client 4: epoch_accuracy 26.78, epoch_loss 1.997249293930923
#
#
#  Round 5, client 5: epoch_accuracy 27.0, epoch_loss 2.009425778932209
#
#
#  Round 5, client 6: epoch_accuracy 26.76, epoch_loss 2.0035520912725713
#
#
#  Round 5, client 7: epoch_accuracy 27.76, epoch_loss 1.97764839401728
#
#
#  Round 5, client 8: epoch_accuracy 26.66, epoch_loss 2.0086832846267315
#
#
#  Round 5, client 9: epoch_accuracy 27.46, epoch_loss 1.997426549090615
#
#
#  Round 5, client 10: epoch_accuracy 26.02, epoch_loss 2.003118045722382
#
#
#
#  Model's Round: 5, train accuracy of model: 26.932, train loss of model: 2.0007629562027844
# round 5 = flri 0
# Model's Round: 5, test accuracy of model: 27.37619808306709, test loss of model: 2.50339569375157
# round 5 completed
#
#
#
#  Round 6, client 1: epoch_accuracy 30.08, epoch_loss 1.9198834941356997
#
#
#  Round 6, client 2: epoch_accuracy 30.5, epoch_loss 1.941062426265282
#
#
#  Round 6, client 3: epoch_accuracy 28.96, epoch_loss 1.947078845168971
#
#
#  Round 6, client 4: epoch_accuracy 30.84, epoch_loss 1.9238650889336308
#
#
#  Round 6, client 5: epoch_accuracy 30.4, epoch_loss 1.9352254716655877
#
#
#  Round 6, client 6: epoch_accuracy 29.4, epoch_loss 1.9633958520768564
#
#
#  Round 6, client 7: epoch_accuracy 30.1, epoch_loss 1.9300644322286677
#
#
#  Round 6, client 8: epoch_accuracy 29.98, epoch_loss 1.9410178585897517
#
#
#  Round 6, client 9: epoch_accuracy 30.76, epoch_loss 1.9322653450543368
#
#
#  Round 6, client 10: epoch_accuracy 29.54, epoch_loss 1.9470743257788163
#
#
#
#  Model's Round: 6, train accuracy of model: 30.056, train loss of model: 1.9380933139897603
# round 6 = flri 0
# Model's Round: 6, test accuracy of model: 29.962060702875398, test loss of model: 2.3540455163858187
# round 6 completed
#
#
#
#  Round 7, client 1: epoch_accuracy 32.2, epoch_loss 1.8743725924552241
#
#
#  Round 7, client 2: epoch_accuracy 32.76, epoch_loss 1.8801449929611593
#
#
#  Round 7, client 3: epoch_accuracy 32.8, epoch_loss 1.8746729455416715
#
#
#  Round 7, client 4: epoch_accuracy 32.62, epoch_loss 1.8711666246003742
#
#
#  Round 7, client 5: epoch_accuracy 31.82, epoch_loss 1.8791303197039833
#
#
#  Round 7, client 6: epoch_accuracy 32.46, epoch_loss 1.893178555029857
#
#
#  Round 7, client 7: epoch_accuracy 32.28, epoch_loss 1.8571966780891902
#
#
#  Round 7, client 8: epoch_accuracy 32.0, epoch_loss 1.8914976240713386
#
#
#  Round 7, client 9: epoch_accuracy 32.8, epoch_loss 1.8731051034565214
#
#
#  Round 7, client 10: epoch_accuracy 32.36, epoch_loss 1.8705861870246598
#
#
#
#  Model's Round: 7, train accuracy of model: 32.410000000000004, train loss of model: 1.8765051622933977
# round 7 = flri 0
# Model's Round: 7, test accuracy of model: 31.230031948881788, test loss of model: 2.443577828498694
# round 7 completed
#
#
#
#  Round 8, client 1: epoch_accuracy 35.2, epoch_loss 1.8163985104500493
#
#
#  Round 8, client 2: epoch_accuracy 34.74, epoch_loss 1.8253016954735866
#
#
#  Round 8, client 3: epoch_accuracy 34.22, epoch_loss 1.8265154286275935
#
#
#  Round 8, client 4: epoch_accuracy 35.08, epoch_loss 1.815569953073429
#
#
#  Round 8, client 5: epoch_accuracy 35.34, epoch_loss 1.818176178992549
#
#
#  Round 8, client 6: epoch_accuracy 34.76, epoch_loss 1.8291115670264522
#
#
#  Round 8, client 7: epoch_accuracy 35.4, epoch_loss 1.8023166928110244
#
#
#  Round 8, client 8: epoch_accuracy 34.24, epoch_loss 1.8350086393235605
#
#
#  Round 8, client 9: epoch_accuracy 35.08, epoch_loss 1.8214801987515221
#
#
#  Round 8, client 10: epoch_accuracy 34.88, epoch_loss 1.8243959734711466
#
#
#
#  Model's Round: 8, train accuracy of model: 34.894, train loss of model: 1.8214274838000915
# round 8 = flri 0
# Model's Round: 8, test accuracy of model: 32.897364217252395, test loss of model: 2.5240189667326955
# round 8 completed
#
#
#
#  Round 9, client 1: epoch_accuracy 36.1, epoch_loss 1.7722599008415318
#
#
#  Round 9, client 2: epoch_accuracy 36.66, epoch_loss 1.7744553572014918
#
#
#  Round 9, client 3: epoch_accuracy 37.46, epoch_loss 1.760030378269244
#
#
#  Round 9, client 4: epoch_accuracy 36.3, epoch_loss 1.7611265469201003
#
#
#  Round 9, client 5: epoch_accuracy 36.78, epoch_loss 1.7829350202898435
#
#
#  Round 9, client 6: epoch_accuracy 36.96, epoch_loss 1.7931698756881906
#
#
#  Round 9, client 7: epoch_accuracy 36.72, epoch_loss 1.7652941097187091
#
#
#  Round 9, client 8: epoch_accuracy 35.14, epoch_loss 1.7989522445050976
#
#
#  Round 9, client 9: epoch_accuracy 36.3, epoch_loss 1.7836904661564887
#
#
#  Round 9, client 10: epoch_accuracy 36.06, epoch_loss 1.783303452443473
#
#
#
#  Model's Round: 9, train accuracy of model: 36.448, train loss of model: 1.7775217352034172
# round 9 = flri 0
# Model's Round: 9, test accuracy of model: 33.13698083067093, test loss of model: 2.547233821104129
# round 9 completed
#
#
#
#  Round 10, client 1: epoch_accuracy 38.32, epoch_loss 1.7235345267042328
#
#
#  Round 10, client 2: epoch_accuracy 38.78, epoch_loss 1.7377231241781501
#
#
#  Round 10, client 3: epoch_accuracy 38.58, epoch_loss 1.7202413293379772
#
#
#  Round 10, client 4: epoch_accuracy 38.34, epoch_loss 1.7223187292678446
#
#
#  Round 10, client 5: epoch_accuracy 38.12, epoch_loss 1.7314219761498366
#
#
#  Round 10, client 6: epoch_accuracy 38.42, epoch_loss 1.740616218953193
#
#
#  Round 10, client 7: epoch_accuracy 38.44, epoch_loss 1.7278113123736805
#
#
#  Round 10, client 8: epoch_accuracy 37.2, epoch_loss 1.7441754537292673
#
#
#  Round 10, client 9: epoch_accuracy 38.04, epoch_loss 1.7453239401684533
#
#
#  Round 10, client 10: epoch_accuracy 37.28, epoch_loss 1.750150727320321
#
#
#
#  Model's Round: 10, train accuracy of model: 38.152, train loss of model: 1.7343317338182955
# round 10 = flri 0
# Model's Round: 10, test accuracy of model: 32.68769968051118, test loss of model: 2.610539045577613
# round 10 completed
#
#
#
#  Round 11, client 1: epoch_accuracy 39.02, epoch_loss 1.6939773966994467
#
#
#  Round 11, client 2: epoch_accuracy 39.02, epoch_loss 1.7014620696442038
#
#
#  Round 11, client 3: epoch_accuracy 38.96, epoch_loss 1.6876136577582057
#
#
#  Round 11, client 4: epoch_accuracy 39.26, epoch_loss 1.682570219039917
#
#
#  Round 11, client 5: epoch_accuracy 39.44, epoch_loss 1.6991086715384374
#
#
#  Round 11, client 6: epoch_accuracy 39.32, epoch_loss 1.6996478098857253
#
#
#  Round 11, client 7: epoch_accuracy 38.68, epoch_loss 1.684398863888994
#
#
#  Round 11, client 8: epoch_accuracy 38.8, epoch_loss 1.7089679437347605
#
#
#  Round 11, client 9: epoch_accuracy 39.82, epoch_loss 1.7018545051164264
#
#
#  Round 11, client 10: epoch_accuracy 38.88, epoch_loss 1.687276944329467
#
#
#
#  Model's Round: 11, train accuracy of model: 39.12, train loss of model: 1.6946878081635586
# round 11 = flri 0
# Model's Round: 11, test accuracy of model: 29.652555910543132, test loss of model: 2.9373535165390647
# round 11 completed
#
#
#
#  Round 12, client 1: epoch_accuracy 39.52, epoch_loss 1.6688561017000223
#
#
#  Round 12, client 2: epoch_accuracy 39.82, epoch_loss 1.665303430979765
#
#
#  Round 12, client 3: epoch_accuracy 39.9, epoch_loss 1.6570862078968482
#
#
#  Round 12, client 4: epoch_accuracy 40.32, epoch_loss 1.662762869762469
#
#
#  Round 12, client 5: epoch_accuracy 40.98, epoch_loss 1.6605340514001967
#
#
#  Round 12, client 6: epoch_accuracy 41.3, epoch_loss 1.6483465478390078
#
#
#  Round 12, client 7: epoch_accuracy 40.52, epoch_loss 1.6486464799204958
#
#
#  Round 12, client 8: epoch_accuracy 39.86, epoch_loss 1.677828796302216
#
#
#  Round 12, client 9: epoch_accuracy 40.98, epoch_loss 1.6627024789399738
#
#
#  Round 12, client 10: epoch_accuracy 40.56, epoch_loss 1.6599706426451477
#
#
#
#  Model's Round: 12, train accuracy of model: 40.376, train loss of model: 1.6612037607386143
# round 12 = flri 0
# Model's Round: 12, test accuracy of model: 27.156549520766774, test loss of model: 3.1872349227198398
# round 12 completed
#
#
#
#  Round 13, client 1: epoch_accuracy 41.12, epoch_loss 1.6325523792942869
#
#
#  Round 13, client 2: epoch_accuracy 43.0, epoch_loss 1.6086200143717513
#
#
#  Round 13, client 3: epoch_accuracy 42.24, epoch_loss 1.6189517748506763
#
#
#  Round 13, client 4: epoch_accuracy 41.26, epoch_loss 1.6284491849851004
#
#
#  Round 13, client 5: epoch_accuracy 41.8, epoch_loss 1.6308430870877038
#
#
#  Round 13, client 6: epoch_accuracy 41.36, epoch_loss 1.6461975287787523
#
#
#  Round 13, client 7: epoch_accuracy 41.52, epoch_loss 1.604025584232958
#
#
#  Round 13, client 8: epoch_accuracy 41.28, epoch_loss 1.643323999416979
#
#
#  Round 13, client 9: epoch_accuracy 42.24, epoch_loss 1.6186758943750887
#
#
#  Round 13, client 10: epoch_accuracy 40.9, epoch_loss 1.6119121071658558
#
#
#
#  Model's Round: 13, train accuracy of model: 41.672000000000004, train loss of model: 1.624355155455915
# round 13 = flri 0
# Model's Round: 13, test accuracy of model: 26.85702875399361, test loss of model: 3.2958719006742534
# round 13 completed
#
#
#
#  Round 14, client 1: epoch_accuracy 42.62, epoch_loss 1.6091195601451247
#
#
#  Round 14, client 2: epoch_accuracy 43.5, epoch_loss 1.5823450586463832
#
#
#  Round 14, client 3: epoch_accuracy 42.72, epoch_loss 1.574603480628774
#
#
#  Round 14, client 4: epoch_accuracy 41.74, epoch_loss 1.5905198492581332
#
#
#  Round 14, client 5: epoch_accuracy 42.24, epoch_loss 1.5845317191715482
#
#
#  Round 14, client 6: epoch_accuracy 42.68, epoch_loss 1.5917632006391693
#
#
#  Round 14, client 7: epoch_accuracy 42.76, epoch_loss 1.5831911322436756
#
#
#  Round 14, client 8: epoch_accuracy 41.62, epoch_loss 1.60897141317778
#
#
#  Round 14, client 9: epoch_accuracy 43.04, epoch_loss 1.60843092429487
#
#
#  Round 14, client 10: epoch_accuracy 41.52, epoch_loss 1.6018845039077951
#
#
#
#  Model's Round: 14, train accuracy of model: 42.444, train loss of model: 1.5935360842113253
# round 14 = flri 0
# Model's Round: 14, test accuracy of model: 26.63738019169329, test loss of model: 3.7018807254279382
# round 14 completed
#
#
#
#  Round 15, client 1: epoch_accuracy 43.92, epoch_loss 1.5661587700059143
#
#
#  Round 15, client 2: epoch_accuracy 43.94, epoch_loss 1.54200509077386
#
#
#  Round 15, client 3: epoch_accuracy 43.96, epoch_loss 1.5635325561595868
#
#
#  Round 15, client 4: epoch_accuracy 42.68, epoch_loss 1.5640853145454503
#
#
#  Round 15, client 5: epoch_accuracy 44.04, epoch_loss 1.5676266965986807
#
#
#  Round 15, client 6: epoch_accuracy 43.86, epoch_loss 1.5695878916148898
#
#
#  Round 15, client 7: epoch_accuracy 44.96, epoch_loss 1.5321924475174915
#
#
#  Round 15, client 8: epoch_accuracy 42.42, epoch_loss 1.5773201305654985
#
#
#  Round 15, client 9: epoch_accuracy 44.38, epoch_loss 1.5546355730370631
#
#
#  Round 15, client 10: epoch_accuracy 42.52, epoch_loss 1.5709658483915692
#
#
#
#  Model's Round: 15, train accuracy of model: 43.66799999999999, train loss of model: 1.5608110319210005
# round 15 = flri 0
# Model's Round: 15, test accuracy of model: 26.108226837060702, test loss of model: 4.1181828754778484
# round 15 completed
#
#
#
#  Round 16, client 1: epoch_accuracy 44.12, epoch_loss 1.5511505815047253
#
#
#  Round 16, client 2: epoch_accuracy 44.76, epoch_loss 1.5339002669612063
#
#
#  Round 16, client 3: epoch_accuracy 45.44, epoch_loss 1.538955189004729
#
#
#  Round 16, client 4: epoch_accuracy 44.36, epoch_loss 1.5328664025173913
#
#
#  Round 16, client 5: epoch_accuracy 45.2, epoch_loss 1.526426162900804
#
#
#  Round 16, client 6: epoch_accuracy 44.54, epoch_loss 1.5583059697211543
#
#
#  Round 16, client 7: epoch_accuracy 45.06, epoch_loss 1.5145416772818263
#
#
#  Round 16, client 8: epoch_accuracy 43.34, epoch_loss 1.556516383267656
#
#
#  Round 16, client 9: epoch_accuracy 44.5, epoch_loss 1.541953470133528
#
#
#  Round 16, client 10: epoch_accuracy 44.8, epoch_loss 1.5296525940110413
#
#
#
#  Model's Round: 16, train accuracy of model: 44.61200000000001, train loss of model: 1.5384268697304062
# round 16 = flri 0
# Model's Round: 16, test accuracy of model: 26.807108626198083, test loss of model: 4.225742755987393
# round 16 completed
#
#
#
#  Round 17, client 1: epoch_accuracy 45.44, epoch_loss 1.5130749835243709
#
#
#  Round 17, client 2: epoch_accuracy 46.28, epoch_loss 1.5078143741511092
#
#
#  Round 17, client 3: epoch_accuracy 45.6, epoch_loss 1.5201716423034668
#
#
#  Round 17, client 4: epoch_accuracy 44.9, epoch_loss 1.5097313681735267
#
#
#  Round 17, client 5: epoch_accuracy 45.42, epoch_loss 1.5056108009966114
#
#
#  Round 17, client 6: epoch_accuracy 45.26, epoch_loss 1.5280076370963567
#
#
#  Round 17, client 7: epoch_accuracy 46.16, epoch_loss 1.491765026804767
#
#
#  Round 17, client 8: epoch_accuracy 44.3, epoch_loss 1.5303579553773132
#
#
#  Round 17, client 9: epoch_accuracy 45.26, epoch_loss 1.526943810378449
#
#
#  Round 17, client 10: epoch_accuracy 44.8, epoch_loss 1.5170620604406428
#
#
#
#  Model's Round: 17, train accuracy of model: 45.342, train loss of model: 1.5150539659246616
# round 17 = flri 0
# Model's Round: 17, test accuracy of model: 25.86861022364217, test loss of model: 4.733941274709975
# round 17 completed
#
#
#
#  Round 18, client 1: epoch_accuracy 45.48, epoch_loss 1.4957727872872655
#
#
#  Round 18, client 2: epoch_accuracy 46.68, epoch_loss 1.4784243544445763
#
#
#  Round 18, client 3: epoch_accuracy 46.54, epoch_loss 1.4870490544958959
#
#
#  Round 18, client 4: epoch_accuracy 46.5, epoch_loss 1.4810644056223616
#
#
#  Round 18, client 5: epoch_accuracy 46.2, epoch_loss 1.4991069715234298
#
#
#  Round 18, client 6: epoch_accuracy 46.7, epoch_loss 1.4956049707871448
#
#
#  Round 18, client 7: epoch_accuracy 46.72, epoch_loss 1.458823946457875
#
#
#  Round 18, client 8: epoch_accuracy 46.4, epoch_loss 1.505914392350595
#
#
#  Round 18, client 9: epoch_accuracy 46.1, epoch_loss 1.4882341668575625
#
#
#  Round 18, client 10: epoch_accuracy 46.26, epoch_loss 1.4869378850429873
#
#
#
#  Model's Round: 18, train accuracy of model: 46.35799999999999, train loss of model: 1.4876932934869693
# round 18 = flri 0
# Model's Round: 18, test accuracy of model: 25.289536741214057, test loss of model: 5.145525456236574
# round 18 completed
#
#
#
#  Round 19, client 1: epoch_accuracy 46.64, epoch_loss 1.4795504265193697
#
#
#  Round 19, client 2: epoch_accuracy 48.1, epoch_loss 1.4626651730718492
#
#
#  Round 19, client 3: epoch_accuracy 47.58, epoch_loss 1.4706165684929378
#
#
#  Round 19, client 4: epoch_accuracy 46.96, epoch_loss 1.4702391398103931
#
#
#  Round 19, client 5: epoch_accuracy 47.36, epoch_loss 1.476119850255266
#
#
#  Round 19, client 6: epoch_accuracy 47.52, epoch_loss 1.4701760117011735
#
#
#  Round 19, client 7: epoch_accuracy 47.76, epoch_loss 1.4416049899934213
#
#
#  Round 19, client 8: epoch_accuracy 47.16, epoch_loss 1.4747644481779654
#
#
#  Round 19, client 9: epoch_accuracy 47.18, epoch_loss 1.4780913410307486
#
#
#  Round 19, client 10: epoch_accuracy 46.82, epoch_loss 1.4794503661650646
#
#
#
#  Model's Round: 19, train accuracy of model: 47.30799999999999, train loss of model: 1.4703278315218185
# round 19 = flri 0
# Model's Round: 19, test accuracy of model: 26.15814696485623, test loss of model: 4.991107024323826
# round 19 completed
#
#
#
#  Round 20, client 1: epoch_accuracy 47.62, epoch_loss 1.447790862638739
#
#
#  Round 20, client 2: epoch_accuracy 48.6, epoch_loss 1.4388329846949517
#
#
#  Round 20, client 3: epoch_accuracy 48.46, epoch_loss 1.4486042019687122
#
#
#  Round 20, client 4: epoch_accuracy 48.0, epoch_loss 1.445774897744384
#
#
#  Round 20, client 5: epoch_accuracy 48.44, epoch_loss 1.4367902580695817
#
#
#  Round 20, client 6: epoch_accuracy 47.88, epoch_loss 1.4516840569580658
#
#
#  Round 20, client 7: epoch_accuracy 47.84, epoch_loss 1.4287272088135345
#
#
#  Round 20, client 8: epoch_accuracy 48.08, epoch_loss 1.4489889944655985
#
#
#  Round 20, client 9: epoch_accuracy 48.82, epoch_loss 1.4282659050784534
#
#
#  Round 20, client 10: epoch_accuracy 47.52, epoch_loss 1.4532809981816932
#
#
#
#  Model's Round: 20, train accuracy of model: 48.126, train loss of model: 1.442874036861371
# round 20 = flri 0
# Model's Round: 20, test accuracy of model: 26.797124600638977, test loss of model: 5.009060076631296
# round 20 completed
#
#
#
#  Round 21, client 1: epoch_accuracy 48.64, epoch_loss 1.4319787206529062
#
#
#  Round 21, client 2: epoch_accuracy 50.56, epoch_loss 1.405851964709125
#
#
#  Round 21, client 3: epoch_accuracy 48.66, epoch_loss 1.4223872242094595
#
#
#  Round 21, client 4: epoch_accuracy 48.28, epoch_loss 1.4323751639716233
#
#
#  Round 21, client 5: epoch_accuracy 48.92, epoch_loss 1.4206518704378153
#
#
#  Round 21, client 6: epoch_accuracy 49.18, epoch_loss 1.4416064929358567
#
#
#  Round 21, client 7: epoch_accuracy 49.84, epoch_loss 1.3864701299727717
#
#
#  Round 21, client 8: epoch_accuracy 48.52, epoch_loss 1.424772837493993
#
#
#  Round 21, client 9: epoch_accuracy 48.7, epoch_loss 1.4240769947631449
#
#
#  Round 21, client 10: epoch_accuracy 48.7, epoch_loss 1.4127675053439563
#
#
#
#  Model's Round: 21, train accuracy of model: 49.0, train loss of model: 1.4202938904490652
# round 21 = flri 0
# Model's Round: 21, test accuracy of model: 25.10982428115016, test loss of model: 5.423461046462623
# round 21 completed
#
#
#
#  Round 22, client 1: epoch_accuracy 49.4, epoch_loss 1.399532346785823
#
#
#  Round 22, client 2: epoch_accuracy 50.64, epoch_loss 1.3852907796449299
#
#
#  Round 22, client 3: epoch_accuracy 49.24, epoch_loss 1.4132066648217696
#
#
#  Round 22, client 4: epoch_accuracy 49.58, epoch_loss 1.4002098561842231
#
#
#  Round 22, client 5: epoch_accuracy 49.9, epoch_loss 1.3962478516977044
#
#
#  Round 22, client 6: epoch_accuracy 48.92, epoch_loss 1.4050547291960898
#
#
#  Round 22, client 7: epoch_accuracy 49.7, epoch_loss 1.3876426069042351
#
#
#  Round 22, client 8: epoch_accuracy 48.92, epoch_loss 1.4123170028758953
#
#
#  Round 22, client 9: epoch_accuracy 49.34, epoch_loss 1.4100892860678178
#
#
#  Round 22, client 10: epoch_accuracy 48.58, epoch_loss 1.41668798953672
#
#
#
#  Model's Round: 22, train accuracy of model: 49.422, train loss of model: 1.4026279113715208
# round 22 = flri 0
# Model's Round: 22, test accuracy of model: 25.169728434504794, test loss of model: 5.762217478249401
# round 22 completed
#
#
#
#  Round 23, client 1: epoch_accuracy 50.46, epoch_loss 1.3850769936283933
#
#
#  Round 23, client 2: epoch_accuracy 51.36, epoch_loss 1.372872462755517
#
#
#  Round 23, client 3: epoch_accuracy 48.56, epoch_loss 1.401060116441944
#
#
#  Round 23, client 4: epoch_accuracy 50.46, epoch_loss 1.379778478719011
#
#
#  Round 23, client 5: epoch_accuracy 50.1, epoch_loss 1.3728324310689033
#
#
#  Round 23, client 6: epoch_accuracy 50.24, epoch_loss 1.393189173710497
#
#
#  Round 23, client 7: epoch_accuracy 49.84, epoch_loss 1.3588287241851227
#
#
#  Round 23, client 8: epoch_accuracy 50.1, epoch_loss 1.4032779600046859
#
#
#  Round 23, client 9: epoch_accuracy 49.96, epoch_loss 1.3944467336316653
#
#
#  Round 23, client 10: epoch_accuracy 49.66, epoch_loss 1.382980903492698
#
#
#
#  Model's Round: 23, train accuracy of model: 50.074, train loss of model: 1.384434397763844
# round 23 = flri 0
# Model's Round: 23, test accuracy of model: 24.96006389776358, test loss of model: 5.912470920398213
# round 23 completed
#
#
#
#  Round 24, client 1: epoch_accuracy 51.84, epoch_loss 1.3523599739316143
#
#
#  Round 24, client 2: epoch_accuracy 52.04, epoch_loss 1.3522851059708414
#
#
#  Round 24, client 3: epoch_accuracy 51.44, epoch_loss 1.36603075643129
#
#
#  Round 24, client 4: epoch_accuracy 50.96, epoch_loss 1.3670419379125667
#
#
#  Round 24, client 5: epoch_accuracy 51.18, epoch_loss 1.3840137523940848
#
#
#  Round 24, client 6: epoch_accuracy 51.06, epoch_loss 1.375987540317487
#
#
#  Round 24, client 7: epoch_accuracy 51.64, epoch_loss 1.3527033811883082
#
#
#  Round 24, client 8: epoch_accuracy 51.1, epoch_loss 1.3771468325506282
#
#
#  Round 24, client 9: epoch_accuracy 51.5, epoch_loss 1.3623828299437897
#
#
#  Round 24, client 10: epoch_accuracy 50.2, epoch_loss 1.371067062208924
#
#
#
#  Model's Round: 24, train accuracy of model: 51.29600000000001, train loss of model: 1.3661019172849533
# round 24 = flri 0
# Model's Round: 24, test accuracy of model: 26.4676517571885, test loss of model: 5.962575835541795
# round 24 completed
#
#
#
#  Round 25, client 1: epoch_accuracy 51.86, epoch_loss 1.3576085054421727
#
#
#  Round 25, client 2: epoch_accuracy 52.54, epoch_loss 1.3304828224302847
#
#
#  Round 25, client 3: epoch_accuracy 51.14, epoch_loss 1.3494222330141672
#
#
#  Round 25, client 4: epoch_accuracy 51.58, epoch_loss 1.3463930781883529
#
#
#  Round 25, client 5: epoch_accuracy 51.42, epoch_loss 1.3468259814419323
#
#
#  Round 25, client 6: epoch_accuracy 51.64, epoch_loss 1.3574047118802615
#
#
#  Round 25, client 7: epoch_accuracy 51.62, epoch_loss 1.3299796973602682
#
#
#  Round 25, client 8: epoch_accuracy 51.88, epoch_loss 1.3545994758605957
#
#
#  Round 25, client 9: epoch_accuracy 52.06, epoch_loss 1.3433765180503265
#
#
#  Round 25, client 10: epoch_accuracy 51.7, epoch_loss 1.3565311688411086
#
#
#
#  Model's Round: 25, train accuracy of model: 51.74400000000001, train loss of model: 1.347262419250947
# round 25 = flri 0
# Model's Round: 25, test accuracy of model: 27.2064696485623, test loss of model: 5.768499383530297
# round 25 completed
#
#
#
#  Round 26, client 1: epoch_accuracy 51.3, epoch_loss 1.3352824660796154
#
#
#  Round 26, client 2: epoch_accuracy 53.62, epoch_loss 1.307482582104357
#
#
#  Round 26, client 3: epoch_accuracy 52.34, epoch_loss 1.3320575258399867
#
#
#  Round 26, client 4: epoch_accuracy 53.0, epoch_loss 1.3155707935743695
#
#
#  Round 26, client 5: epoch_accuracy 53.02, epoch_loss 1.3171659768382205
#
#
#  Round 26, client 6: epoch_accuracy 52.48, epoch_loss 1.321497428266308
#
#
#  Round 26, client 7: epoch_accuracy 53.38, epoch_loss 1.3093292169933077
#
#
#  Round 26, client 8: epoch_accuracy 52.74, epoch_loss 1.3196943198578268
#
#
#  Round 26, client 9: epoch_accuracy 52.32, epoch_loss 1.3122938222522977
#
#
#  Round 26, client 10: epoch_accuracy 52.6, epoch_loss 1.3275917798657961
#
#
#
#  Model's Round: 26, train accuracy of model: 52.67999999999999, train loss of model: 1.3197965911672087
# round 26 = flri 0
# Model's Round: 26, test accuracy of model: 25.9185303514377, test loss of model: 6.096594752595067
# round 26 completed
#
#
#
#  Round 27, client 1: epoch_accuracy 53.24, epoch_loss 1.3061184279526337
#
#
#  Round 27, client 2: epoch_accuracy 54.14, epoch_loss 1.2980132465121113
#
#
#  Round 27, client 3: epoch_accuracy 52.68, epoch_loss 1.3092679328556303
#
#
#  Round 27, client 4: epoch_accuracy 51.34, epoch_loss 1.3321417607838595
#
#
#  Round 27, client 5: epoch_accuracy 53.5, epoch_loss 1.301118233535863
#
#
#  Round 27, client 6: epoch_accuracy 53.52, epoch_loss 1.309416171870654
#
#
#  Round 27, client 7: epoch_accuracy 53.4, epoch_loss 1.2756194562851628
#
#
#  Round 27, client 8: epoch_accuracy 52.24, epoch_loss 1.3168912099886545
#
#
#  Round 27, client 9: epoch_accuracy 53.44, epoch_loss 1.3124143156824233
#
#
#  Round 27, client 10: epoch_accuracy 52.54, epoch_loss 1.3011582765398146
#
#
#
#  Model's Round: 27, train accuracy of model: 53.004, train loss of model: 1.3062159032006806
# round 27 = flri 0
# Model's Round: 27, test accuracy of model: 26.15814696485623, test loss of model: 6.190203909675915
# round 27 completed
#
#
#
#  Round 28, client 1: epoch_accuracy 54.26, epoch_loss 1.2904459222962585
#
#
#  Round 28, client 2: epoch_accuracy 54.6, epoch_loss 1.2597858800163753
#
#
#  Round 28, client 3: epoch_accuracy 53.5, epoch_loss 1.29937427028825
#
#
#  Round 28, client 4: epoch_accuracy 53.56, epoch_loss 1.2857244512702846
#
#
#  Round 28, client 5: epoch_accuracy 53.96, epoch_loss 1.2824432585812822
#
#
#  Round 28, client 6: epoch_accuracy 54.06, epoch_loss 1.2760728748538825
#
#
#  Round 28, client 7: epoch_accuracy 55.48, epoch_loss 1.2595817258086386
#
#
#  Round 28, client 8: epoch_accuracy 54.4, epoch_loss 1.2680879703050927
#
#
#  Round 28, client 9: epoch_accuracy 52.92, epoch_loss 1.2900077421453935
#
#
#  Round 28, client 10: epoch_accuracy 53.56, epoch_loss 1.2936578045917462
#
#
#
#  Model's Round: 28, train accuracy of model: 54.029999999999994, train loss of model: 1.2805181900157203
# round 28 = flri 0
# Model's Round: 28, test accuracy of model: 28.4944089456869, test loss of model: 5.885348342858945
# round 28 completed
#
#
#
#  Round 29, client 1: epoch_accuracy 53.16, epoch_loss 1.272373231905925
#
#
#  Round 29, client 2: epoch_accuracy 55.26, epoch_loss 1.247907480107078
#
#
#  Round 29, client 3: epoch_accuracy 54.44, epoch_loss 1.269240500051764
#
#
#  Round 29, client 4: epoch_accuracy 54.38, epoch_loss 1.2698277069043509
#
#
#  Round 29, client 5: epoch_accuracy 55.7, epoch_loss 1.2433712889876547
#
#
#  Round 29, client 6: epoch_accuracy 54.72, epoch_loss 1.2643984744820413
#
#
#  Round 29, client 7: epoch_accuracy 54.9, epoch_loss 1.248762206186222
#
#
#  Round 29, client 8: epoch_accuracy 54.58, epoch_loss 1.2678354525867896
#
#
#  Round 29, client 9: epoch_accuracy 54.08, epoch_loss 1.2723415426061124
#
#
#  Round 29, client 10: epoch_accuracy 54.66, epoch_loss 1.2593820789192296
#
#
#
#  Model's Round: 29, train accuracy of model: 54.58799999999999, train loss of model: 1.2615439962737165
# round 29 = flri 0
# Model's Round: 29, test accuracy of model: 27.705670926517573, test loss of model: 6.285328181026081
# round 29 completed
#
#
#
#  Round 30, client 1: epoch_accuracy 54.9, epoch_loss 1.2609798214103602
#
#
#  Round 30, client 2: epoch_accuracy 56.06, epoch_loss 1.2243807255467283
#
#
#  Round 30, client 3: epoch_accuracy 54.76, epoch_loss 1.2534654502627216
#
#
#  Round 30, client 4: epoch_accuracy 55.6, epoch_loss 1.255459020409403
#
#
#  Round 30, client 5: epoch_accuracy 55.44, epoch_loss 1.2378964559941352
#
#
#  Round 30, client 6: epoch_accuracy 56.48, epoch_loss 1.2489611642270149
#
#
#  Round 30, client 7: epoch_accuracy 56.28, epoch_loss 1.2248435971103138
#
#
#  Round 30, client 8: epoch_accuracy 54.98, epoch_loss 1.228366030922419
#
#
#  Round 30, client 9: epoch_accuracy 55.94, epoch_loss 1.2386039857622944
#
#
#  Round 30, client 10: epoch_accuracy 54.72, epoch_loss 1.2494995541210416
#
#
#
#  Model's Round: 30, train accuracy of model: 55.516, train loss of model: 1.2422455805766432
# round 30 = flri 0
# Model's Round: 30, test accuracy of model: 24.710463258785943, test loss of model: 6.749506884870438
# round 30 completed
#
#
#
#  Round 31, client 1: epoch_accuracy 56.48, epoch_loss 1.2072352872619145
#
#
#  Round 31, client 2: epoch_accuracy 56.68, epoch_loss 1.2061754201031938
#
#
#  Round 31, client 3: epoch_accuracy 56.08, epoch_loss 1.225565479526037
#
#
#  Round 31, client 4: epoch_accuracy 56.32, epoch_loss 1.2157514857340463
#
#
#  Round 31, client 5: epoch_accuracy 57.28, epoch_loss 1.2172912366782562
#
#
#  Round 31, client 6: epoch_accuracy 55.76, epoch_loss 1.2340210442301593
#
#
#  Round 31, client 7: epoch_accuracy 57.42, epoch_loss 1.1966701512095295
#
#
#  Round 31, client 8: epoch_accuracy 56.62, epoch_loss 1.216978448855726
#
#
#  Round 31, client 9: epoch_accuracy 56.7, epoch_loss 1.2159216698211959
#
#
#  Round 31, client 10: epoch_accuracy 55.86, epoch_loss 1.2257056824768646
#
#
#
#  Model's Round: 31, train accuracy of model: 56.52, train loss of model: 1.2161315905896923
# round 31 = flri 0
# Model's Round: 31, test accuracy of model: 28.704073482428115, test loss of model: 6.2569744647882235
# round 31 completed
#
#
#
#  Round 32, client 1: epoch_accuracy 56.76, epoch_loss 1.206905116763296
#
#
#  Round 32, client 2: epoch_accuracy 57.5, epoch_loss 1.1838521180273611
#
#
#  Round 32, client 3: epoch_accuracy 57.16, epoch_loss 1.1965743009048173
#
#
#  Round 32, client 4: epoch_accuracy 56.98, epoch_loss 1.1995201299462137
#
#
#  Round 32, client 5: epoch_accuracy 57.1, epoch_loss 1.1913481980939455
#
#
#  Round 32, client 6: epoch_accuracy 57.26, epoch_loss 1.2053582932375655
#
#
#  Round 32, client 7: epoch_accuracy 58.5, epoch_loss 1.1729199335544924
#
#
#  Round 32, client 8: epoch_accuracy 56.7, epoch_loss 1.2192350294016585
#
#
#  Round 32, client 9: epoch_accuracy 56.9, epoch_loss 1.2128926696656626
#
#
#  Round 32, client 10: epoch_accuracy 56.0, epoch_loss 1.2223703906505923
#
#
#
#  Model's Round: 32, train accuracy of model: 57.086, train loss of model: 1.2010976180245607
# round 32 = flri 0
# Model's Round: 32, test accuracy of model: 28.744009584664536, test loss of model: 6.241115317177087
# round 32 completed
#
#
#
#  Round 33, client 1: epoch_accuracy 58.28, epoch_loss 1.183156911330887
#
#
#  Round 33, client 2: epoch_accuracy 57.94, epoch_loss 1.176513182966015
#
#
#  Round 33, client 3: epoch_accuracy 57.4, epoch_loss 1.1718386992623535
#
#
#  Round 33, client 4: epoch_accuracy 57.9, epoch_loss 1.1934878803506683
#
#
#  Round 33, client 5: epoch_accuracy 57.92, epoch_loss 1.1815951474105255
#
#
#  Round 33, client 6: epoch_accuracy 57.34, epoch_loss 1.1817945204203641
#
#
#  Round 33, client 7: epoch_accuracy 57.6, epoch_loss 1.1814650085907947
#
#
#  Round 33, client 8: epoch_accuracy 58.36, epoch_loss 1.1680536511578137
#
#
#  Round 33, client 9: epoch_accuracy 57.66, epoch_loss 1.1926954184906393
#
#
#  Round 33, client 10: epoch_accuracy 56.98, epoch_loss 1.1934535103508188
#
#
#
#  Model's Round: 33, train accuracy of model: 57.738, train loss of model: 1.1824053930330882
# round 33 = flri 0
# Model's Round: 33, test accuracy of model: 28.793929712460063, test loss of model: 6.3883914787548415
# round 33 completed
#
#
#
#  Round 34, client 1: epoch_accuracy 58.46, epoch_loss 1.165993514694745
#
#
#  Round 34, client 2: epoch_accuracy 58.82, epoch_loss 1.164451985419551
#
#
#  Round 34, client 3: epoch_accuracy 58.16, epoch_loss 1.172931748854963
#
#
#  Round 34, client 4: epoch_accuracy 58.52, epoch_loss 1.1633482960206043
#
#
#  Round 34, client 5: epoch_accuracy 59.68, epoch_loss 1.1452003672153135
#
#
#  Round 34, client 6: epoch_accuracy 58.72, epoch_loss 1.1609419169305246
#
#
#  Round 34, client 7: epoch_accuracy 59.0, epoch_loss 1.1492536045327972
#
#
#  Round 34, client 8: epoch_accuracy 58.54, epoch_loss 1.1502127783207954
#
#
#  Round 34, client 9: epoch_accuracy 58.1, epoch_loss 1.1558958752245843
#
#
#  Round 34, client 10: epoch_accuracy 57.8, epoch_loss 1.1628647009028663
#
#
#
#  Model's Round: 34, train accuracy of model: 58.58, train loss of model: 1.1591094788116745
# round 34 = flri 0
# Model's Round: 34, test accuracy of model: 29.52276357827476, test loss of model: 6.453908535619132
# round 34 completed
#
#
#
#  Round 35, client 1: epoch_accuracy 58.62, epoch_loss 1.1327656839467302
#
#
#  Round 35, client 2: epoch_accuracy 59.92, epoch_loss 1.1295670165291316
#
#
#  Round 35, client 3: epoch_accuracy 58.18, epoch_loss 1.1428339383270167
#
#
#  Round 35, client 4: epoch_accuracy 59.44, epoch_loss 1.1479156100297276
#
#
#  Round 35, client 5: epoch_accuracy 59.1, epoch_loss 1.1375881629654123
#
#
#  Round 35, client 6: epoch_accuracy 59.68, epoch_loss 1.1398889897744866
#
#
#  Round 35, client 7: epoch_accuracy 59.06, epoch_loss 1.1340325044680246
#
#
#  Round 35, client 8: epoch_accuracy 59.68, epoch_loss 1.1272573297536825
#
#
#  Round 35, client 9: epoch_accuracy 59.34, epoch_loss 1.1371230181259444
#
#
#  Round 35, client 10: epoch_accuracy 59.3, epoch_loss 1.124600761298892
#
#
#
#  Model's Round: 35, train accuracy of model: 59.23199999999999, train loss of model: 1.1353573015219047
# round 35 = flri 0
# Model's Round: 35, test accuracy of model: 29.273162939297123, test loss of model: 6.22049654710788
# round 35 completed
#
#
#
#  Round 36, client 1: epoch_accuracy 60.92, epoch_loss 1.0977807920190352
#
#
#  Round 36, client 2: epoch_accuracy 61.2, epoch_loss 1.1167352599433706
#
#
#  Round 36, client 3: epoch_accuracy 60.2, epoch_loss 1.1093545118464698
#
#
#  Round 36, client 4: epoch_accuracy 60.78, epoch_loss 1.1108461791955972
#
#
#  Round 36, client 5: epoch_accuracy 61.16, epoch_loss 1.1043862504295157
#
#
#  Round 36, client 6: epoch_accuracy 60.68, epoch_loss 1.1117231264899048
#
#
#  Round 36, client 7: epoch_accuracy 59.78, epoch_loss 1.107657660411883
#
#
#  Round 36, client 8: epoch_accuracy 60.26, epoch_loss 1.104672671118869
#
#
#  Round 36, client 9: epoch_accuracy 60.02, epoch_loss 1.1142170414139954
#
#
#  Round 36, client 10: epoch_accuracy 59.32, epoch_loss 1.1286416898799847
#
#
#
#  Model's Round: 36, train accuracy of model: 60.432, train loss of model: 1.1106015182748625
# round 36 = flri 0
# Model's Round: 36, test accuracy of model: 27.505990415335464, test loss of model: 6.932347745560229
# round 36 completed
#
#
#
#  Round 37, client 1: epoch_accuracy 61.84, epoch_loss 1.0929256790800939
#
#
#  Round 37, client 2: epoch_accuracy 61.42, epoch_loss 1.100911081591739
#
#
#  Round 37, client 3: epoch_accuracy 60.3, epoch_loss 1.1123102654384662
#
#
#  Round 37, client 4: epoch_accuracy 61.4, epoch_loss 1.1138048232356204
#
#
#  Round 37, client 5: epoch_accuracy 61.1, epoch_loss 1.0967340839060047
#
#
#  Round 37, client 6: epoch_accuracy 60.52, epoch_loss 1.1056885032714168
#
#
#  Round 37, client 7: epoch_accuracy 60.54, epoch_loss 1.085972859135157
#
#
#  Round 37, client 8: epoch_accuracy 61.44, epoch_loss 1.0901345120200627
#
#
#  Round 37, client 9: epoch_accuracy 61.08, epoch_loss 1.1074093331264545
#
#
#  Round 37, client 10: epoch_accuracy 60.54, epoch_loss 1.1125465065618105
#
#
#
#  Model's Round: 37, train accuracy of model: 61.017999999999994, train loss of model: 1.1018437647366826
# round 37 = flri 0
# Model's Round: 37, test accuracy of model: 27.16653354632588, test loss of model: 6.8566874010494345
# round 37 completed
#
#
#
#  Round 38, client 1: epoch_accuracy 62.16, epoch_loss 1.0714226131197773
#
#
#  Round 38, client 2: epoch_accuracy 62.68, epoch_loss 1.0932917579819885
#
#
#  Round 38, client 3: epoch_accuracy 61.02, epoch_loss 1.0782310155373585
#
#
#  Round 38, client 4: epoch_accuracy 62.16, epoch_loss 1.074753765818439
#
#
#  Round 38, client 5: epoch_accuracy 62.18, epoch_loss 1.0737570569485049
#
#
#  Round 38, client 6: epoch_accuracy 60.78, epoch_loss 1.0918179131761383
#
#
#  Round 38, client 7: epoch_accuracy 62.28, epoch_loss 1.0653789088695864
#
#
#  Round 38, client 8: epoch_accuracy 61.28, epoch_loss 1.080412330506723
#
#
#  Round 38, client 9: epoch_accuracy 61.54, epoch_loss 1.0947473547126674
#
#
#  Round 38, client 10: epoch_accuracy 61.0, epoch_loss 1.0984768075279043
#
#
#
#  Model's Round: 38, train accuracy of model: 61.70799999999999, train loss of model: 1.0822289524199087
# round 38 = flri 0
# Model's Round: 38, test accuracy of model: 30.59105431309904, test loss of model: 6.157305511803672
# round 38 completed
#
#
#
#  Round 39, client 1: epoch_accuracy 61.88, epoch_loss 1.0517425953964643
#
#
#  Round 39, client 2: epoch_accuracy 62.66, epoch_loss 1.0631969986082632
#
#
#  Round 39, client 3: epoch_accuracy 62.28, epoch_loss 1.0632773124718968
#
#
#  Round 39, client 4: epoch_accuracy 62.44, epoch_loss 1.0576076190682906
#
#
#  Round 39, client 5: epoch_accuracy 62.8, epoch_loss 1.0445189815533311
#
#
#  Round 39, client 6: epoch_accuracy 61.58, epoch_loss 1.076292262047152
#
#
#  Round 39, client 7: epoch_accuracy 62.72, epoch_loss 1.0344428465336184
#
#
#  Round 39, client 8: epoch_accuracy 62.66, epoch_loss 1.0610465324377711
#
#
#  Round 39, client 9: epoch_accuracy 62.26, epoch_loss 1.06685217498224
#
#
#  Round 39, client 10: epoch_accuracy 61.74, epoch_loss 1.056585591050643
#
#
#
#  Model's Round: 39, train accuracy of model: 62.302, train loss of model: 1.0575562914149672
# round 39 = flri 0
# Model's Round: 39, test accuracy of model: 32.158546325878596, test loss of model: 5.736147652037989
# round 39 completed
#
#
#
#  Round 40, client 1: epoch_accuracy 63.3, epoch_loss 1.0355498858644991
#
#
#  Round 40, client 2: epoch_accuracy 63.22, epoch_loss 1.0404552938062934
#
#
#  Round 40, client 3: epoch_accuracy 61.72, epoch_loss 1.0646139609662792
#
#
#  Round 40, client 4: epoch_accuracy 62.2, epoch_loss 1.0423041423664818
#
#
#  Round 40, client 5: epoch_accuracy 63.68, epoch_loss 1.0098948482471177
#
#
#  Round 40, client 6: epoch_accuracy 62.34, epoch_loss 1.0486020589176612
#
#
#  Round 40, client 7: epoch_accuracy 63.62, epoch_loss 0.9945488270324997
#
#
#  Round 40, client 8: epoch_accuracy 63.38, epoch_loss 1.035622922680046
#
#
#  Round 40, client 9: epoch_accuracy 62.82, epoch_loss 1.0456497065628632
#
#
#  Round 40, client 10: epoch_accuracy 62.4, epoch_loss 1.039397626738005
#
#
#
#  Model's Round: 40, train accuracy of model: 62.86800000000001, train loss of model: 1.0356639273181745
# round 40 = flri 0
# Model's Round: 40, test accuracy of model: 31.55950479233227, test loss of model: 5.897463982097638
# round 40 completed
#
#
#
#  Round 41, client 1: epoch_accuracy 64.38, epoch_loss 0.9958658173114439
#
#
#  Round 41, client 2: epoch_accuracy 64.6, epoch_loss 1.016017068035995
#
#
#  Round 41, client 3: epoch_accuracy 62.06, epoch_loss 1.038617054872875
#
#
#  Round 41, client 4: epoch_accuracy 62.92, epoch_loss 1.0369187336933763
#
#
#  Round 41, client 5: epoch_accuracy 64.24, epoch_loss 1.0142686714099933
#
#
#  Round 41, client 6: epoch_accuracy 63.32, epoch_loss 1.0393822004523459
#
#
#  Round 41, client 7: epoch_accuracy 64.38, epoch_loss 1.007599924184099
#
#
#  Round 41, client 8: epoch_accuracy 64.16, epoch_loss 1.0124499397941782
#
#
#  Round 41, client 9: epoch_accuracy 63.82, epoch_loss 1.0286773382862913
#
#
#  Round 41, client 10: epoch_accuracy 62.74, epoch_loss 1.0270488624331318
#
#
#
#  Model's Round: 41, train accuracy of model: 63.662, train loss of model: 1.021684561047373
# round 41 = flri 0
# Model's Round: 41, test accuracy of model: 33.89576677316294, test loss of model: 5.553155389456704
# round 41 completed
#
#
#
#  Round 42, client 1: epoch_accuracy 64.44, epoch_loss 0.9997068681294405
#
#
#  Round 42, client 2: epoch_accuracy 64.5, epoch_loss 1.003484280426291
#
#
#  Round 42, client 3: epoch_accuracy 63.08, epoch_loss 1.0194321154039117
#
#
#  Round 42, client 4: epoch_accuracy 63.76, epoch_loss 0.9944255563277232
#
#
#  Round 42, client 5: epoch_accuracy 64.12, epoch_loss 0.9838973570473587
#
#
#  Round 42, client 6: epoch_accuracy 64.08, epoch_loss 1.0075752561605429
#
#
#  Round 42, client 7: epoch_accuracy 64.44, epoch_loss 0.9853808065003986
#
#
#  Round 42, client 8: epoch_accuracy 64.54, epoch_loss 0.9871319268323198
#
#
#  Round 42, client 9: epoch_accuracy 64.08, epoch_loss 1.006998680060423
#
#
#  Round 42, client 10: epoch_accuracy 64.36, epoch_loss 0.999355015875418
#
#
#
#  Model's Round: 42, train accuracy of model: 64.14, train loss of model: 0.9987387862763827
# round 42 = flri 0
# Model's Round: 42, test accuracy of model: 32.57787539936102, test loss of model: 5.942400252857147
# round 42 completed
#
#
#
#  Round 43, client 1: epoch_accuracy 65.34, epoch_loss 0.9778806008870089
#
#
#  Round 43, client 2: epoch_accuracy 64.96, epoch_loss 0.9837161166758477
#
#
#  Round 43, client 3: epoch_accuracy 64.92, epoch_loss 0.9948907471910308
#
#
#  Round 43, client 4: epoch_accuracy 65.14, epoch_loss 0.988445395155798
#
#
#  Round 43, client 5: epoch_accuracy 65.24, epoch_loss 0.9813959915426713
#
#
#  Round 43, client 6: epoch_accuracy 65.26, epoch_loss 0.990752680392205
#
#
#  Round 43, client 7: epoch_accuracy 65.48, epoch_loss 0.9709726617306094
#
#
#  Round 43, client 8: epoch_accuracy 65.06, epoch_loss 0.9624404009384445
#
#
#  Round 43, client 9: epoch_accuracy 64.44, epoch_loss 0.9906881096996839
#
#
#  Round 43, client 10: epoch_accuracy 64.44, epoch_loss 0.9800719452809684
#
#
#
#  Model's Round: 43, train accuracy of model: 65.02800000000002, train loss of model: 0.9821254649494268
# round 43 = flri 0
# Model's Round: 43, test accuracy of model: 32.82747603833866, test loss of model: 5.914682429438582
# round 43 completed
#
#
#
#  Round 44, client 1: epoch_accuracy 66.5, epoch_loss 0.9455601935145221
#
#
#  Round 44, client 2: epoch_accuracy 66.14, epoch_loss 0.9654691868190524
#
#
#  Round 44, client 3: epoch_accuracy 66.04, epoch_loss 0.9490524341788473
#
#
#  Round 44, client 4: epoch_accuracy 66.08, epoch_loss 0.9621964670434783
#
#
#  Round 44, client 5: epoch_accuracy 65.66, epoch_loss 0.9696262282661244
#
#
#  Round 44, client 6: epoch_accuracy 65.98, epoch_loss 0.9604106696346139
#
#
#  Round 44, client 7: epoch_accuracy 65.4, epoch_loss 0.9556595283218577
#
#
#  Round 44, client 8: epoch_accuracy 65.88, epoch_loss 0.9596589652797843
#
#
#  Round 44, client 9: epoch_accuracy 65.2, epoch_loss 0.9798659425747546
#
#
#  Round 44, client 10: epoch_accuracy 65.56, epoch_loss 0.963706214216691
#
#
#
#  Model's Round: 44, train accuracy of model: 65.84400000000001, train loss of model: 0.9611205829849727
# round 44 = flri 0
# Model's Round: 44, test accuracy of model: 33.61621405750799, test loss of model: 5.985096390635823
# round 44 completed
#
#
#
#  Round 45, client 1: epoch_accuracy 67.14, epoch_loss 0.9273323778864704
#
#
#  Round 45, client 2: epoch_accuracy 67.14, epoch_loss 0.9351525163348717
#
#
#  Round 45, client 3: epoch_accuracy 66.08, epoch_loss 0.9414866636448269
#
#
#  Round 45, client 4: epoch_accuracy 65.44, epoch_loss 0.9555881264843519
#
#
#  Round 45, client 5: epoch_accuracy 66.02, epoch_loss 0.9435493123682239
#
#
#  Round 45, client 6: epoch_accuracy 65.96, epoch_loss 0.9408516250079191
#
#
#  Round 45, client 7: epoch_accuracy 67.02, epoch_loss 0.9247760597286345
#
#
#  Round 45, client 8: epoch_accuracy 67.06, epoch_loss 0.926163881639891
#
#
#  Round 45, client 9: epoch_accuracy 66.6, epoch_loss 0.9442067674443692
#
#
#  Round 45, client 10: epoch_accuracy 66.24, epoch_loss 0.9421587752390511
#
#
#
#  Model's Round: 45, train accuracy of model: 66.47, train loss of model: 0.938126610577861
# round 45 = flri 0
# Model's Round: 45, test accuracy of model: 34.135383386581466, test loss of model: 5.8907334035197
# round 45 completed
#
#
#
#  Round 46, client 1: epoch_accuracy 66.98, epoch_loss 0.9216751546799382
#
#
#  Round 46, client 2: epoch_accuracy 66.86, epoch_loss 0.9378735023208812
#
#
#  Round 46, client 3: epoch_accuracy 66.22, epoch_loss 0.9437288000613828
#
#
#  Round 46, client 4: epoch_accuracy 67.86, epoch_loss 0.9241032977647419
#
#
#  Round 46, client 5: epoch_accuracy 67.32, epoch_loss 0.9039462184226965
#
#
#  Round 46, client 6: epoch_accuracy 66.12, epoch_loss 0.9384570536734183
#
#
#  Round 46, client 7: epoch_accuracy 66.78, epoch_loss 0.9324481260927417
#
#
#  Round 46, client 8: epoch_accuracy 67.3, epoch_loss 0.9178600050980532
#
#
#  Round 46, client 9: epoch_accuracy 66.54, epoch_loss 0.9370105915431735
#
#
#  Round 46, client 10: epoch_accuracy 66.58, epoch_loss 0.9333871814269054
#
#
#
#  Model's Round: 46, train accuracy of model: 66.856, train loss of model: 0.9290489931083933
# round 46 = flri 0
# Model's Round: 46, test accuracy of model: 34.384984025559106, test loss of model: 5.990278820641125
# round 46 completed
#
#
#
#  Round 47, client 1: epoch_accuracy 67.52, epoch_loss 0.8998261456248127
#
#
#  Round 47, client 2: epoch_accuracy 67.3, epoch_loss 0.9132146918320958
#
#
#  Round 47, client 3: epoch_accuracy 66.6, epoch_loss 0.9323897482473639
#
#
#  Round 47, client 4: epoch_accuracy 67.7, epoch_loss 0.9132144994373563
#
#
#  Round 47, client 5: epoch_accuracy 67.98, epoch_loss 0.9098323462884638
#
#
#  Round 47, client 6: epoch_accuracy 66.92, epoch_loss 0.9220005854775634
#
#
#  Round 47, client 7: epoch_accuracy 67.6, epoch_loss 0.8863084316253662
#
#
#  Round 47, client 8: epoch_accuracy 67.28, epoch_loss 0.9099173085599006
#
#
#  Round 47, client 9: epoch_accuracy 67.18, epoch_loss 0.9152700470972664
#
#
#  Round 47, client 10: epoch_accuracy 67.92, epoch_loss 0.9023616713813588
#
#
#
#  Model's Round: 47, train accuracy of model: 67.39999999999999, train loss of model: 0.9104335475571548
# round 47 = flri 0
# Model's Round: 47, test accuracy of model: 33.98562300319489, test loss of model: 5.991243275590598
# round 47 completed
#
#
#
#  Round 48, client 1: epoch_accuracy 69.28, epoch_loss 0.8748636887043337
#
#
#  Round 48, client 2: epoch_accuracy 68.22, epoch_loss 0.8957154962080943
#
#
#  Round 48, client 3: epoch_accuracy 67.58, epoch_loss 0.9078028964090951
#
#
#  Round 48, client 4: epoch_accuracy 67.74, epoch_loss 0.8954647304136542
#
#
#  Round 48, client 5: epoch_accuracy 69.1, epoch_loss 0.8785163186773469
#
#
#  Round 48, client 6: epoch_accuracy 67.88, epoch_loss 0.895318004903914
#
#
#  Round 48, client 7: epoch_accuracy 69.34, epoch_loss 0.8705774402316613
#
#
#  Round 48, client 8: epoch_accuracy 69.0, epoch_loss 0.8657144421263586
#
#
#  Round 48, client 9: epoch_accuracy 68.72, epoch_loss 0.8783804280093953
#
#
#  Round 48, client 10: epoch_accuracy 67.7, epoch_loss 0.8912803892847858
#
#
#
#  Model's Round: 48, train accuracy of model: 68.456, train loss of model: 0.885363383496864
# round 48 = flri 0
# Model's Round: 48, test accuracy of model: 36.29193290734824, test loss of model: 5.845892134185036
# round 48 completed
#
#
#
#  Round 49, client 1: epoch_accuracy 70.2, epoch_loss 0.8557638722130015
#
#
#  Round 49, client 2: epoch_accuracy 68.9, epoch_loss 0.8730552113508876
#
#
#  Round 49, client 3: epoch_accuracy 67.86, epoch_loss 0.8748606616937662
#
#
#  Round 49, client 4: epoch_accuracy 69.22, epoch_loss 0.869978479946716
#
#
#  Round 49, client 5: epoch_accuracy 69.36, epoch_loss 0.8554864865315112
#
#
#  Round 49, client 6: epoch_accuracy 69.4, epoch_loss 0.8779691420023954
#
#
#  Round 49, client 7: epoch_accuracy 69.28, epoch_loss 0.8480651506894752
#
#
#  Round 49, client 8: epoch_accuracy 68.68, epoch_loss 0.8503040686438356
#
#
#  Round 49, client 9: epoch_accuracy 68.42, epoch_loss 0.8679234053515181
#
#
#  Round 49, client 10: epoch_accuracy 68.98, epoch_loss 0.8711802657646469
#
#
#
#  Model's Round: 49, train accuracy of model: 69.03, train loss of model: 0.8644586744187753
# round 49 = flri 0
# Model's Round: 49, test accuracy of model: 35.98242811501598, test loss of model: 5.765789859972823
# round 49 completed
#
#
#
#  Round 50, client 1: epoch_accuracy 70.62, epoch_loss 0.8377003673511215
#
#
#  Round 50, client 2: epoch_accuracy 69.6, epoch_loss 0.8651586340952523
#
#
#  Round 50, client 3: epoch_accuracy 68.48, epoch_loss 0.8713284572468528
#
#
#  Round 50, client 4: epoch_accuracy 70.06, epoch_loss 0.8566901034946683
#
#
#  Round 50, client 5: epoch_accuracy 69.78, epoch_loss 0.8431045820441427
#
#
#  Round 50, client 6: epoch_accuracy 69.14, epoch_loss 0.861162744368179
#
#
#  Round 50, client 7: epoch_accuracy 70.26, epoch_loss 0.8299786274946188
#
#
#  Round 50, client 8: epoch_accuracy 70.12, epoch_loss 0.8395176967488059
#
#
#  Round 50, client 9: epoch_accuracy 70.0, epoch_loss 0.8622508894039106
#
#
#  Round 50, client 10: epoch_accuracy 70.1, epoch_loss 0.852752261523959
#
#
#
#  Model's Round: 50, train accuracy of model: 69.816, train loss of model: 0.8519644363771512
# round 50 = flri 0
# Model's Round: 50, test accuracy of model: 38.25878594249201, test loss of model: 5.316169150721151
# round 50 completed
#
#
#
#  Round 51, client 1: epoch_accuracy 71.5, epoch_loss 0.8150400413742548
#
#
#  Round 51, client 2: epoch_accuracy 71.24, epoch_loss 0.8453531597234025
#
#
#  Round 51, client 3: epoch_accuracy 70.06, epoch_loss 0.8243303310267532
#
#
#  Round 51, client 4: epoch_accuracy 70.86, epoch_loss 0.8249761828138858
#
#
#  Round 51, client 5: epoch_accuracy 70.82, epoch_loss 0.8285988342912891
#
#
#  Round 51, client 6: epoch_accuracy 69.44, epoch_loss 0.8668618390831766
#
#
#  Round 51, client 7: epoch_accuracy 70.52, epoch_loss 0.8324037699759761
#
#
#  Round 51, client 8: epoch_accuracy 70.2, epoch_loss 0.8286475365674948
#
#
#  Round 51, client 9: epoch_accuracy 70.16, epoch_loss 0.8354491319837449
#
#
#  Round 51, client 10: epoch_accuracy 70.44, epoch_loss 0.8387499572355536
#
#
#
#  Model's Round: 51, train accuracy of model: 70.524, train loss of model: 0.834041078407553
# round 51 = flri 0
# Model's Round: 51, test accuracy of model: 37.120607028753994, test loss of model: 5.775247639741379
# round 51 completed
#
#
#
#  Round 52, client 1: epoch_accuracy 71.1, epoch_loss 0.8213058521475973
#
#
#  Round 52, client 2: epoch_accuracy 70.94, epoch_loss 0.8265799133083488
#
#
#  Round 52, client 3: epoch_accuracy 70.28, epoch_loss 0.8116913309580163
#
#
#  Round 52, client 4: epoch_accuracy 70.36, epoch_loss 0.8252021821239327
#
#
#  Round 52, client 5: epoch_accuracy 70.96, epoch_loss 0.8137864991079403
#
#
#  Round 52, client 6: epoch_accuracy 69.94, epoch_loss 0.8374207261242445
#
#
#  Round 52, client 7: epoch_accuracy 70.42, epoch_loss 0.8399130256870125
#
#
#  Round 52, client 8: epoch_accuracy 70.7, epoch_loss 0.8084444833707206
#
#
#  Round 52, client 9: epoch_accuracy 71.04, epoch_loss 0.8189748472805265
#
#
#  Round 52, client 10: epoch_accuracy 70.66, epoch_loss 0.8311904299108288
#
#
#
#  Model's Round: 52, train accuracy of model: 70.64, train loss of model: 0.8234509290019169
# round 52 = flri 0
# Model's Round: 52, test accuracy of model: 37.99920127795527, test loss of model: 5.458149187481061
# round 52 completed
#
#
#
#  Round 53, client 1: epoch_accuracy 71.2, epoch_loss 0.7980688153942929
#
#
#  Round 53, client 2: epoch_accuracy 71.88, epoch_loss 0.7974036547202098
#
#
#  Round 53, client 3: epoch_accuracy 70.3, epoch_loss 0.8067786172975467
#
#
#  Round 53, client 4: epoch_accuracy 70.86, epoch_loss 0.8072148606747012
#
#
#  Round 53, client 5: epoch_accuracy 71.54, epoch_loss 0.8049272472345377
#
#
#  Round 53, client 6: epoch_accuracy 70.42, epoch_loss 0.8202287509471555
#
#
#  Round 53, client 7: epoch_accuracy 72.66, epoch_loss 0.7683671437486818
#
#
#  Round 53, client 8: epoch_accuracy 72.24, epoch_loss 0.7883004236824905
#
#
#  Round 53, client 9: epoch_accuracy 71.12, epoch_loss 0.8142489851275577
#
#
#  Round 53, client 10: epoch_accuracy 71.48, epoch_loss 0.8081477895567689
#
#
#
#  Model's Round: 53, train accuracy of model: 71.37, train loss of model: 0.8013686288383942
# round 53 = flri 0
# Model's Round: 53, test accuracy of model: 39.16733226837061, test loss of model: 5.406870528151052
# round 53 completed
#
#
#
#  Round 54, client 1: epoch_accuracy 72.66, epoch_loss 0.7680478126187867
#
#
#  Round 54, client 2: epoch_accuracy 72.14, epoch_loss 0.7921463756621638
#
#
#  Round 54, client 3: epoch_accuracy 71.12, epoch_loss 0.7868124322046207
#
#
#  Round 54, client 4: epoch_accuracy 72.02, epoch_loss 0.7963926731785641
#
#
#  Round 54, client 5: epoch_accuracy 72.44, epoch_loss 0.7579780311524114
#
#
#  Round 54, client 6: epoch_accuracy 72.12, epoch_loss 0.7924164209184767
#
#
#  Round 54, client 7: epoch_accuracy 72.64, epoch_loss 0.7859233051915712
#
#
#  Round 54, client 8: epoch_accuracy 71.86, epoch_loss 0.7882844104042536
#
#
#  Round 54, client 9: epoch_accuracy 72.24, epoch_loss 0.7904748788362816
#
#
#  Round 54, client 10: epoch_accuracy 71.9, epoch_loss 0.7978340892852107
#
#
#
#  Model's Round: 54, train accuracy of model: 72.114, train loss of model: 0.7856310429452341
# round 54 = flri 0
# Model's Round: 54, test accuracy of model: 38.58825878594249, test loss of model: 5.7049863060442405
# round 54 completed
#
#
#
#  Round 55, client 1: epoch_accuracy 73.32, epoch_loss 0.7644658216947242
#
#
#  Round 55, client 2: epoch_accuracy 72.76, epoch_loss 0.7721372231652465
#
#
#  Round 55, client 3: epoch_accuracy 72.16, epoch_loss 0.7752855499333973
#
#
#  Round 55, client 4: epoch_accuracy 72.68, epoch_loss 0.7825918205176727
#
#
#  Round 55, client 5: epoch_accuracy 73.5, epoch_loss 0.7600627537769608
#
#
#  Round 55, client 6: epoch_accuracy 71.74, epoch_loss 0.7866815781291527
#
#
#  Round 55, client 7: epoch_accuracy 72.68, epoch_loss 0.7717938023277476
#
#
#  Round 55, client 8: epoch_accuracy 73.24, epoch_loss 0.7426240878014625
#
#
#  Round 55, client 9: epoch_accuracy 72.5, epoch_loss 0.7878905380073982
#
#
#  Round 55, client 10: epoch_accuracy 72.5, epoch_loss 0.7569547284253036
#
#
#
#  Model's Round: 55, train accuracy of model: 72.708, train loss of model: 0.7700487903779065
# round 55 = flri 0
# Model's Round: 55, test accuracy of model: 38.76797124600639, test loss of model: 5.627537477130707
# round 55 completed
#
#
#
#  Round 56, client 1: epoch_accuracy 73.16, epoch_loss 0.7335831070248084
#
#
#  Round 56, client 2: epoch_accuracy 73.58, epoch_loss 0.7379221855839596
#
#
#  Round 56, client 3: epoch_accuracy 72.54, epoch_loss 0.7536278600934185
#
#
#  Round 56, client 4: epoch_accuracy 73.6, epoch_loss 0.7575089161909079
#
#
#  Round 56, client 5: epoch_accuracy 74.08, epoch_loss 0.7355963599078262
#
#
#  Round 56, client 6: epoch_accuracy 73.56, epoch_loss 0.7574661253373834
#
#
#  Round 56, client 7: epoch_accuracy 73.7, epoch_loss 0.7524682004240495
#
#
#  Round 56, client 8: epoch_accuracy 73.88, epoch_loss 0.7347205930118319
#
#
#  Round 56, client 9: epoch_accuracy 73.46, epoch_loss 0.7538958603068243
#
#
#  Round 56, client 10: epoch_accuracy 73.26, epoch_loss 0.7528056389168848
#
#
#
#  Model's Round: 56, train accuracy of model: 73.482, train loss of model: 0.7469594846797893
# round 56 = flri 0
# Model's Round: 56, test accuracy of model: 39.81629392971246, test loss of model: 5.359187028278558
# round 56 completed
#
#
#
#  Round 57, client 1: epoch_accuracy 75.24, epoch_loss 0.7213447207136999
#
#
#  Round 57, client 2: epoch_accuracy 74.2, epoch_loss 0.7355726930914046
#
#
#  Round 57, client 3: epoch_accuracy 73.9, epoch_loss 0.7304578087752378
#
#
#  Round 57, client 4: epoch_accuracy 73.54, epoch_loss 0.7339435589464405
#
#
#  Round 57, client 5: epoch_accuracy 74.32, epoch_loss 0.7242940370040604
#
#
#  Round 57, client 6: epoch_accuracy 74.24, epoch_loss 0.7361604895772813
#
#
#  Round 57, client 7: epoch_accuracy 74.88, epoch_loss 0.7111446019969409
#
#
#  Round 57, client 8: epoch_accuracy 74.18, epoch_loss 0.7302296750153168
#
#
#  Round 57, client 9: epoch_accuracy 75.76, epoch_loss 0.7193318560153623
#
#
#  Round 57, client 10: epoch_accuracy 73.44, epoch_loss 0.7323530263538602
#
#
#
#  Model's Round: 57, train accuracy of model: 74.37, train loss of model: 0.7274832467489605
# round 57 = flri 0
# Model's Round: 57, test accuracy of model: 38.328674121405754, test loss of model: 5.877289493624776
# round 57 completed
#
#
#
#  Round 58, client 1: epoch_accuracy 74.5, epoch_loss 0.7022972189927403
#
#
#  Round 58, client 2: epoch_accuracy 74.16, epoch_loss 0.7275372894504403
#
#
#  Round 58, client 3: epoch_accuracy 74.52, epoch_loss 0.7123084686979463
#
#
#  Round 58, client 4: epoch_accuracy 74.54, epoch_loss 0.7389404947244669
#
#
#  Round 58, client 5: epoch_accuracy 74.22, epoch_loss 0.7270057367373116
#
#
#  Round 58, client 6: epoch_accuracy 74.12, epoch_loss 0.7257866387880301
#
#
#  Round 58, client 7: epoch_accuracy 74.34, epoch_loss 0.7042645725268352
#
#
#  Round 58, client 8: epoch_accuracy 75.2, epoch_loss 0.7193809460990036
#
#
#  Round 58, client 9: epoch_accuracy 74.32, epoch_loss 0.7294421520414232
#
#
#  Round 58, client 10: epoch_accuracy 74.2, epoch_loss 0.745052305957939
#
#
#
#  Model's Round: 58, train accuracy of model: 74.412, train loss of model: 0.7232015824016138
# round 58 = flri 0
# Model's Round: 58, test accuracy of model: 40.625, test loss of model: 5.433954798756316
# round 58 completed
#
#
#
#  Round 59, client 1: epoch_accuracy 74.84, epoch_loss 0.6983538171913051
#
#
#  Round 59, client 2: epoch_accuracy 74.66, epoch_loss 0.7307174511348145
#
#
#  Round 59, client 3: epoch_accuracy 74.3, epoch_loss 0.7013894764682914
#
#
#  Round 59, client 4: epoch_accuracy 75.4, epoch_loss 0.7042701847945587
#
#
#  Round 59, client 5: epoch_accuracy 75.3, epoch_loss 0.696259308842164
#
#
#  Round 59, client 6: epoch_accuracy 75.24, epoch_loss 0.7198157683957981
#
#
#  Round 59, client 7: epoch_accuracy 75.52, epoch_loss 0.7058246313016626
#
#
#  Round 59, client 8: epoch_accuracy 75.78, epoch_loss 0.6851380165619186
#
#
#  Round 59, client 9: epoch_accuracy 74.9, epoch_loss 0.7119956299473967
#
#
#  Round 59, client 10: epoch_accuracy 74.66, epoch_loss 0.7172895073890686
#
#
#
#  Model's Round: 59, train accuracy of model: 75.06, train loss of model: 0.7071053792026978
# round 59 = flri 0
# Model's Round: 59, test accuracy of model: 42.861421725239616, test loss of model: 5.012986173264135
# round 59 completed
#
#
#
#  Round 60, client 1: epoch_accuracy 75.88, epoch_loss 0.6808045796955688
#
#
#  Round 60, client 2: epoch_accuracy 75.76, epoch_loss 0.6833770659905446
#
#
#  Round 60, client 3: epoch_accuracy 75.76, epoch_loss 0.6888846639968171
#
#
#  Round 60, client 4: epoch_accuracy 74.82, epoch_loss 0.7112723173974436
#
#
#  Round 60, client 5: epoch_accuracy 75.8, epoch_loss 0.682439910460122
#
#
#  Round 60, client 6: epoch_accuracy 75.04, epoch_loss 0.7057777182965339
#
#
#  Round 60, client 7: epoch_accuracy 76.16, epoch_loss 0.6716083457952813
#
#
#  Round 60, client 8: epoch_accuracy 76.02, epoch_loss 0.6759389714349674
#
#
#  Round 60, client 9: epoch_accuracy 75.1, epoch_loss 0.6777750834634032
#
#
#  Round 60, client 10: epoch_accuracy 75.24, epoch_loss 0.695524078758457
#
#
#
#  Model's Round: 60, train accuracy of model: 75.558, train loss of model: 0.6873402735289138
# round 60 = flri 0
# Model's Round: 60, test accuracy of model: 39.936102236421725, test loss of model: 5.862304215994887
# round 60 completed

# %%
# # folder_name = f"{mathod}_{opti}_lr={learning_rate}_R={round_no}_ E={epochs}_B={batch_size}_{distribution}"
# fn_=f"{mathod}_{opti}_E={epochs}_B={batch_size}_iid"

# %%
# def plot_train_test_accuracy(round_results, title, folder):
#     rounds = list(range(0, len(round_results)))
#     train_accuracies = round_results['train_accuracy'].tolist()
#     test_accuracies = round_results['test_accuracy'].tolist()

#     fig, ax = plt.subplots(figsize=(5, 3))
#     ax.plot(rounds, train_accuracies, label='Train Accuracy', color='blue')
#     ax.plot(rounds, test_accuracies, label='Test Accuracy', color='green')

#     ax.set_xlabel("Round")
#     ax.set_ylabel("Server accuracy in %")
#     ax.set_title(title)
#     ax.set_ylim(0, 100)
#     ax.set_xlim(0, len(rounds))
#     ax.set_xticks(range(0, len(rounds) + 2, 10))

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     ax.grid(True)
#     ax.legend()
#     plt.tight_layout()
#     os.makedirs(folder, exist_ok=True)
#     filename = os.path.join(folder, f"{title}.png")
#     plt.savefig(filename, dpi=300)
#     plt.show()





# def plot_flri(round_results, title, folder):
#     rounds = list(range(0, len(round_results)))
#     train_accuracies = round_results['flri'].tolist()
#     print(train_accuracies)
#     # test_accuracies = round_results['test_accuracy'].tolist()

#     fig, ax = plt.subplots(figsize=(5, 3))
#     ax.plot(rounds, train_accuracies, label='flri', color='blue')
#     # ax.plot(rounds, test_accuracies, label='Test Accuracy', color='green')

#     ax.set_xlabel("Round")
#     ax.set_ylabel("Server accuracy in %")
#     ax.set_title(title)
#     ax.set_ylim(0, 2)
#     ax.set_xlim(0, len(rounds))Amr found himself sidelined and held partially responsible for Uthman's death. He then allied with Mu'awiya, who was also seeking retribution for Uthman's death and challenging Caliph Ali's rule. Amr'
#     ax.set_xticks(range(0, len(rounds) + 2, 10))

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     ax.grid(True)
#     ax.legend()
#     plt.tight_layout()
#     os.makedirs(folder, exist_ok=True)
#     filename = os.path.join(folder, f"{title}.png")
#     plt.savefig(filename, dpi=300)
#     plt.show()

# %%
# # title = f"a) AD vs R for {fn_}"
# # plot_rounds_clients_ad(delta_ad, title, folder_name)

# title = f"Acc (%) vs R for {fn_}"
# plot_train_test_accuracy(round_results, title, folder_name)

# title = f"flri vs R for {fn_}"
# plot_flri(round_results, title, folder_name)

# %% [markdown]
# # Reuslts

# %%
# save_dir = folder_name  # your desired folder
# os.makedirs(save_dir, exist_ok=True)  # create folder if not exists

# save_path = os.path.join(save_dir, 'delta_ad_data.pt')
# torch.save(delta_ad, save_path)
# print(f"[✓] delta_ad saved at {save_path}")

# save_path = os.path.join(folder_name, 'delta_ad_data.pt')

# # Load the saved file
# if os.path.exists(save_path):
#     delta_ad_loaded = torch.load(save_path)
#     print("[✓] Loaded delta_ad from:", save_path)
#     print(delta_ad_loaded)
# else:
#     print("[✗] File not found at:", save_path)

# %%
# Round # Define the folder and file name
# folder_name = f"fed_avg_{opti}_{learning_rate}_{name}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
# folder_name =  f"fed_avg_{opti}_{learning_rate}_{name}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
