# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import os
import sys
import time
import copy
import random
import warnings
import pickle

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch import Tensor
from torch.utils.data import DataLoader, Subset

import torchvision
from torchvision import datasets, transforms, models

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from collections import Counter

# Plot settings
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# Ignore warnings
warnings.filterwarnings("ignore")

# Reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda:0

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#====CNN model
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)

        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        # Fully connected layers
        self.fc1 = nn.Linear(128 * 8 * 8, 512)  # Adjust input size here
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Add a linear layer for classification

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)

        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)

        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)

        return x

# %% [markdown]
# # Train

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag, ci,c):
    global opti
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    # Initialize local model with the global model weights
    yi = {k: v.clone().float().to(device) for k, v in i_weights.items()}
    # Ensure control variates are float
    ci = {k: v.float().to(device) for k, v in ci.items()}
    c = {k: v.float().to(device) for k, v in c.items()}
    
    # Adjust gradients with control variate (c - ci)
    with torch.no_grad():  # Ensure no gradient tracking for this operation
        for k in local_model.state_dict().keys():
            param = local_model.state_dict()[k].float()
            local_model.state_dict()[k] = param - (ci[k] - c[k])

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    # epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    epoch_test_accuracy=0
    epoch_test_loss=0
    
    
    epoch_rmd=0#model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [roun, cli, epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data

    # Update client control variate ci using Option II
    new_ci = {
        k: ci[k] - c[k] + (1 / (epochs * le_rate)) * (i_weights[k].float() - f_weights[k])
        for k in ci.keys()
    }
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag, new_ci

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()
    lmodel.load_state_dict(w)
    lmodel.eval()

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
# def calculate_flri(client_updates, client_weights):
#     """
#     client_updates: list of model update tensors (delta_w_k), flattened
#     client_weights: list of weights (alpha_k), usually n_k / total_n
#     """
#     assert len(client_updates) == len(client_weights), "Mismatch between updates and weights"

#     # Compute the weighted average update
#     avg_update = sum(w * u for w, u in zip(client_weights, client_updates))

#     def cosine_sim(a, b):
#         return torch.nn.functional.cosine_similarity(a, b, dim=0)

#     # Compute weighted disagreement
#     rosa_t = 0.0
#     for w_k, delta_k in zip(client_weights, client_updates):
#         sim = cosine_sim(delta_k, avg_update)
#         rosa_t += w_k * (1 - sim)
    
#     return rosa_t.item()

# %%
def average_weights_function(dicts):
    # Initialize an empty dictionary to store the summed weights
    summed_weights = {}
    
    # Initialize an empty dictionary to keep track of how many times each key is seen
    key_occurrences = {}
    
    # Iterate through all the dictionaries
    for d in dicts:
        for key, value in d.items():
            if key in summed_weights:
                summed_weights[key] += value
                key_occurrences[key] += 1
            else:
                summed_weights[key] = value
                key_occurrences[key] = 1
    
    # Create a dictionary to store the final averaged weights
    averaged_weights = {}
    
    # Iterate through the summed weights and divide by the number of occurrences for each key
    for key, value in summed_weights.items():
        if key_occurrences[key] > 1:
            averaged_weights[key] = value / key_occurrences[key]
        else:
            averaged_weights[key] = value  # If only present in one dict, keep as is
    
    return averaged_weights

# %%
def flatten_model_update(update_dict):
    """
    Convert a dict of parameter tensors (model state dict differences)
    to one 1D flattened tensor.
    """
    flat_params = []
    for key in update_dict:
        flat_params.append(update_dict[key].flatten())
    return torch.cat(flat_params)

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_clients_list, participating_client_list
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)

    c_list = {k: torch.zeros_like(v, dtype=torch.float).to(device) for k, v in i_w.items()}  # Initialize global control variate to zero
    ci_list = [{k: torch.zeros_like(v, dtype=torch.float).to(device) for k, v in i_w.items()} for _ in range(C)]  # Initialize client control variates to zero

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        models = []

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                
                c_i = ci_list[c] 
                
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                #train model
                train_accuracy, train_loss, c_f_weights, epoch_flag, new_ci = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag, c_i, c_list)

                models.append( c_f_weights)

                ci_list[c] = new_ci

                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

            else:
                print(f"client {c+1} is not selectecd")
                
        all_final_weights = average_weights_function(models)
        
        round_epoch=(epoch_flag)

        for k in c_list.keys():
            # Convert to float before summing and assigning
            ci_sum = sum([ci_list[n_no][k].float() for n_no in range(C)])
            c_list[k] += (1 / C) * ci_sum
        
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)

        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        #for param_name in all_final_weights:
            #all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        #model deviation code
        round_rmd=0#model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)

        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
        round_results.loc[len(round_results)] = round_data
            
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=10
participating_client=10
epochs=5
learning_rate=0.01
round_no=60
batch_size=64
data_class=10

opti="sgd"
# opti="adam"

mathod="fed_scaffold"

# set_up='IID'
# set_up='non_IID'
set_up='salt_pepper'
# set_up='mislabelled'

# iid
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_infinity"

#non_iid
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_0.1"
# distribution=f"clients_no_{client_no}_data_IID_CIFAR10_alpha_0.5"

#salt_pepper
# distribution=f"clients_no_5_10_IID_CIFAR10_alpha_infinity_0.6"
# distribution=f"clients_no_5_10_data_non-IID_CIFAR10_alpha_0.1_0.6"
distribution=f"clients_no_5_10_data_non-IID_CIFAR10_alpha_0.5_0.6"


#misslabelled
# distribution=f"IID_clients_1_2_3_4_60pct_mislabeled_CIFAR10_infinity"
# distribution=f"clients_1_2_3_4_60pct_mislabeled_CIFAR10_0.1"
# distribution=f"clients_1_2_3_4_60pct_mislabeled_CIFAR10_0.5"


# List of clients
total_clients_list = list(range(0, client_no))
# print(total_clients_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['round', 'client', 'train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

ad_client_values_list=[]

list_accuracy=[]
list_loss=[]
list_test_accuracy=[]
list_test_loss=[]


delta_ad={}
weight_c={}

#===================================loading the saved weight list====================================================
global_model = model().to(device)
file_path= "i_w.pth"
initial_weights = {k: v.clone() for k, v in global_model.state_dict().items()}
torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=False)
Print("Model's initial weights", initial_weights)

folder_name = f"{mathod}_{opti}_lr={learning_rate}_R={round_no}_E={epochs}_B={batch_size}_{distribution}"
# Out:
# Model's initial weights:conv1.weight: tensor([[ 0.1471,  0.1597, -0.0451],
#         [ 0.1768, -0.0422,  0.0388],
#         [-0.0937,  0.1130,  0.1697]], device='cuda:0')

# %% [markdown]
# # Dataset loader

# %%
def print_data_distribution(clients_data):
    """
    Print the distribution of class labels for each client.
    """
    for idx, client in enumerate(clients_data):
        labels = [label for (_, label) in client]
        class_counts = Counter(labels)
        sorted_counts = dict(sorted(class_counts.items()))
        print(f"Client {idx} - Total Samples: {len(labels)} - Class Distribution: {sorted_counts}")


pt_path = os.path.join(f'{set_up}', f'{distribution}.pt')

client_datasets = torch.load(pt_path)

print_data_distribution(client_datasets)

from torchvision import datasets, transforms
from torch.utils.data import DataLoader
# Define test set transformations for CIFAR-10 (no augmentation, just normalization)
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),  # mean for CIFAR-10
                         (0.2023, 0.1994, 0.2010))  # std for CIFAR-10
])
# Load CIFAR-10 test dataset
cifar10_test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
# Create DataLoader for the test set
test_loader = DataLoader(cifar10_test_dataset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# Client 0 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 1 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 2 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 3 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 4 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 5 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 6 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 7 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 8 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Client 9 - Total Samples: 5000 - Class Distribution: {0: 500, 1: 500, 2: 500, 3: 500, 4: 500, 5: 500, 6: 500, 7: 500, 8: 500, 9: 500}
# Files already downloaded and verified

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for clients
round_train_accuracy=0
round_train_loss=0
train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


list_accuracy.append(round_train_accuracy)
list_loss.append(round_train_loss)

#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
# val_accuracy,val_loss=test(initial_weights,val_loader)

# print(f"{test_accuracy}, {test_loss}, {val_accuracy}, {val_loss}  ")
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

# list_val_accuracy.append(val_accuracy)
# list_val_loss.append(val_loss)
list_test_accuracy.append(test_accuracy)
list_test_loss.append(test_loss)


Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[ 0.1471,  0.1597, -0.0451],
#         [ 0.1768, -0.0422,  0.0388],
#         [-0.0937,  0.1130,  0.1697]], device='cuda:0')
#
#  train accuracy: 10.009889240506329
#  train_loss: 2.3027977016907704
#  test_accuracy: 10.093849840255592
#  test_loss: 2.302839367534406

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1: epoch_accuracy 9.815705128205128, epoch_loss 2.303462187449137
# Round 1, cleint 1, epoch 2: epoch_accuracy 9.615384615384615, epoch_loss 2.303251018890968
# Round 1, cleint 1, epoch 3: epoch_accuracy 10.216346153846153, epoch_loss 2.3029281420585437
# Round 1, cleint 1, epoch 4: epoch_accuracy 9.795673076923077, epoch_loss 2.302986420117892
# Round 1, cleint 1, epoch 5: epoch_accuracy 10.276442307692308, epoch_loss 2.302832551491566
# Round 1, cleint 1, epoch 6: epoch_accuracy 9.815705128205128, epoch_loss 2.3026623787024083
# Round 1, cleint 1, epoch 7: epoch_accuracy 10.116185897435898, epoch_loss 2.3028183166797342
# Round 1, cleint 1, epoch 8: epoch_accuracy 10.516826923076923, epoch_loss 2.302514932094476
# Round 1, cleint 1, epoch 9: epoch_accuracy 10.056089743589743, epoch_loss 2.303194360855298
# Round 1, cleint 1, epoch 10: epoch_accuracy 10.556891025641026, epoch_loss 2.3024365657415147
# Round 1, cleint 2, epoch 1: epoch_accuracy 10.096153846153847, epoch_loss 2.3031517572892017
# Round 1, cleint 2, epoch 2: epoch_accuracy 9.134615384615385, epoch_loss 2.3030952031795797
# Round 1, cleint 2, epoch 3: epoch_accuracy 9.615384615384615, epoch_loss 2.30306652876047
# Round 1, cleint 2, epoch 4: epoch_accuracy 9.815705128205128, epoch_loss 2.303044175490355
# Round 1, cleint 2, epoch 5: epoch_accuracy 9.99599358974359, epoch_loss 2.3027969965567956
# Round 1, cleint 2, epoch 6: epoch_accuracy 10.01602564102564, epoch_loss 2.3025825298749485
# Round 1, cleint 2, epoch 7: epoch_accuracy 10.436698717948717, epoch_loss 2.302300994212811
# Round 1, cleint 2, epoch 8: epoch_accuracy 9.895833333333334, epoch_loss 2.3029263753157396
# Round 1, cleint 2, epoch 9: epoch_accuracy 9.635416666666666, epoch_loss 2.302994734201676
# Round 1, cleint 2, epoch 10: epoch_accuracy 10.196314102564102, epoch_loss 2.3024288568741236
# Round 1, cleint 3, epoch 1: epoch_accuracy 9.895833333333334, epoch_loss 2.3027979471744637
# Round 1, cleint 3, epoch 2: epoch_accuracy 10.236378205128204, epoch_loss 2.303186541948563
# Round 1, cleint 3, epoch 3: epoch_accuracy 10.536858974358974, epoch_loss 2.303128236379379
# Round 1, cleint 3, epoch 4: epoch_accuracy 9.575320512820513, epoch_loss 2.3026953782790747
# Round 1, cleint 3, epoch 5: epoch_accuracy 9.99599358974359, epoch_loss 2.3030524039879823
# Round 1, cleint 3, epoch 6: epoch_accuracy 9.67548076923077, epoch_loss 2.3033044705024133
# Round 1, cleint 3, epoch 7: epoch_accuracy 9.475160256410257, epoch_loss 2.3030215685184183
# Round 1, cleint 3, epoch 8: epoch_accuracy 9.815705128205128, epoch_loss 2.302815107198862
# Round 1, cleint 3, epoch 9: epoch_accuracy 9.99599358974359, epoch_loss 2.302820841471354
# Round 1, cleint 3, epoch 10: epoch_accuracy 9.294871794871796, epoch_loss 2.302902952218667
# Round 1, cleint 4, epoch 1: epoch_accuracy 10.216346153846153, epoch_loss 2.3029893269905677
# Round 1, cleint 4, epoch 2: epoch_accuracy 9.53525641025641, epoch_loss 2.3031059289589906
# Round 1, cleint 4, epoch 3: epoch_accuracy 10.276442307692308, epoch_loss 2.3025771226638403
# Round 1, cleint 4, epoch 4: epoch_accuracy 9.755608974358974, epoch_loss 2.3028986148345165
# Round 1, cleint 4, epoch 5: epoch_accuracy 9.254807692307692, epoch_loss 2.303027418943552
# Round 1, cleint 4, epoch 6: epoch_accuracy 9.99599358974359, epoch_loss 2.302709258519686
# Round 1, cleint 4, epoch 7: epoch_accuracy 10.15625, epoch_loss 2.3028357731990323
# Round 1, cleint 4, epoch 8: epoch_accuracy 10.236378205128204, epoch_loss 2.3025755759997244
# Round 1, cleint 4, epoch 9: epoch_accuracy 10.036057692307692, epoch_loss 2.302774349848429
# Round 1, cleint 4, epoch 10: epoch_accuracy 10.056089743589743, epoch_loss 2.3026189712377696
# Round 1, cleint 5, epoch 1: epoch_accuracy 9.955929487179487, epoch_loss 2.30305369083698
# Round 1, cleint 5, epoch 2: epoch_accuracy 9.835737179487179, epoch_loss 2.302824934323629
# Round 1, cleint 5, epoch 3: epoch_accuracy 9.915865384615385, epoch_loss 2.303105959525475
# Round 1, cleint 5, epoch 4: epoch_accuracy 10.176282051282051, epoch_loss 2.3028378517199783
# Round 1, cleint 5, epoch 5: epoch_accuracy 9.274839743589743, epoch_loss 2.3028223117192588
# Round 1, cleint 5, epoch 6: epoch_accuracy 10.236378205128204, epoch_loss 2.3027397974943504
# Round 1, cleint 5, epoch 7: epoch_accuracy 10.076121794871796, epoch_loss 2.3027297380643015
# Round 1, cleint 5, epoch 8: epoch_accuracy 10.31650641025641, epoch_loss 2.3025821386239467
# Round 1, cleint 5, epoch 9: epoch_accuracy 9.294871794871796, epoch_loss 2.3029271303079066
# Round 1, cleint 5, epoch 10: epoch_accuracy 10.496794871794872, epoch_loss 2.3027188869623036
# Round 1, cleint 6, epoch 1: epoch_accuracy 9.695512820512821, epoch_loss 2.303120200450604
# Round 1, cleint 6, epoch 2: epoch_accuracy 10.616987179487179, epoch_loss 2.3024348815282187
# Round 1, cleint 6, epoch 3: epoch_accuracy 10.036057692307692, epoch_loss 2.302458922068278
# Round 1, cleint 6, epoch 4: epoch_accuracy 9.99599358974359, epoch_loss 2.30227324901483
# Round 1, cleint 6, epoch 5: epoch_accuracy 10.45673076923077, epoch_loss 2.3020814259847007
# Round 1, cleint 6, epoch 6: epoch_accuracy 11.09775641025641, epoch_loss 2.302041081281809
# Round 1, cleint 6, epoch 7: epoch_accuracy 11.177884615384615, epoch_loss 2.30163481602302
# Round 1, cleint 6, epoch 8: epoch_accuracy 11.017628205128204, epoch_loss 2.3013291634046116
# Round 1, cleint 6, epoch 9: epoch_accuracy 11.398237179487179, epoch_loss 2.3003229116782165
# Round 1, cleint 6, epoch 10: epoch_accuracy 11.939102564102564, epoch_loss 2.299798629222772
# Round 1, cleint 7, epoch 1: epoch_accuracy 9.655448717948717, epoch_loss 2.3029121038241263
# Round 1, cleint 7, epoch 2: epoch_accuracy 10.396634615384615, epoch_loss 2.3029321890610914
# Round 1, cleint 7, epoch 3: epoch_accuracy 10.036057692307692, epoch_loss 2.3025109951312723
# Round 1, cleint 7, epoch 4: epoch_accuracy 10.096153846153847, epoch_loss 2.3023479045965733
# Round 1, cleint 7, epoch 5: epoch_accuracy 10.056089743589743, epoch_loss 2.3023021037761984
# Round 1, cleint 7, epoch 6: epoch_accuracy 10.757211538461538, epoch_loss 2.301757534344991
# Round 1, cleint 7, epoch 7: epoch_accuracy 11.298076923076923, epoch_loss 2.3014207222522836
# Round 1, cleint 7, epoch 8: epoch_accuracy 11.318108974358974, epoch_loss 2.3013353561743712
# Round 1, cleint 7, epoch 9: epoch_accuracy 11.618589743589743, epoch_loss 2.300642945827582
# Round 1, cleint 7, epoch 10: epoch_accuracy 11.538461538461538, epoch_loss 2.2996986217987843
# Round 1, cleint 8, epoch 1: epoch_accuracy 9.875801282051283, epoch_loss 2.302880021241995
# Round 1, cleint 8, epoch 2: epoch_accuracy 10.096153846153847, epoch_loss 2.302695225446652
# Round 1, cleint 8, epoch 3: epoch_accuracy 9.715544871794872, epoch_loss 2.3026504058104296
# Round 1, cleint 8, epoch 4: epoch_accuracy 10.276442307692308, epoch_loss 2.3022405764995475
# Round 1, cleint 8, epoch 5: epoch_accuracy 10.9375, epoch_loss 2.302039134196746
# Round 1, cleint 8, epoch 6: epoch_accuracy 10.616987179487179, epoch_loss 2.302575319241255
# Round 1, cleint 8, epoch 7: epoch_accuracy 10.877403846153847, epoch_loss 2.301821898191403
# Round 1, cleint 8, epoch 8: epoch_accuracy 10.536858974358974, epoch_loss 2.3017413096550183
# Round 1, cleint 8, epoch 9: epoch_accuracy 11.157852564102564, epoch_loss 2.301350865608607
# Round 1, cleint 8, epoch 10: epoch_accuracy 11.678685897435898, epoch_loss 2.300887872011234
# Round 1, cleint 9, epoch 1: epoch_accuracy 10.416666666666666, epoch_loss 2.302788025293595
# Round 1, cleint 9, epoch 2: epoch_accuracy 9.815705128205128, epoch_loss 2.3029900942093287
# Round 1, cleint 9, epoch 3: epoch_accuracy 10.29647435897436, epoch_loss 2.3025586880170383
# Round 1, cleint 9, epoch 4: epoch_accuracy 11.037660256410257, epoch_loss 2.302471469610165
# Round 1, cleint 9, epoch 5: epoch_accuracy 10.216346153846153, epoch_loss 2.3022120793660483
# Round 1, cleint 9, epoch 6: epoch_accuracy 10.717147435897436, epoch_loss 2.302193039502853
# Round 1, cleint 9, epoch 7: epoch_accuracy 10.77724358974359, epoch_loss 2.301988516098414
# Round 1, cleint 9, epoch 8: epoch_accuracy 10.657051282051283, epoch_loss 2.3016498516767454
# Round 1, cleint 9, epoch 9: epoch_accuracy 11.458333333333334, epoch_loss 2.3014889099659066
# Round 1, cleint 9, epoch 10: epoch_accuracy 11.298076923076923, epoch_loss 2.300900074151846
# Round 1, cleint 10, epoch 1: epoch_accuracy 9.695512820512821, epoch_loss 2.302821920468257
# Round 1, cleint 10, epoch 2: epoch_accuracy 9.975961538461538, epoch_loss 2.30263575223776
# Round 1, cleint 10, epoch 3: epoch_accuracy 9.895833333333334, epoch_loss 2.3025488700622168
# Round 1, cleint 10, epoch 4: epoch_accuracy 9.935897435897436, epoch_loss 2.302261505371485
# Round 1, cleint 10, epoch 5: epoch_accuracy 10.596955128205128, epoch_loss 2.3019952193284645
# Round 1, cleint 10, epoch 6: epoch_accuracy 10.516826923076923, epoch_loss 2.302048301085448
# Round 1, cleint 10, epoch 7: epoch_accuracy 9.915865384615385, epoch_loss 2.3019612660774817
# Round 1, cleint 10, epoch 8: epoch_accuracy 11.438301282051283, epoch_loss 2.301317639839955
# Round 1, cleint 10, epoch 9: epoch_accuracy 11.258012820512821, epoch_loss 2.301190061446948
# Round 1, cleint 10, epoch 10: epoch_accuracy 12.119391025641026, epoch_loss 2.3002320925394693
# Model's Round: 1, train accuracy of model: 10.917467948717947, train loss of model: 2.301462352275849
#
#
# Model's Round: 1, test accuracy of model: 10.75279552715655, test loss of model: 2.301166153563478
#
#
# round 1 completed
# Round 2, cleint 1, epoch 1: epoch_accuracy 9.715544871794872, epoch_loss 2.3030206668071256
# Round 2, cleint 1, epoch 2: epoch_accuracy 10.436698717948717, epoch_loss 2.3023986174510074
# Round 2, cleint 1, epoch 3: epoch_accuracy 10.737179487179487, epoch_loss 2.3020639541821604
# Round 2, cleint 1, epoch 4: epoch_accuracy 10.036057692307692, epoch_loss 2.302807930188301
# Round 2, cleint 1, epoch 5: epoch_accuracy 9.615384615384615, epoch_loss 2.3024709071868505
# Round 2, cleint 1, epoch 6: epoch_accuracy 11.338141025641026, epoch_loss 2.3016693041874814
# Round 2, cleint 1, epoch 7: epoch_accuracy 11.217948717948717, epoch_loss 2.302238259560023
# Round 2, cleint 1, epoch 8: epoch_accuracy 10.977564102564102, epoch_loss 2.3018059119200096
# Round 2, cleint 1, epoch 9: epoch_accuracy 10.256410256410257, epoch_loss 2.3020661366291537
# Round 2, cleint 1, epoch 10: epoch_accuracy 10.216346153846153, epoch_loss 2.302293453461085
# Round 2, cleint 2, epoch 1: epoch_accuracy 10.616987179487179, epoch_loss 2.302357465792925
# Round 2, cleint 2, epoch 2: epoch_accuracy 9.51522435897436, epoch_loss 2.3032629581598134
# Round 2, cleint 2, epoch 3: epoch_accuracy 9.415064102564102, epoch_loss 2.3019604774621816
# Round 2, cleint 2, epoch 4: epoch_accuracy 11.177884615384615, epoch_loss 2.3023760471588526
# Round 2, cleint 2, epoch 5: epoch_accuracy 10.116185897435898, epoch_loss 2.302682103254856
# Round 2, cleint 2, epoch 6: epoch_accuracy 9.915865384615385, epoch_loss 2.3027071983386307
# Round 2, cleint 2, epoch 7: epoch_accuracy 9.715544871794872, epoch_loss 2.302621636635218
# Round 2, cleint 2, epoch 8: epoch_accuracy 10.176282051282051, epoch_loss 2.3022280625807934
# Round 2, cleint 2, epoch 9: epoch_accuracy 10.29647435897436, epoch_loss 2.3016636616144424
# Round 2, cleint 2, epoch 10: epoch_accuracy 11.318108974358974, epoch_loss 2.301567386358212
# Round 2, cleint 3, epoch 1: epoch_accuracy 9.935897435897436, epoch_loss 2.3030043565309963
# Round 2, cleint 3, epoch 2: epoch_accuracy 10.496794871794872, epoch_loss 2.302452781261542
# Round 2, cleint 3, epoch 3: epoch_accuracy 10.77724358974359, epoch_loss 2.3019639375882273
# Round 2, cleint 3, epoch 4: epoch_accuracy 10.236378205128204, epoch_loss 2.3023784894209642
# Round 2, cleint 3, epoch 5: epoch_accuracy 10.77724358974359, epoch_loss 2.302572849469307
# Round 2, cleint 3, epoch 6: epoch_accuracy 10.036057692307692, epoch_loss 2.3025146080897403
# Round 2, cleint 3, epoch 7: epoch_accuracy 10.256410256410257, epoch_loss 2.3020059695610633
# Round 2, cleint 3, epoch 8: epoch_accuracy 11.358173076923077, epoch_loss 2.3014782269795737
# Round 2, cleint 3, epoch 9: epoch_accuracy 10.917467948717949, epoch_loss 2.3020772475462694
# Round 2, cleint 3, epoch 10: epoch_accuracy 9.67548076923077, epoch_loss 2.301820831421094
# Round 2, cleint 4, epoch 1: epoch_accuracy 10.556891025641026, epoch_loss 2.30213956343822
# Round 2, cleint 4, epoch 2: epoch_accuracy 10.29647435897436, epoch_loss 2.302840049450214
# Round 2, cleint 4, epoch 3: epoch_accuracy 10.496794871794872, epoch_loss 2.3023821146060257
# Round 2, cleint 4, epoch 4: epoch_accuracy 10.096153846153847, epoch_loss 2.302241841952006
# Round 2, cleint 4, epoch 5: epoch_accuracy 9.975961538461538, epoch_loss 2.3024024352049217
# Round 2, cleint 4, epoch 6: epoch_accuracy 9.815705128205128, epoch_loss 2.3023012020649056
# Round 2, cleint 4, epoch 7: epoch_accuracy 9.755608974358974, epoch_loss 2.3022608787585526
# Round 2, cleint 4, epoch 8: epoch_accuracy 10.036057692307692, epoch_loss 2.302627147772373
# Round 2, cleint 4, epoch 9: epoch_accuracy 11.197916666666666, epoch_loss 2.301696193523896
# Round 2, cleint 4, epoch 10: epoch_accuracy 11.117788461538462, epoch_loss 2.3017078454677877
# Round 2, cleint 5, epoch 1: epoch_accuracy 9.795673076923077, epoch_loss 2.302788334015088
# Round 2, cleint 5, epoch 2: epoch_accuracy 10.596955128205128, epoch_loss 2.3019777077894945
# Round 2, cleint 5, epoch 3: epoch_accuracy 10.31650641025641, epoch_loss 2.302483457785386
# Round 2, cleint 5, epoch 4: epoch_accuracy 9.575320512820513, epoch_loss 2.3028378639465723
# Round 2, cleint 5, epoch 5: epoch_accuracy 10.076121794871796, epoch_loss 2.3026529061488614
# Round 2, cleint 5, epoch 6: epoch_accuracy 10.31650641025641, epoch_loss 2.3022744839008036
# Round 2, cleint 5, epoch 7: epoch_accuracy 9.715544871794872, epoch_loss 2.3024136683879752
# Round 2, cleint 5, epoch 8: epoch_accuracy 10.45673076923077, epoch_loss 2.30227176959698
# Round 2, cleint 5, epoch 9: epoch_accuracy 10.897435897435898, epoch_loss 2.3019773287650867
# Round 2, cleint 5, epoch 10: epoch_accuracy 10.216346153846153, epoch_loss 2.3021831604150624
# Round 2, cleint 6, epoch 1: epoch_accuracy 11.798878205128204, epoch_loss 2.300910708231804
# Round 2, cleint 6, epoch 2: epoch_accuracy 12.19951923076923, epoch_loss 2.3001696268717446
# Round 2, cleint 6, epoch 3: epoch_accuracy 12.179487179487179, epoch_loss 2.2992972624607577
# Round 2, cleint 6, epoch 4: epoch_accuracy 12.439903846153847, epoch_loss 2.297549666502537
# Round 2, cleint 6, epoch 5: epoch_accuracy 12.35977564102564, epoch_loss 2.2950232334626026
# Round 2, cleint 6, epoch 6: epoch_accuracy 11.818910256410257, epoch_loss 2.2910967270533242
# Round 2, cleint 6, epoch 7: epoch_accuracy 11.698717948717949, epoch_loss 2.2835989945974107
# Round 2, cleint 6, epoch 8: epoch_accuracy 13.040865384615385, epoch_loss 2.2690520042028184
# Round 2, cleint 6, epoch 9: epoch_accuracy 15.044070512820513, epoch_loss 2.2432654943221655
# Round 2, cleint 6, epoch 10: epoch_accuracy 18.189102564102566, epoch_loss 2.2061366729247265
# Round 2, cleint 7, epoch 1: epoch_accuracy 11.55849358974359, epoch_loss 2.301427511068491
# Round 2, cleint 7, epoch 2: epoch_accuracy 11.959134615384615, epoch_loss 2.3006337789388804
# Round 2, cleint 7, epoch 3: epoch_accuracy 12.039262820512821, epoch_loss 2.2997035949658127
# Round 2, cleint 7, epoch 4: epoch_accuracy 12.319711538461538, epoch_loss 2.2982872816232534
# Round 2, cleint 7, epoch 5: epoch_accuracy 11.738782051282051, epoch_loss 2.2960062607740745
# Round 2, cleint 7, epoch 6: epoch_accuracy 11.618589743589743, epoch_loss 2.292525123327206
# Round 2, cleint 7, epoch 7: epoch_accuracy 12.299679487179487, epoch_loss 2.2858805442467713
# Round 2, cleint 7, epoch 8: epoch_accuracy 11.017628205128204, epoch_loss 2.2738656325218005
# Round 2, cleint 7, epoch 9: epoch_accuracy 15.384615384615385, epoch_loss 2.2498173132920876
# Round 2, cleint 7, epoch 10: epoch_accuracy 18.008814102564102, epoch_loss 2.20372527379256
# Round 2, cleint 8, epoch 1: epoch_accuracy 12.139423076923077, epoch_loss 2.3011281184661083
# Round 2, cleint 8, epoch 2: epoch_accuracy 12.259615384615385, epoch_loss 2.301071973947378
# Round 2, cleint 8, epoch 3: epoch_accuracy 11.999198717948717, epoch_loss 2.300067981084188
# Round 2, cleint 8, epoch 4: epoch_accuracy 11.598557692307692, epoch_loss 2.298796739333715
# Round 2, cleint 8, epoch 5: epoch_accuracy 11.41826923076923, epoch_loss 2.297334619057484
# Round 2, cleint 8, epoch 6: epoch_accuracy 12.039262820512821, epoch_loss 2.2943712167250805
# Round 2, cleint 8, epoch 7: epoch_accuracy 12.880608974358974, epoch_loss 2.289637131568713
# Round 2, cleint 8, epoch 8: epoch_accuracy 12.439903846153847, epoch_loss 2.280434501476777
# Round 2, cleint 8, epoch 9: epoch_accuracy 13.181089743589743, epoch_loss 2.2639356545912914
# Round 2, cleint 8, epoch 10: epoch_accuracy 16.746794871794872, epoch_loss 2.235145125633631
# Round 2, cleint 9, epoch 1: epoch_accuracy 12.219551282051283, epoch_loss 2.300958590629773
# Round 2, cleint 9, epoch 2: epoch_accuracy 12.239583333333334, epoch_loss 2.3005042473475137
# Round 2, cleint 9, epoch 3: epoch_accuracy 12.399839743589743, epoch_loss 2.2996837878838563
# Round 2, cleint 9, epoch 4: epoch_accuracy 12.780448717948717, epoch_loss 2.298355368467478
# Round 2, cleint 9, epoch 5: epoch_accuracy 12.299679487179487, epoch_loss 2.297333390284807
# Round 2, cleint 9, epoch 6: epoch_accuracy 11.959134615384615, epoch_loss 2.293968778390151
# Round 2, cleint 9, epoch 7: epoch_accuracy 13.12099358974359, epoch_loss 2.289076581979409
# Round 2, cleint 9, epoch 8: epoch_accuracy 12.760416666666666, epoch_loss 2.2815324465433755
# Round 2, cleint 9, epoch 9: epoch_accuracy 14.803685897435898, epoch_loss 2.2668618116623316
# Round 2, cleint 9, epoch 10: epoch_accuracy 16.626602564102566, epoch_loss 2.239163948939397
# Round 2, cleint 10, epoch 1: epoch_accuracy 11.438301282051283, epoch_loss 2.30136208045177
# Round 2, cleint 10, epoch 2: epoch_accuracy 11.618589743589743, epoch_loss 2.301010024853242
# Round 2, cleint 10, epoch 3: epoch_accuracy 12.620192307692308, epoch_loss 2.299986203511556
# Round 2, cleint 10, epoch 4: epoch_accuracy 12.219551282051283, epoch_loss 2.2986931739709315
# Round 2, cleint 10, epoch 5: epoch_accuracy 11.939102564102564, epoch_loss 2.2964658034153476
# Round 2, cleint 10, epoch 6: epoch_accuracy 12.64022435897436, epoch_loss 2.2940301406077848
# Round 2, cleint 10, epoch 7: epoch_accuracy 12.5, epoch_loss 2.288799273662078
# Round 2, cleint 10, epoch 8: epoch_accuracy 12.900641025641026, epoch_loss 2.2782400265718117
# Round 2, cleint 10, epoch 9: epoch_accuracy 14.242788461538462, epoch_loss 2.262044805746812
# Round 2, cleint 10, epoch 10: epoch_accuracy 16.72676282051282, epoch_loss 2.226102780073117
# Model's Round: 2, train accuracy of model: 13.884214743589746, train loss of model: 2.261984647848667
#
#
# Model's Round: 2, test accuracy of model: 20.71685303514377, test loss of model: 2.2404850016767606
#
#
# round 2 completed
# Round 3, cleint 1, epoch 1: epoch_accuracy 12.780448717948717, epoch_loss 2.292167752217024
# Round 3, cleint 1, epoch 2: epoch_accuracy 12.399839743589743, epoch_loss 2.2879717411139073
# Round 3, cleint 1, epoch 3: epoch_accuracy 13.361378205128204, epoch_loss 2.2825990945864945
# Round 3, cleint 1, epoch 4: epoch_accuracy 14.923878205128204, epoch_loss 2.2707256965148144
# Round 3, cleint 1, epoch 5: epoch_accuracy 14.503205128205128, epoch_loss 2.2582735954186854
# Round 3, cleint 1, epoch 6: epoch_accuracy 16.145833333333332, epoch_loss 2.2383985030345426
# Round 3, cleint 1, epoch 7: epoch_accuracy 17.047275641025642, epoch_loss 2.210414538016686
# Round 3, cleint 1, epoch 8: epoch_accuracy 20.753205128205128, epoch_loss 2.171838798584082
# Round 3, cleint 1, epoch 9: epoch_accuracy 21.654647435897434, epoch_loss 2.144250512123108
# Round 3, cleint 1, epoch 10: epoch_accuracy 22.35576923076923, epoch_loss 2.1259279189965663
# Round 3, cleint 2, epoch 1: epoch_accuracy 12.620192307692308, epoch_loss 2.2908295392990112
# Round 3, cleint 2, epoch 2: epoch_accuracy 13.221153846153847, epoch_loss 2.2878844371208777
# Round 3, cleint 2, epoch 3: epoch_accuracy 13.58173076923077, epoch_loss 2.2810853108381615
# Round 3, cleint 2, epoch 4: epoch_accuracy 14.36298076923077, epoch_loss 2.2715534766515098
# Round 3, cleint 2, epoch 5: epoch_accuracy 14.0625, epoch_loss 2.2579916226558194
# Round 3, cleint 2, epoch 6: epoch_accuracy 15.905448717948717, epoch_loss 2.2396236872061706
# Round 3, cleint 2, epoch 7: epoch_accuracy 17.78846153846154, epoch_loss 2.204557648071876
# Round 3, cleint 2, epoch 8: epoch_accuracy 20.372596153846153, epoch_loss 2.168435099797371
# Round 3, cleint 2, epoch 9: epoch_accuracy 20.072115384615383, epoch_loss 2.142860154310862
# Round 3, cleint 2, epoch 10: epoch_accuracy 22.916666666666668, epoch_loss 2.1201624396519785
# Round 3, cleint 3, epoch 1: epoch_accuracy 12.459935897435898, epoch_loss 2.292141999953832
# Round 3, cleint 3, epoch 2: epoch_accuracy 13.321314102564102, epoch_loss 2.2898010046054154
# Round 3, cleint 3, epoch 3: epoch_accuracy 13.76201923076923, epoch_loss 2.2811940816732554
# Round 3, cleint 3, epoch 4: epoch_accuracy 14.823717948717949, epoch_loss 2.27203613672501
# Round 3, cleint 3, epoch 5: epoch_accuracy 14.723557692307692, epoch_loss 2.259644878216279
# Round 3, cleint 3, epoch 6: epoch_accuracy 16.466346153846153, epoch_loss 2.2369290498586802
# Round 3, cleint 3, epoch 7: epoch_accuracy 18.209134615384617, epoch_loss 2.214365690182417
# Round 3, cleint 3, epoch 8: epoch_accuracy 20.63301282051282, epoch_loss 2.174976565898993
# Round 3, cleint 3, epoch 9: epoch_accuracy 21.213942307692307, epoch_loss 2.141856632171533
# Round 3, cleint 3, epoch 10: epoch_accuracy 22.536057692307693, epoch_loss 2.1295358401078444
# Round 3, cleint 4, epoch 1: epoch_accuracy 13.000801282051283, epoch_loss 2.2897244905814147
# Round 3, cleint 4, epoch 2: epoch_accuracy 13.381410256410257, epoch_loss 2.285470329798185
# Round 3, cleint 4, epoch 3: epoch_accuracy 13.621794871794872, epoch_loss 2.2803364594777427
# Round 3, cleint 4, epoch 4: epoch_accuracy 14.20272435897436, epoch_loss 2.2717350813058705
# Round 3, cleint 4, epoch 5: epoch_accuracy 14.803685897435898, epoch_loss 2.2590871927065725
# Round 3, cleint 4, epoch 6: epoch_accuracy 16.145833333333332, epoch_loss 2.235006998746823
# Round 3, cleint 4, epoch 7: epoch_accuracy 18.28926282051282, epoch_loss 2.198322030214163
# Round 3, cleint 4, epoch 8: epoch_accuracy 19.451121794871796, epoch_loss 2.168583848537543
# Round 3, cleint 4, epoch 9: epoch_accuracy 20.973557692307693, epoch_loss 2.131089549798232
# Round 3, cleint 4, epoch 10: epoch_accuracy 22.015224358974358, epoch_loss 2.117579412765992
# Round 3, cleint 5, epoch 1: epoch_accuracy 12.459935897435898, epoch_loss 2.2944298493556485
# Round 3, cleint 5, epoch 2: epoch_accuracy 12.459935897435898, epoch_loss 2.288332789372175
# Round 3, cleint 5, epoch 3: epoch_accuracy 13.802083333333334, epoch_loss 2.2825641448681173
# Round 3, cleint 5, epoch 4: epoch_accuracy 13.741987179487179, epoch_loss 2.2755662447366958
# Round 3, cleint 5, epoch 5: epoch_accuracy 14.743589743589743, epoch_loss 2.264224749345046
# Round 3, cleint 5, epoch 6: epoch_accuracy 15.965544871794872, epoch_loss 2.245773116747538
# Round 3, cleint 5, epoch 7: epoch_accuracy 17.1875, epoch_loss 2.221404790878296
# Round 3, cleint 5, epoch 8: epoch_accuracy 19.25080128205128, epoch_loss 2.191723401729877
# Round 3, cleint 5, epoch 9: epoch_accuracy 21.37419871794872, epoch_loss 2.157107418928391
# Round 3, cleint 5, epoch 10: epoch_accuracy 20.77323717948718, epoch_loss 2.1475381407982264
# Round 3, cleint 6, epoch 1: epoch_accuracy 17.127403846153847, epoch_loss 2.2533251689030576
# Round 3, cleint 6, epoch 2: epoch_accuracy 18.028846153846153, epoch_loss 2.2106150572116556
# Round 3, cleint 6, epoch 3: epoch_accuracy 20.432692307692307, epoch_loss 2.169450934116657
# Round 3, cleint 6, epoch 4: epoch_accuracy 22.47596153846154, epoch_loss 2.1277058109258995
# Round 3, cleint 6, epoch 5: epoch_accuracy 23.838141025641026, epoch_loss 2.0864855968035183
# Round 3, cleint 6, epoch 6: epoch_accuracy 25.96153846153846, epoch_loss 2.057964740655361
# Round 3, cleint 6, epoch 7: epoch_accuracy 25.701121794871796, epoch_loss 2.0389157029298635
# Round 3, cleint 6, epoch 8: epoch_accuracy 26.482371794871796, epoch_loss 2.0255601024016356
# Round 3, cleint 6, epoch 9: epoch_accuracy 27.283653846153847, epoch_loss 2.005156252628718
# Round 3, cleint 6, epoch 10: epoch_accuracy 26.782852564102566, epoch_loss 2.0015797523351817
# Round 3, cleint 7, epoch 1: epoch_accuracy 16.546474358974358, epoch_loss 2.254367831425789
# Round 3, cleint 7, epoch 2: epoch_accuracy 17.888621794871796, epoch_loss 2.2052585772978954
# Round 3, cleint 7, epoch 3: epoch_accuracy 20.452724358974358, epoch_loss 2.15912512021187
# Round 3, cleint 7, epoch 4: epoch_accuracy 23.697916666666668, epoch_loss 2.1044507989516625
# Round 3, cleint 7, epoch 5: epoch_accuracy 26.06169871794872, epoch_loss 2.055810361336439
# Round 3, cleint 7, epoch 6: epoch_accuracy 25.46073717948718, epoch_loss 2.0283945691891208
# Round 3, cleint 7, epoch 7: epoch_accuracy 26.001602564102566, epoch_loss 2.007929667448386
# Round 3, cleint 7, epoch 8: epoch_accuracy 27.203525641025642, epoch_loss 1.9939543452018347
# Round 3, cleint 7, epoch 9: epoch_accuracy 27.80448717948718, epoch_loss 1.9802637115502968
# Round 3, cleint 7, epoch 10: epoch_accuracy 28.365384615384617, epoch_loss 1.9659854769706726
# Round 3, cleint 8, epoch 1: epoch_accuracy 17.708333333333332, epoch_loss 2.2566088132369213
# Round 3, cleint 8, epoch 2: epoch_accuracy 18.26923076923077, epoch_loss 2.2177393344732432
# Round 3, cleint 8, epoch 3: epoch_accuracy 19.431089743589745, epoch_loss 2.177487911322178
# Round 3, cleint 8, epoch 4: epoch_accuracy 23.13701923076923, epoch_loss 2.132675586602627
# Round 3, cleint 8, epoch 5: epoch_accuracy 24.559294871794872, epoch_loss 2.0818699399630227
# Round 3, cleint 8, epoch 6: epoch_accuracy 25.681089743589745, epoch_loss 2.0496846391604495
# Round 3, cleint 8, epoch 7: epoch_accuracy 26.161858974358974, epoch_loss 2.0374789910438733
# Round 3, cleint 8, epoch 8: epoch_accuracy 25.921474358974358, epoch_loss 2.0314238484089193
# Round 3, cleint 8, epoch 9: epoch_accuracy 26.642628205128204, epoch_loss 2.0046074268145437
# Round 3, cleint 8, epoch 10: epoch_accuracy 27.123397435897434, epoch_loss 2.0018173089394202
# Round 3, cleint 9, epoch 1: epoch_accuracy 16.846955128205128, epoch_loss 2.260849274121798
# Round 3, cleint 9, epoch 2: epoch_accuracy 17.868589743589745, epoch_loss 2.222346333357004
# Round 3, cleint 9, epoch 3: epoch_accuracy 20.753205128205128, epoch_loss 2.17952072314727
# Round 3, cleint 9, epoch 4: epoch_accuracy 23.197115384615383, epoch_loss 2.1331897240418654
# Round 3, cleint 9, epoch 5: epoch_accuracy 24.158653846153847, epoch_loss 2.0843168741617446
# Round 3, cleint 9, epoch 6: epoch_accuracy 25.30048076923077, epoch_loss 2.049848498442234
# Round 3, cleint 9, epoch 7: epoch_accuracy 25.901442307692307, epoch_loss 2.0401781614010153
# Round 3, cleint 9, epoch 8: epoch_accuracy 26.782852564102566, epoch_loss 2.014274898247841
# Round 3, cleint 9, epoch 9: epoch_accuracy 26.88301282051282, epoch_loss 2.0059317977000504
# Round 3, cleint 9, epoch 10: epoch_accuracy 27.04326923076923, epoch_loss 1.9859498082063136
# Round 3, cleint 10, epoch 1: epoch_accuracy 16.326121794871796, epoch_loss 2.2569183233456735
# Round 3, cleint 10, epoch 2: epoch_accuracy 18.14903846153846, epoch_loss 2.2141637282493787
# Round 3, cleint 10, epoch 3: epoch_accuracy 20.01201923076923, epoch_loss 2.1724687875845494
# Round 3, cleint 10, epoch 4: epoch_accuracy 22.15544871794872, epoch_loss 2.1322559271103296
# Round 3, cleint 10, epoch 5: epoch_accuracy 23.71794871794872, epoch_loss 2.0859917173018823
# Round 3, cleint 10, epoch 6: epoch_accuracy 24.298878205128204, epoch_loss 2.053686724259303
# Round 3, cleint 10, epoch 7: epoch_accuracy 25.80128205128205, epoch_loss 2.037561771197197
# Round 3, cleint 10, epoch 8: epoch_accuracy 25.841346153846153, epoch_loss 2.020474605071239
# Round 3, cleint 10, epoch 9: epoch_accuracy 27.123397435897434, epoch_loss 2.009009268039312
# Round 3, cleint 10, epoch 10: epoch_accuracy 26.74278846153846, epoch_loss 1.9943479574643648
# Model's Round: 3, train accuracy of model: 24.665464743589745, train loss of model: 2.059042405623656
#
#
# Model's Round: 3, test accuracy of model: 26.6573482428115, test loss of model: 2.680536578638485
#
#
# round 3 completed
# Round 4, cleint 1, epoch 1: epoch_accuracy 22.115384615384617, epoch_loss 2.124329921526787
# Round 4, cleint 1, epoch 2: epoch_accuracy 22.616185897435898, epoch_loss 2.094884303899912
# Round 4, cleint 1, epoch 3: epoch_accuracy 24.579326923076923, epoch_loss 2.070752487732814
# Round 4, cleint 1, epoch 4: epoch_accuracy 23.59775641025641, epoch_loss 2.065718690554301
# Round 4, cleint 1, epoch 5: epoch_accuracy 25.02003205128205, epoch_loss 2.056596039197384
# Round 4, cleint 1, epoch 6: epoch_accuracy 25.0, epoch_loss 2.04533502077445
# Round 4, cleint 1, epoch 7: epoch_accuracy 25.260416666666668, epoch_loss 2.030725440917871
# Round 4, cleint 1, epoch 8: epoch_accuracy 26.181891025641026, epoch_loss 2.0296572125875034
# Round 4, cleint 1, epoch 9: epoch_accuracy 26.522435897435898, epoch_loss 2.020163337389628
# Round 4, cleint 1, epoch 10: epoch_accuracy 25.861378205128204, epoch_loss 2.0160471567740808
# Round 4, cleint 2, epoch 1: epoch_accuracy 22.115384615384617, epoch_loss 2.1229610641797385
# Round 4, cleint 2, epoch 2: epoch_accuracy 22.63621794871795, epoch_loss 2.0910312808476963
# Round 4, cleint 2, epoch 3: epoch_accuracy 23.41746794871795, epoch_loss 2.0804185011448006
# Round 4, cleint 2, epoch 4: epoch_accuracy 24.078525641025642, epoch_loss 2.075669229030609
# Round 4, cleint 2, epoch 5: epoch_accuracy 24.97996794871795, epoch_loss 2.064736219552847
# Round 4, cleint 2, epoch 6: epoch_accuracy 25.400641025641026, epoch_loss 2.055525087393247
# Round 4, cleint 2, epoch 7: epoch_accuracy 26.06169871794872, epoch_loss 2.0482760530251722
# Round 4, cleint 2, epoch 8: epoch_accuracy 26.482371794871796, epoch_loss 2.0316828412887378
# Round 4, cleint 2, epoch 9: epoch_accuracy 27.003205128205128, epoch_loss 2.0235252365087852
# Round 4, cleint 2, epoch 10: epoch_accuracy 26.141826923076923, epoch_loss 2.0329489891345682
# Round 4, cleint 3, epoch 1: epoch_accuracy 22.736378205128204, epoch_loss 2.1232311679766727
# Round 4, cleint 3, epoch 2: epoch_accuracy 23.297275641025642, epoch_loss 2.0980307383415027
# Round 4, cleint 3, epoch 3: epoch_accuracy 24.759615384615383, epoch_loss 2.072249030455565
# Round 4, cleint 3, epoch 4: epoch_accuracy 24.138621794871796, epoch_loss 2.069994029326317
# Round 4, cleint 3, epoch 5: epoch_accuracy 25.220352564102566, epoch_loss 2.0570259659718246
# Round 4, cleint 3, epoch 6: epoch_accuracy 25.60096153846154, epoch_loss 2.0502613354951906
# Round 4, cleint 3, epoch 7: epoch_accuracy 25.641025641025642, epoch_loss 2.0337353960061684
# Round 4, cleint 3, epoch 8: epoch_accuracy 26.10176282051282, epoch_loss 2.0286346765664907
# Round 4, cleint 3, epoch 9: epoch_accuracy 26.762820512820515, epoch_loss 2.023503601551056
# Round 4, cleint 3, epoch 10: epoch_accuracy 26.221955128205128, epoch_loss 2.0219819163664794
# Round 4, cleint 4, epoch 1: epoch_accuracy 22.93669871794872, epoch_loss 2.10936240813671
# Round 4, cleint 4, epoch 2: epoch_accuracy 22.896634615384617, epoch_loss 2.0956900272613916
# Round 4, cleint 4, epoch 3: epoch_accuracy 24.178685897435898, epoch_loss 2.0762839133922872
# Round 4, cleint 4, epoch 4: epoch_accuracy 24.03846153846154, epoch_loss 2.0622005340380545
# Round 4, cleint 4, epoch 5: epoch_accuracy 24.919871794871796, epoch_loss 2.0592799522937875
# Round 4, cleint 4, epoch 6: epoch_accuracy 25.380608974358974, epoch_loss 2.0496174066494675
# Round 4, cleint 4, epoch 7: epoch_accuracy 25.60096153846154, epoch_loss 2.0262470810841293
# Round 4, cleint 4, epoch 8: epoch_accuracy 25.841346153846153, epoch_loss 2.027861541662461
# Round 4, cleint 4, epoch 9: epoch_accuracy 26.822916666666668, epoch_loss 2.0270451719944296
# Round 4, cleint 4, epoch 10: epoch_accuracy 27.083333333333332, epoch_loss 2.012177364948468
# Round 4, cleint 5, epoch 1: epoch_accuracy 21.915064102564102, epoch_loss 2.1254012172038736
# Round 4, cleint 5, epoch 2: epoch_accuracy 22.395833333333332, epoch_loss 2.1063325726068935
# Round 4, cleint 5, epoch 3: epoch_accuracy 23.577724358974358, epoch_loss 2.0807984929818373
# Round 4, cleint 5, epoch 4: epoch_accuracy 24.078525641025642, epoch_loss 2.065444929477496
# Round 4, cleint 5, epoch 5: epoch_accuracy 24.258814102564102, epoch_loss 2.062862139481765
# Round 4, cleint 5, epoch 6: epoch_accuracy 25.18028846153846, epoch_loss 2.0602088433045607
# Round 4, cleint 5, epoch 7: epoch_accuracy 24.81971153846154, epoch_loss 2.0654555467458873
# Round 4, cleint 5, epoch 8: epoch_accuracy 25.94150641025641, epoch_loss 2.0339030852684608
# Round 4, cleint 5, epoch 9: epoch_accuracy 26.782852564102566, epoch_loss 2.0240471225518446
# Round 4, cleint 5, epoch 10: epoch_accuracy 25.48076923076923, epoch_loss 2.0400693584711123
# Round 4, cleint 6, epoch 1: epoch_accuracy 26.5625, epoch_loss 2.026102440479474
# Round 4, cleint 6, epoch 2: epoch_accuracy 26.943108974358974, epoch_loss 2.0056094175729995
# Round 4, cleint 6, epoch 3: epoch_accuracy 27.904647435897434, epoch_loss 1.9867500830919316
# Round 4, cleint 6, epoch 4: epoch_accuracy 28.325320512820515, epoch_loss 1.9845515993925242
# Round 4, cleint 6, epoch 5: epoch_accuracy 29.50721153846154, epoch_loss 1.9655753389382973
# Round 4, cleint 6, epoch 6: epoch_accuracy 29.727564102564102, epoch_loss 1.9505823376851203
# Round 4, cleint 6, epoch 7: epoch_accuracy 29.907852564102566, epoch_loss 1.949807998461601
# Round 4, cleint 6, epoch 8: epoch_accuracy 31.27003205128205, epoch_loss 1.9357598316975129
# Round 4, cleint 6, epoch 9: epoch_accuracy 30.248397435897434, epoch_loss 1.9294747740794451
# Round 4, cleint 6, epoch 10: epoch_accuracy 31.450320512820515, epoch_loss 1.9071177733250153
# Round 4, cleint 7, epoch 1: epoch_accuracy 27.283653846153847, epoch_loss 1.9969312181839576
# Round 4, cleint 7, epoch 2: epoch_accuracy 27.924679487179485, epoch_loss 1.9776535981740706
# Round 4, cleint 7, epoch 3: epoch_accuracy 27.82451923076923, epoch_loss 1.9618692780152345
# Round 4, cleint 7, epoch 4: epoch_accuracy 28.946314102564102, epoch_loss 1.949789930612613
# Round 4, cleint 7, epoch 5: epoch_accuracy 29.427083333333332, epoch_loss 1.9373116386242402
# Round 4, cleint 7, epoch 6: epoch_accuracy 30.268429487179485, epoch_loss 1.9221189358295538
# Round 4, cleint 7, epoch 7: epoch_accuracy 30.348557692307693, epoch_loss 1.9174793377900734
# Round 4, cleint 7, epoch 8: epoch_accuracy 31.25, epoch_loss 1.905538103519342
# Round 4, cleint 7, epoch 9: epoch_accuracy 30.729166666666668, epoch_loss 1.893172556009048
# Round 4, cleint 7, epoch 10: epoch_accuracy 32.111378205128204, epoch_loss 1.8741208849809108
# Round 4, cleint 8, epoch 1: epoch_accuracy 26.963141025641026, epoch_loss 2.015283948335892
# Round 4, cleint 8, epoch 2: epoch_accuracy 27.544070512820515, epoch_loss 2.0061184611075964
# Round 4, cleint 8, epoch 3: epoch_accuracy 27.724358974358974, epoch_loss 1.9909926775174263
# Round 4, cleint 8, epoch 4: epoch_accuracy 28.205128205128204, epoch_loss 1.973811386487423
# Round 4, cleint 8, epoch 5: epoch_accuracy 29.22676282051282, epoch_loss 1.9631673403275318
# Round 4, cleint 8, epoch 6: epoch_accuracy 29.246794871794872, epoch_loss 1.9542161791752546
# Round 4, cleint 8, epoch 7: epoch_accuracy 28.90625, epoch_loss 1.9466220950468993
# Round 4, cleint 8, epoch 8: epoch_accuracy 30.76923076923077, epoch_loss 1.9299196891295605
# Round 4, cleint 8, epoch 9: epoch_accuracy 30.809294871794872, epoch_loss 1.9213813375204036
# Round 4, cleint 8, epoch 10: epoch_accuracy 31.08974358974359, epoch_loss 1.9031907396438794
# Round 4, cleint 9, epoch 1: epoch_accuracy 26.06169871794872, epoch_loss 2.025069618836427
# Round 4, cleint 9, epoch 2: epoch_accuracy 26.58253205128205, epoch_loss 2.0031470442429566
# Round 4, cleint 9, epoch 3: epoch_accuracy 28.565705128205128, epoch_loss 1.9818396797546973
# Round 4, cleint 9, epoch 4: epoch_accuracy 28.30528846153846, epoch_loss 1.9720949500035017
# Round 4, cleint 9, epoch 5: epoch_accuracy 28.72596153846154, epoch_loss 1.96350503884829
# Round 4, cleint 9, epoch 6: epoch_accuracy 30.78926282051282, epoch_loss 1.9398537201759143
# Round 4, cleint 9, epoch 7: epoch_accuracy 30.268429487179485, epoch_loss 1.9326479114018953
# Round 4, cleint 9, epoch 8: epoch_accuracy 31.149839743589745, epoch_loss 1.9108778543961353
# Round 4, cleint 9, epoch 9: epoch_accuracy 31.27003205128205, epoch_loss 1.9095934537740855
# Round 4, cleint 9, epoch 10: epoch_accuracy 30.849358974358974, epoch_loss 1.8958817154933245
# Round 4, cleint 10, epoch 1: epoch_accuracy 25.62099358974359, epoch_loss 2.020835071037977
# Round 4, cleint 10, epoch 2: epoch_accuracy 26.5625, epoch_loss 1.999550761320652
# Round 4, cleint 10, epoch 3: epoch_accuracy 26.983173076923077, epoch_loss 1.9897981194349437
# Round 4, cleint 10, epoch 4: epoch_accuracy 27.66426282051282, epoch_loss 1.9794325904968457
# Round 4, cleint 10, epoch 5: epoch_accuracy 27.904647435897434, epoch_loss 1.9626549971409333
# Round 4, cleint 10, epoch 6: epoch_accuracy 28.084935897435898, epoch_loss 1.9536882073451312
# Round 4, cleint 10, epoch 7: epoch_accuracy 29.18669871794872, epoch_loss 1.9362897047629724
# Round 4, cleint 10, epoch 8: epoch_accuracy 29.36698717948718, epoch_loss 1.9262459476788838
# Round 4, cleint 10, epoch 9: epoch_accuracy 30.428685897435898, epoch_loss 1.9112249383559594
# Round 4, cleint 10, epoch 10: epoch_accuracy 31.149839743589745, epoch_loss 1.8903821676205366
# Model's Round: 4, train accuracy of model: 28.74399038461538, train loss of model: 1.9593918066758378
#
#
# Model's Round: 4, test accuracy of model: 29.32308306709265, test loss of model: 2.7536081685044893
#
#
# round 4 completed
# Round 5, cleint 1, epoch 1: epoch_accuracy 24.97996794871795, epoch_loss 2.0412797178977575
# Round 5, cleint 1, epoch 2: epoch_accuracy 26.302083333333332, epoch_loss 2.0162050479497666
# Round 5, cleint 1, epoch 3: epoch_accuracy 26.54246794871795, epoch_loss 2.006345482972952
# Round 5, cleint 1, epoch 4: epoch_accuracy 26.5625, epoch_loss 1.9944377144177754
# Round 5, cleint 1, epoch 5: epoch_accuracy 26.983173076923077, epoch_loss 2.0039866260993175
# Round 5, cleint 1, epoch 6: epoch_accuracy 27.443910256410255, epoch_loss 1.9898346142891126
# Round 5, cleint 1, epoch 7: epoch_accuracy 27.96474358974359, epoch_loss 1.9693660644384532
# Round 5, cleint 1, epoch 8: epoch_accuracy 28.60576923076923, epoch_loss 1.955353027735001
# Round 5, cleint 1, epoch 9: epoch_accuracy 28.74599358974359, epoch_loss 1.9668416105783904
# Round 5, cleint 1, epoch 10: epoch_accuracy 29.6875, epoch_loss 1.9494143372926958
# Round 5, cleint 2, epoch 1: epoch_accuracy 25.60096153846154, epoch_loss 2.0399443232096157
# Round 5, cleint 2, epoch 2: epoch_accuracy 26.642628205128204, epoch_loss 2.0214894398664818
# Round 5, cleint 2, epoch 3: epoch_accuracy 26.482371794871796, epoch_loss 2.0294234233024793
# Round 5, cleint 2, epoch 4: epoch_accuracy 27.203525641025642, epoch_loss 2.011175365020067
# Round 5, cleint 2, epoch 5: epoch_accuracy 28.60576923076923, epoch_loss 1.9944473229921782
# Round 5, cleint 2, epoch 6: epoch_accuracy 28.044871794871796, epoch_loss 1.992349922657013
# Round 5, cleint 2, epoch 7: epoch_accuracy 28.74599358974359, epoch_loss 1.9781450247153258
# Round 5, cleint 2, epoch 8: epoch_accuracy 28.966346153846153, epoch_loss 1.9801706641148298
# Round 5, cleint 2, epoch 9: epoch_accuracy 28.866185897435898, epoch_loss 1.9766937799942799
# Round 5, cleint 2, epoch 10: epoch_accuracy 29.70753205128205, epoch_loss 1.9652238824428656
# Round 5, cleint 3, epoch 1: epoch_accuracy 25.240384615384617, epoch_loss 2.046812265347212
# Round 5, cleint 3, epoch 2: epoch_accuracy 25.841346153846153, epoch_loss 2.023530195920895
# Round 5, cleint 3, epoch 3: epoch_accuracy 25.50080128205128, epoch_loss 2.0232939445055447
# Round 5, cleint 3, epoch 4: epoch_accuracy 26.822916666666668, epoch_loss 2.0000551832027926
# Round 5, cleint 3, epoch 5: epoch_accuracy 27.263621794871796, epoch_loss 1.9984020651915135
# Round 5, cleint 3, epoch 6: epoch_accuracy 27.80448717948718, epoch_loss 1.9941313220904424
# Round 5, cleint 3, epoch 7: epoch_accuracy 27.924679487179485, epoch_loss 1.9751729766527812
# Round 5, cleint 3, epoch 8: epoch_accuracy 28.685897435897434, epoch_loss 1.9635714154977064
# Round 5, cleint 3, epoch 9: epoch_accuracy 28.024839743589745, epoch_loss 1.9649937871174934
# Round 5, cleint 3, epoch 10: epoch_accuracy 29.607371794871796, epoch_loss 1.95279565682778
# Round 5, cleint 4, epoch 1: epoch_accuracy 26.221955128205128, epoch_loss 2.0471876554000072
# Round 5, cleint 4, epoch 2: epoch_accuracy 26.422275641025642, epoch_loss 2.02833581276429
# Round 5, cleint 4, epoch 3: epoch_accuracy 27.02323717948718, epoch_loss 2.005232262305724
# Round 5, cleint 4, epoch 4: epoch_accuracy 27.82451923076923, epoch_loss 1.9932204775321178
# Round 5, cleint 4, epoch 5: epoch_accuracy 28.505608974358974, epoch_loss 1.9827371499477289
# Round 5, cleint 4, epoch 6: epoch_accuracy 27.82451923076923, epoch_loss 1.992102324962616
# Round 5, cleint 4, epoch 7: epoch_accuracy 29.487179487179485, epoch_loss 1.959044126363901
# Round 5, cleint 4, epoch 8: epoch_accuracy 28.385416666666668, epoch_loss 1.9602518738844457
# Round 5, cleint 4, epoch 9: epoch_accuracy 28.645833333333332, epoch_loss 1.9529959238492525
# Round 5, cleint 4, epoch 10: epoch_accuracy 30.16826923076923, epoch_loss 1.9468733546061394
# Round 5, cleint 5, epoch 1: epoch_accuracy 25.380608974358974, epoch_loss 2.048029758991339
# Round 5, cleint 5, epoch 2: epoch_accuracy 26.522435897435898, epoch_loss 2.026956692720071
# Round 5, cleint 5, epoch 3: epoch_accuracy 26.001602564102566, epoch_loss 2.024721981623234
# Round 5, cleint 5, epoch 4: epoch_accuracy 26.502403846153847, epoch_loss 2.0073792796868544
# Round 5, cleint 5, epoch 5: epoch_accuracy 27.263621794871796, epoch_loss 2.004350810478895
# Round 5, cleint 5, epoch 6: epoch_accuracy 26.86298076923077, epoch_loss 1.9933081269264221
# Round 5, cleint 5, epoch 7: epoch_accuracy 28.505608974358974, epoch_loss 1.9833960548425331
# Round 5, cleint 5, epoch 8: epoch_accuracy 29.286858974358974, epoch_loss 1.9761487413675358
# Round 5, cleint 5, epoch 9: epoch_accuracy 29.467147435897434, epoch_loss 1.961881636044918
# Round 5, cleint 5, epoch 10: epoch_accuracy 29.84775641025641, epoch_loss 1.946841102380019
# Round 5, cleint 6, epoch 1: epoch_accuracy 30.849358974358974, epoch_loss 1.9334706832201054
# Round 5, cleint 6, epoch 2: epoch_accuracy 30.608974358974358, epoch_loss 1.9230961753771856
# Round 5, cleint 6, epoch 3: epoch_accuracy 32.21153846153846, epoch_loss 1.8958127651459131
# Round 5, cleint 6, epoch 4: epoch_accuracy 32.41185897435897, epoch_loss 1.8921195574295826
# Round 5, cleint 6, epoch 5: epoch_accuracy 32.57211538461539, epoch_loss 1.8761883301612658
# Round 5, cleint 6, epoch 6: epoch_accuracy 33.23317307692308, epoch_loss 1.8591271256789184
# Round 5, cleint 6, epoch 7: epoch_accuracy 33.71394230769231, epoch_loss 1.8496271662223034
# Round 5, cleint 6, epoch 8: epoch_accuracy 34.83573717948718, epoch_loss 1.8396236178202507
# Round 5, cleint 6, epoch 9: epoch_accuracy 34.77564102564103, epoch_loss 1.8207032741644444
# Round 5, cleint 6, epoch 10: epoch_accuracy 34.93589743589744, epoch_loss 1.8163337738086016
# Round 5, cleint 7, epoch 1: epoch_accuracy 30.548878205128204, epoch_loss 1.90101874485994
# Round 5, cleint 7, epoch 2: epoch_accuracy 31.350160256410255, epoch_loss 1.8845367217675233
# Round 5, cleint 7, epoch 3: epoch_accuracy 32.87259615384615, epoch_loss 1.867035373663291
# Round 5, cleint 7, epoch 4: epoch_accuracy 32.57211538461539, epoch_loss 1.858549917355562
# Round 5, cleint 7, epoch 5: epoch_accuracy 33.11298076923077, epoch_loss 1.8343631640458717
# Round 5, cleint 7, epoch 6: epoch_accuracy 32.97275641025641, epoch_loss 1.8315335359328833
# Round 5, cleint 7, epoch 7: epoch_accuracy 33.93429487179487, epoch_loss 1.8240707256855109
# Round 5, cleint 7, epoch 8: epoch_accuracy 34.71554487179487, epoch_loss 1.8147553557004683
# Round 5, cleint 7, epoch 9: epoch_accuracy 35.076121794871796, epoch_loss 1.7962748622282958
# Round 5, cleint 7, epoch 10: epoch_accuracy 35.53685897435897, epoch_loss 1.7948345297422164
# Round 5, cleint 8, epoch 1: epoch_accuracy 30.14823717948718, epoch_loss 1.940720490920238
# Round 5, cleint 8, epoch 2: epoch_accuracy 31.029647435897434, epoch_loss 1.921933528704521
# Round 5, cleint 8, epoch 3: epoch_accuracy 31.009615384615383, epoch_loss 1.904929335300739
# Round 5, cleint 8, epoch 4: epoch_accuracy 31.85096153846154, epoch_loss 1.8872324839616432
# Round 5, cleint 8, epoch 5: epoch_accuracy 32.21153846153846, epoch_loss 1.8774739320461566
# Round 5, cleint 8, epoch 6: epoch_accuracy 32.33173076923077, epoch_loss 1.8670024596727812
# Round 5, cleint 8, epoch 7: epoch_accuracy 33.19310897435897, epoch_loss 1.8505095350436676
# Round 5, cleint 8, epoch 8: epoch_accuracy 33.91426282051282, epoch_loss 1.841862638791402
# Round 5, cleint 8, epoch 9: epoch_accuracy 35.15625, epoch_loss 1.822251749344361
# Round 5, cleint 8, epoch 10: epoch_accuracy 33.99439102564103, epoch_loss 1.8165041972429326
# Round 5, cleint 9, epoch 1: epoch_accuracy 31.049679487179485, epoch_loss 1.9220368892718585
# Round 5, cleint 9, epoch 2: epoch_accuracy 31.891025641025642, epoch_loss 1.9034056816345606
# Round 5, cleint 9, epoch 3: epoch_accuracy 32.111378205128204, epoch_loss 1.8959776759147644
# Round 5, cleint 9, epoch 4: epoch_accuracy 32.63221153846154, epoch_loss 1.8830949679399147
# Round 5, cleint 9, epoch 5: epoch_accuracy 33.072916666666664, epoch_loss 1.868143284932161
# Round 5, cleint 9, epoch 6: epoch_accuracy 33.072916666666664, epoch_loss 1.8492721884678571
# Round 5, cleint 9, epoch 7: epoch_accuracy 33.99439102564103, epoch_loss 1.8444060331735856
# Round 5, cleint 9, epoch 8: epoch_accuracy 34.3349358974359, epoch_loss 1.8218112007165566
# Round 5, cleint 9, epoch 9: epoch_accuracy 34.99599358974359, epoch_loss 1.8171947583174095
# Round 5, cleint 9, epoch 10: epoch_accuracy 35.076121794871796, epoch_loss 1.8225337924101415
# Round 5, cleint 10, epoch 1: epoch_accuracy 29.86778846153846, epoch_loss 1.9287570867782984
# Round 5, cleint 10, epoch 2: epoch_accuracy 30.76923076923077, epoch_loss 1.9116847729071593
# Round 5, cleint 10, epoch 3: epoch_accuracy 31.390224358974358, epoch_loss 1.893758779917008
# Round 5, cleint 10, epoch 4: epoch_accuracy 31.73076923076923, epoch_loss 1.8897952345701365
# Round 5, cleint 10, epoch 5: epoch_accuracy 32.39182692307692, epoch_loss 1.8713501691818237
# Round 5, cleint 10, epoch 6: epoch_accuracy 33.81410256410256, epoch_loss 1.8599627094391065
# Round 5, cleint 10, epoch 7: epoch_accuracy 33.03285256410256, epoch_loss 1.8424298625725966
# Round 5, cleint 10, epoch 8: epoch_accuracy 34.455128205128204, epoch_loss 1.8321615717349908
# Round 5, cleint 10, epoch 9: epoch_accuracy 33.89423076923077, epoch_loss 1.8176462405767195
# Round 5, cleint 10, epoch 10: epoch_accuracy 34.895833333333336, epoch_loss 1.8138264646896949
# Model's Round: 5, train accuracy of model: 32.345753205128204, train loss of model: 1.8825181091443084
#
#
# Model's Round: 5, test accuracy of model: 32.56789137380192, test loss of model: 2.8321870432113307
#
#
# round 5 completed
# Round 6, cleint 1, epoch 1: epoch_accuracy 28.265224358974358, epoch_loss 1.9707167882185717
# Round 6, cleint 1, epoch 2: epoch_accuracy 28.345352564102566, epoch_loss 1.9511114282485766
# Round 6, cleint 1, epoch 3: epoch_accuracy 30.568910256410255, epoch_loss 1.922540245912014
# ...
# Round 29, cleint 4, epoch 5: epoch_accuracy 57.61217948717949, epoch_loss 1.1786057192545671
# Round 29, cleint 4, epoch 6: epoch_accuracy 58.19310897435897, epoch_loss 1.1808911111110296
# Round 29, cleint 4, epoch 7: epoch_accuracy 59.81570512820513, epoch_loss 1.113663110213402
# Round 29, cleint 4, epoch 8: epoch_accuracy 61.037660256410255, epoch_loss 1.0841202185704157
# Round 29, cleint 4, epoch 9: epoch_accuracy 61.93910256410256, epoch_loss 1.076235953049782
# Round 29, cleint 4, epoch 10: epoch_accuracy 63.44150641025641, epoch_loss 1.0296295239375188
# Round 29, cleint 5, epoch 1: epoch_accuracy 52.34375, epoch_loss 1.359076941624666
# Round 29, cleint 5, epoch 2: epoch_accuracy 52.80448717948718, epoch_loss 1.3015163984054174
# Round 29, cleint 5, epoch 3: epoch_accuracy 55.00801282051282, epoch_loss 1.2615152230629554
# Round 29, cleint 5, epoch 4: epoch_accuracy 56.06971153846154, epoch_loss 1.2271500245118752
# Round 29, cleint 5, epoch 5: epoch_accuracy 57.49198717948718, epoch_loss 1.1843843926221898
# Round 29, cleint 5, epoch 6: epoch_accuracy 57.8525641025641, epoch_loss 1.188998328569608
# Round 29, cleint 5, epoch 7: epoch_accuracy 60.57692307692308, epoch_loss 1.1284933991921253
# Round 29, cleint 5, epoch 8: epoch_accuracy 60.71714743589744, epoch_loss 1.1064774829607744
# Round 29, cleint 5, epoch 9: epoch_accuracy 62.17948717948718, epoch_loss 1.0680054770066187
# Round 29, cleint 5, epoch 10: epoch_accuracy 62.219551282051285, epoch_loss 1.066991075491294
# Round 29, cleint 6, epoch 1: epoch_accuracy 58.53365384615385, epoch_loss 1.1624721708970192
# Round 29, cleint 6, epoch 2: epoch_accuracy 60.1963141025641, epoch_loss 1.0881682145289886
# Round 29, cleint 6, epoch 3: epoch_accuracy 63.06089743589744, epoch_loss 1.0303826737098205
# Round 29, cleint 6, epoch 4: epoch_accuracy 62.70032051282051, epoch_loss 1.0077293461714036
# Round 29, cleint 6, epoch 5: epoch_accuracy 63.962339743589745, epoch_loss 0.9732121221530132
# Round 29, cleint 6, epoch 6: epoch_accuracy 66.26602564102564, epoch_loss 0.9238764338004284
# Round 29, cleint 6, epoch 7: epoch_accuracy 66.4463141025641, epoch_loss 0.8995408347019782
# Round 29, cleint 6, epoch 8: epoch_accuracy 68.75, epoch_loss 0.8683863243995569
# Round 29, cleint 6, epoch 9: epoch_accuracy 68.50961538461539, epoch_loss 0.8691561650007199
# Round 29, cleint 6, epoch 10: epoch_accuracy 70.57291666666667, epoch_loss 0.8341209529302059
# Round 29, cleint 7, epoch 1: epoch_accuracy 59.094551282051285, epoch_loss 1.1425190201172462
# Round 29, cleint 7, epoch 2: epoch_accuracy 60.9775641025641, epoch_loss 1.0710376730332007
# Round 29, cleint 7, epoch 3: epoch_accuracy 62.90064102564103, epoch_loss 1.0227800263808324
# Round 29, cleint 7, epoch 4: epoch_accuracy 64.20272435897436, epoch_loss 0.9877751989242358
# Round 29, cleint 7, epoch 5: epoch_accuracy 66.22596153846153, epoch_loss 0.9393183023501666
# Round 29, cleint 7, epoch 6: epoch_accuracy 66.74679487179488, epoch_loss 0.9142055824781076
# Round 29, cleint 7, epoch 7: epoch_accuracy 67.66826923076923, epoch_loss 0.8829299754057175
# Round 29, cleint 7, epoch 8: epoch_accuracy 68.93028846153847, epoch_loss 0.8625851105421017
# Round 29, cleint 7, epoch 9: epoch_accuracy 69.71153846153847, epoch_loss 0.8448919455210367
# Round 29, cleint 7, epoch 10: epoch_accuracy 69.85176282051282, epoch_loss 0.8203872128939017
# Round 29, cleint 8, epoch 1: epoch_accuracy 59.05448717948718, epoch_loss 1.1505802411299486
# Round 29, cleint 8, epoch 2: epoch_accuracy 61.05769230769231, epoch_loss 1.066661856113336
# Round 29, cleint 8, epoch 3: epoch_accuracy 63.06089743589744, epoch_loss 1.0289343396822612
# Round 29, cleint 8, epoch 4: epoch_accuracy 63.782051282051285, epoch_loss 0.9990622187272097
# Round 29, cleint 8, epoch 5: epoch_accuracy 64.66346153846153, epoch_loss 0.9724105397860209
# Round 29, cleint 8, epoch 6: epoch_accuracy 65.64503205128206, epoch_loss 0.9376031641776745
# Round 29, cleint 8, epoch 7: epoch_accuracy 67.52804487179488, epoch_loss 0.8989585362947904
# Round 29, cleint 8, epoch 8: epoch_accuracy 68.77003205128206, epoch_loss 0.8573631048202515
# Round 29, cleint 8, epoch 9: epoch_accuracy 69.47115384615384, epoch_loss 0.8427798106120183
# Round 29, cleint 8, epoch 10: epoch_accuracy 70.1923076923077, epoch_loss 0.8247441339951295
# Round 29, cleint 9, epoch 1: epoch_accuracy 58.93429487179487, epoch_loss 1.1433274776507647
# Round 29, cleint 9, epoch 2: epoch_accuracy 61.979166666666664, epoch_loss 1.0590229271314082
# Round 29, cleint 9, epoch 3: epoch_accuracy 62.94070512820513, epoch_loss 1.0228135119646022
# Round 29, cleint 9, epoch 4: epoch_accuracy 64.52323717948718, epoch_loss 0.9813178059382316
# Round 29, cleint 9, epoch 5: epoch_accuracy 65.14423076923077, epoch_loss 0.9722802547308115
# Round 29, cleint 9, epoch 6: epoch_accuracy 66.98717948717949, epoch_loss 0.9219313034644494
# Round 29, cleint 9, epoch 7: epoch_accuracy 67.1875, epoch_loss 0.9075756019506699
# Round 29, cleint 9, epoch 8: epoch_accuracy 69.4911858974359, epoch_loss 0.8517611240729307
# Round 29, cleint 9, epoch 9: epoch_accuracy 69.5713141025641, epoch_loss 0.829362921225719
# Round 29, cleint 9, epoch 10: epoch_accuracy 69.87179487179488, epoch_loss 0.8086300912575844
# Round 29, cleint 10, epoch 1: epoch_accuracy 59.21474358974359, epoch_loss 1.1462644789463434
# Round 29, cleint 10, epoch 2: epoch_accuracy 60.69711538461539, epoch_loss 1.0825316944183447
# Round 29, cleint 10, epoch 3: epoch_accuracy 62.62019230769231, epoch_loss 1.0270735919475555
# Round 29, cleint 10, epoch 4: epoch_accuracy 64.90384615384616, epoch_loss 0.9877185691625644
# Round 29, cleint 10, epoch 5: epoch_accuracy 65.82532051282051, epoch_loss 0.9515360647287124
# Round 29, cleint 10, epoch 6: epoch_accuracy 68.22916666666667, epoch_loss 0.9022898926184728
# Round 29, cleint 10, epoch 7: epoch_accuracy 68.14903846153847, epoch_loss 0.8908625497267797
# Round 29, cleint 10, epoch 8: epoch_accuracy 68.72996794871794, epoch_loss 0.8586648656771734
# Round 29, cleint 10, epoch 9: epoch_accuracy 70.2323717948718, epoch_loss 0.8364513959640112
# Round 29, cleint 10, epoch 10: epoch_accuracy 70.81330128205128, epoch_loss 0.8136138877807519
# Model's Round: 29, train accuracy of model: 66.61458333333334, train loss of model: 0.929717234044503
#
#
# Model's Round: 29, test accuracy of model: 43.680111821086264, test loss of model: 3.4934596977294823
#
#
# round 29 completed
# Round 30, cleint 1, epoch 1: epoch_accuracy 51.302083333333336, epoch_loss 1.3505008618036907
# Round 30, cleint 1, epoch 2: epoch_accuracy 54.90785256410256, epoch_loss 1.2738085901125884
# Round 30, cleint 1, epoch 3: epoch_accuracy 55.48878205128205, epoch_loss 1.2496879047308214
# Round 30, cleint 1, epoch 4: epoch_accuracy 56.49038461538461, epoch_loss 1.197054501527395
# Round 30, cleint 1, epoch 5: epoch_accuracy 58.43349358974359, epoch_loss 1.1543380449979732
# Round 30, cleint 1, epoch 6: epoch_accuracy 60.21634615384615, epoch_loss 1.124376321450258
# Round 30, cleint 1, epoch 7: epoch_accuracy 60.657051282051285, epoch_loss 1.090568876419312
# Round 30, cleint 1, epoch 8: epoch_accuracy 62.15945512820513, epoch_loss 1.0627116644993806
# Round 30, cleint 1, epoch 9: epoch_accuracy 63.2411858974359, epoch_loss 1.0255917723362262
# Round 30, cleint 1, epoch 10: epoch_accuracy 63.76201923076923, epoch_loss 0.989044460730675
# Round 30, cleint 2, epoch 1: epoch_accuracy 53.385416666666664, epoch_loss 1.3356725497123523
# Round 30, cleint 2, epoch 2: epoch_accuracy 54.20673076923077, epoch_loss 1.2847741865194762
# Round 30, cleint 2, epoch 3: epoch_accuracy 55.70913461538461, epoch_loss 1.2359104851881664
# Round 30, cleint 2, epoch 4: epoch_accuracy 57.8125, epoch_loss 1.1820771273894188
# Round 30, cleint 2, epoch 5: epoch_accuracy 58.97435897435897, epoch_loss 1.1613857463384285
# Round 30, cleint 2, epoch 6: epoch_accuracy 59.51522435897436, epoch_loss 1.1456691416410298
# Round 30, cleint 2, epoch 7: epoch_accuracy 61.41826923076923, epoch_loss 1.093492961082703
# Round 30, cleint 2, epoch 8: epoch_accuracy 62.760416666666664, epoch_loss 1.059209623397925
# Round 30, cleint 2, epoch 9: epoch_accuracy 63.94230769230769, epoch_loss 1.028499498581275
# Round 30, cleint 2, epoch 10: epoch_accuracy 65.04407051282051, epoch_loss 0.9859983859918057
# Round 30, cleint 3, epoch 1: epoch_accuracy 52.64423076923077, epoch_loss 1.3328600816237621
# Round 30, cleint 3, epoch 2: epoch_accuracy 54.62740384615385, epoch_loss 1.2686708523676946
# Round 30, cleint 3, epoch 3: epoch_accuracy 56.750801282051285, epoch_loss 1.2061027127962847
# Round 30, cleint 3, epoch 4: epoch_accuracy 58.05288461538461, epoch_loss 1.185037294259438
# Round 30, cleint 3, epoch 5: epoch_accuracy 58.874198717948715, epoch_loss 1.1438471835393171
# Round 30, cleint 3, epoch 6: epoch_accuracy 59.17467948717949, epoch_loss 1.1206419865290325
# Round 30, cleint 3, epoch 7: epoch_accuracy 61.93910256410256, epoch_loss 1.0612912124548204
# Round 30, cleint 3, epoch 8: epoch_accuracy 62.07932692307692, epoch_loss 1.0347921634331727
# Round 30, cleint 3, epoch 9: epoch_accuracy 63.08092948717949, epoch_loss 1.0316987526722443
# Round 30, cleint 3, epoch 10: epoch_accuracy 63.74198717948718, epoch_loss 1.0049437651267419
# Round 30, cleint 4, epoch 1: epoch_accuracy 51.90304487179487, epoch_loss 1.3381354014078777
# Round 30, cleint 4, epoch 2: epoch_accuracy 53.74599358974359, epoch_loss 1.2855874246511705
# Round 30, cleint 4, epoch 3: epoch_accuracy 55.60897435897436, epoch_loss 1.2375161387981513
# Round 30, cleint 4, epoch 4: epoch_accuracy 56.81089743589744, epoch_loss 1.2065413212164855
# Round 30, cleint 4, epoch 5: epoch_accuracy 57.95272435897436, epoch_loss 1.164362024802428
# Round 30, cleint 4, epoch 6: epoch_accuracy 59.07451923076923, epoch_loss 1.1297206282615662
# Round 30, cleint 4, epoch 7: epoch_accuracy 60.77724358974359, epoch_loss 1.1013456483681996
# Round 30, cleint 4, epoch 8: epoch_accuracy 61.17788461538461, epoch_loss 1.0554565626841326
# Round 30, cleint 4, epoch 9: epoch_accuracy 62.4599358974359, epoch_loss 1.0421245862276127
# Round 30, cleint 4, epoch 10: epoch_accuracy 63.46153846153846, epoch_loss 1.0072442973271394
# Round 30, cleint 5, epoch 1: epoch_accuracy 52.22355769230769, epoch_loss 1.3486637885753925
# Round 30, cleint 5, epoch 2: epoch_accuracy 53.90625, epoch_loss 1.2835395962764056
# Round 30, cleint 5, epoch 3: epoch_accuracy 55.82932692307692, epoch_loss 1.232293615738551
# Round 30, cleint 5, epoch 4: epoch_accuracy 56.79086538461539, epoch_loss 1.204956795160587
# Round 30, cleint 5, epoch 5: epoch_accuracy 58.854166666666664, epoch_loss 1.1440773124878223
# Round 30, cleint 5, epoch 6: epoch_accuracy 60.21634615384615, epoch_loss 1.1279912468714592
# Round 30, cleint 5, epoch 7: epoch_accuracy 61.438301282051285, epoch_loss 1.079341987768809
# Round 30, cleint 5, epoch 8: epoch_accuracy 61.85897435897436, epoch_loss 1.0604533545481853
# Round 30, cleint 5, epoch 9: epoch_accuracy 62.84054487179487, epoch_loss 1.042719243428646
# Round 30, cleint 5, epoch 10: epoch_accuracy 63.201121794871796, epoch_loss 1.0137597612845592
# Round 30, cleint 6, epoch 1: epoch_accuracy 60.1963141025641, epoch_loss 1.130808345018289
# Round 30, cleint 6, epoch 2: epoch_accuracy 61.89903846153846, epoch_loss 1.0564430203193274
# Round 30, cleint 6, epoch 3: epoch_accuracy 63.381410256410255, epoch_loss 1.0132110798970246
# Round 30, cleint 6, epoch 4: epoch_accuracy 65.16426282051282, epoch_loss 0.9629575617802448
# Round 30, cleint 6, epoch 5: epoch_accuracy 66.4863782051282, epoch_loss 0.9234241430576031
# Round 30, cleint 6, epoch 6: epoch_accuracy 67.76842948717949, epoch_loss 0.8974637916454902
# Round 30, cleint 6, epoch 7: epoch_accuracy 67.96875, epoch_loss 0.8622480936539478
# Round 30, cleint 6, epoch 8: epoch_accuracy 69.89182692307692, epoch_loss 0.8435073968691703
# Round 30, cleint 6, epoch 9: epoch_accuracy 70.65304487179488, epoch_loss 0.8084206573474102
# Round 30, cleint 6, epoch 10: epoch_accuracy 71.67467948717949, epoch_loss 0.7855856372759893
# Round 30, cleint 7, epoch 1: epoch_accuracy 59.655448717948715, epoch_loss 1.124088927721366
# Round 30, cleint 7, epoch 2: epoch_accuracy 62.80048076923077, epoch_loss 1.0396720789946043
# Round 30, cleint 7, epoch 3: epoch_accuracy 63.52163461538461, epoch_loss 1.0019580676005437
# Round 30, cleint 7, epoch 4: epoch_accuracy 64.42307692307692, epoch_loss 0.9540097392522372
# Round 30, cleint 7, epoch 5: epoch_accuracy 67.48798076923077, epoch_loss 0.9045471877623827
# Round 30, cleint 7, epoch 6: epoch_accuracy 67.8886217948718, epoch_loss 0.8813812923737061
# Round 30, cleint 7, epoch 7: epoch_accuracy 69.03044871794872, epoch_loss 0.8603284595868527
# Round 30, cleint 7, epoch 8: epoch_accuracy 70.71314102564102, epoch_loss 0.821169165464548
# Round 30, cleint 7, epoch 9: epoch_accuracy 70.45272435897436, epoch_loss 0.8084847812469189
# Round 30, cleint 7, epoch 10: epoch_accuracy 71.37419871794872, epoch_loss 0.7915841742203786
# Round 30, cleint 8, epoch 1: epoch_accuracy 60.13621794871795, epoch_loss 1.1349198138102508
# Round 30, cleint 8, epoch 2: epoch_accuracy 62.47996794871795, epoch_loss 1.0376969698147895
# Round 30, cleint 8, epoch 3: epoch_accuracy 63.2411858974359, epoch_loss 1.0052760044733684
# Round 30, cleint 8, epoch 4: epoch_accuracy 64.8838141025641, epoch_loss 0.9591242013833462
# Round 30, cleint 8, epoch 5: epoch_accuracy 67.20753205128206, epoch_loss 0.9170237007813576
# Round 30, cleint 8, epoch 6: epoch_accuracy 67.56810897435898, epoch_loss 0.8929872520459003
# Round 30, cleint 8, epoch 7: epoch_accuracy 69.39102564102564, epoch_loss 0.8555658673628782
# Round 30, cleint 8, epoch 8: epoch_accuracy 69.25080128205128, epoch_loss 0.8349765623227144
# Round 30, cleint 8, epoch 9: epoch_accuracy 70.3926282051282, epoch_loss 0.831407673847981
# Round 30, cleint 8, epoch 10: epoch_accuracy 72.51602564102564, epoch_loss 0.7750937877557217
# Round 30, cleint 9, epoch 1: epoch_accuracy 60.53685897435897, epoch_loss 1.1144679249861302
# Round 30, cleint 9, epoch 2: epoch_accuracy 61.037660256410255, epoch_loss 1.068134566148122
# Round 30, cleint 9, epoch 3: epoch_accuracy 64.32291666666667, epoch_loss 1.0024072306278424
# Round 30, cleint 9, epoch 4: epoch_accuracy 65.56490384615384, epoch_loss 0.9516159441226568
# Round 30, cleint 9, epoch 5: epoch_accuracy 66.3661858974359, epoch_loss 0.9217234765871977
# Round 30, cleint 9, epoch 6: epoch_accuracy 67.82852564102564, epoch_loss 0.9014072295946952
# Round 30, cleint 9, epoch 7: epoch_accuracy 68.56971153846153, epoch_loss 0.85682607231996
# Round 30, cleint 9, epoch 8: epoch_accuracy 69.81169871794872, epoch_loss 0.83995449084502
# Round 30, cleint 9, epoch 9: epoch_accuracy 70.63301282051282, epoch_loss 0.8029556022240565
# Round 30, cleint 9, epoch 10: epoch_accuracy 71.43429487179488, epoch_loss 0.7731637496214646
# Round 30, cleint 10, epoch 1: epoch_accuracy 59.91586538461539, epoch_loss 1.1462518297708952
# Round 30, cleint 10, epoch 2: epoch_accuracy 61.83894230769231, epoch_loss 1.0563274973478072
# Round 30, cleint 10, epoch 3: epoch_accuracy 64.0625, epoch_loss 1.013298782782677
# Round 30, cleint 10, epoch 4: epoch_accuracy 65.16426282051282, epoch_loss 0.9668990258987133
# Round 30, cleint 10, epoch 5: epoch_accuracy 66.86698717948718, epoch_loss 0.9337327029460516
# Round 30, cleint 10, epoch 6: epoch_accuracy 67.58814102564102, epoch_loss 0.8915698818671398
# Round 30, cleint 10, epoch 7: epoch_accuracy 68.8301282051282, epoch_loss 0.8748435790722187
# Round 30, cleint 10, epoch 8: epoch_accuracy 69.6514423076923, epoch_loss 0.8389108211566241
# Round 30, cleint 10, epoch 9: epoch_accuracy 72.19551282051282, epoch_loss 0.7920170204761701
# Round 30, cleint 10, epoch 10: epoch_accuracy 72.23557692307692, epoch_loss 0.7776550856920389
# Model's Round: 30, train accuracy of model: 67.8445512820513, train loss of model: 0.8904073105026515
#
#
# Model's Round: 30, test accuracy of model: 43.480431309904155, test loss of model: 3.5338195010115165
#
#
# round 30 completed

# %%
# folder_name = f"{mathod}_{opti}_lr={learning_rate}_R={round_no}_ E={epochs}_B={batch_size}_{distribution}"
fn_=f"{mathod}_{opti}_E={epochs}_B={batch_size}_iid"

# %%
# def plot_train_test_accuracy(round_results, title, folder):
#     rounds = list(range(0, len(round_results)))
#     train_accuracies = round_results['train_accuracy'].tolist()
#     test_accuracies = round_results['test_accuracy'].tolist()

#     fig, ax = plt.subplots(figsize=(5, 3))
#     ax.plot(rounds, train_accuracies, label='Train Accuracy', color='blue')
#     ax.plot(rounds, test_accuracies, label='Test Accuracy', color='green')

#     ax.set_xlabel("Round")
#     ax.set_ylabel("Server accuracy in %")
#     ax.set_title(title)
#     ax.set_ylim(0, 100)
#     ax.set_xlim(0, len(rounds))
#     ax.set_xticks(range(0, len(rounds) + 2, 10))

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     ax.grid(True)
#     ax.legend()
#     plt.tight_layout()
#     os.makedirs(folder, exist_ok=True)
#     filename = os.path.join(folder, f"{title}.png")
#     plt.savefig(filename, dpi=300)
#     plt.show()





# def plot_flri(round_results, title, folder):
#     rounds = list(range(0, len(round_results)))
#     train_accuracies = round_results['flri'].tolist()
#     print(train_accuracies)
#     # test_accuracies = round_results['test_accuracy'].tolist()

#     fig, ax = plt.subplots(figsize=(5, 3))
#     ax.plot(rounds, train_accuracies, label='flri', color='blue')
#     # ax.plot(rounds, test_accuracies, label='Test Accuracy', color='green')

#     ax.set_xlabel("Round")
#     ax.set_ylabel("Server accuracy in %")
#     ax.set_title(title)
#     ax.set_ylim(0, 2)
#     ax.set_xlim(0, len(rounds))Amr found himself sidelined and held partially responsible for Uthman's death. He then allied with Mu'awiya, who was also seeking retribution for Uthman's death and challenging Caliph Ali's rule. Amr'
#     ax.set_xticks(range(0, len(rounds) + 2, 10))

#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)

#     ax.grid(True)
#     ax.legend()
#     plt.tight_layout()
#     os.makedirs(folder, exist_ok=True)
#     filename = os.path.join(folder, f"{title}.png")
#     plt.savefig(filename, dpi=300)
#     plt.show()

# %%
# # title = f"a) AD vs R for {fn_}"
# # plot_rounds_clients_ad(delta_ad, title, folder_name)

# title = f"Acc (%) vs R for {fn_}"
# plot_train_test_accuracy(round_results, title, folder_name)

# title = f"flri vs R for {fn_}"
# plot_flri(round_results, title, folder_name)

# %% [markdown]
# # Reuslts

# %%
# save_dir = folder_name  # your desired folder
# os.makedirs(save_dir, exist_ok=True)  # create folder if not exists

# save_path = os.path.join(save_dir, 'delta_ad_data.pt')
# torch.save(delta_ad, save_path)
# print(f"[✓] delta_ad saved at {save_path}")

# save_path = os.path.join(folder_name, 'delta_ad_data.pt')

# # Load the saved file
# if os.path.exists(save_path):
#     delta_ad_loaded = torch.load(save_path)
#     print("[✓] Loaded delta_ad from:", save_path)
#     print(delta_ad_loaded)
# else:
#     print("[✗] File not found at:", save_path)

# %%
# Round # Define the folder and file name
# folder_name = f"fed_avg_{opti}_{learning_rate}_{name}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
# folder_name =  f"fed_avg_{opti}_{learning_rate}_{name}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
